# %% [markdown]
# ## Introduction to the Data
#
# Hacker News is a community where users can submit articles, and other users can upvote those articles. The articles with the most upvotes make it to the front page, where they're more visible to the community.
#
# The data set consists of submissions users made to Hacker News from 2006 to 2015.
#
# The columns in the dataset include:
#
# - submission_time - When the article was submitted
# - upvotes - The number of upvotes the article received
# - url - The base URL of the article
# - headline - The article's headline
#
# In this project, I'll be predicting the number of upvotes the articles received, based on their headlines.
#
# Because upvotes are an indicator of popularity, we'll discover which types of articles tend to be the most popular.

# %%
import pandas as pd
submissions = pd.read_csv("sel_hn_stories.csv")
submissions.columns = ["submission_time", "upvotes", "url", "headline"]

# %%
submissions
# Out:
#                submission_time  upvotes                            url  \
# 0         2010-02-17T16:57:59Z        1            blog.jonasbandi.net
# 1         2014-02-04T02:36:30Z        1                  blogs.wsj.com
# 2         2011-10-26T07:11:29Z        1                 threatpost.com
# 3         2011-04-03T15:43:44Z       67               algorithm.com.au
# 4         2013-01-13T16:49:20Z        1                winmacsofts.com
# 5         2013-09-04T12:10:52Z        1     theincidentaleconomist.com
# 6         2012-03-09T20:25:42Z        1              worldometers.info
# 7         2010-04-22T13:23:10Z       26                       docs.com
# 8         2012-05-06T16:08:46Z        2             blog.hackplanet.in
# 9     2014-12-23T00:55:31.000Z        1                  curt-rice.com
# 10    2014-08-14T14:27:07.000Z       26                            NaN
# 11        2013-06-27T20:35:34Z        8                    nytimes.com
# 12        2014-03-23T00:22:26Z        1                 retargeter.com
# 13        2011-12-14T15:50:25Z        2                extremetech.com
# 14        2011-10-01T05:28:30Z        9  tenprinciplesofgooddesign.com
# 15        2012-04-17T17:02:58Z      109                     google.com
# 16        2012-04-02T18:14:03Z       48                    tomayko.com
# 17    2014-07-28T06:53:09.000Z        3             washingtonpost.com
# 18        2010-08-18T02:47:01Z        3                    youtube.com
# 19        2011-12-02T15:12:30Z        1           changerlaplanete.com
# 20        2011-07-05T10:32:02Z       61         holdenweb.blogspot.com
# 21        2013-02-09T23:18:04Z        1             peninsulapress.com
# 22        2012-06-04T21:43:00Z        1                  letitlinks.ru
# 23        2012-03-12T00:55:44Z       10                   usatoday.com
# 24        2011-11-10T17:32:14Z       15                    nytimes.com
# 25        2010-01-12T14:55:24Z        1                 rowtheboat.com
# 26        2011-03-08T02:54:22Z        1        join.latinosexdates.com
# 27        2012-04-03T23:12:51Z        1               androidandme.com
# 28        2014-04-14T13:37:13Z        1                     kottke.org
# 29        2010-12-12T12:48:48Z        2                    nytimes.com
# ...                        ...      ...                            ...
# 2969      2010-02-16T16:40:05Z        5               smexperiment.com
# 2970      2011-10-11T11:47:02Z        2                    youtube.com
# 2971      2013-08-13T21:18:00Z        1                  smitpatel.com
# 2972  2015-01-12T14:12:46.000Z        3                 chronicons.com
# 2973      2013-04-04T14:09:41Z        1                        veri.fi
# 2974      2013-11-13T19:03:32Z        1                raspberrypi.org
# 2975      2010-07-12T13:00:36Z        2                       gist.com
# 2976      2013-02-23T04:39:10Z        1               dunkhighclub.com
# 2977      2011-12-20T00:04:49Z        1                        npr.org
# 2978      2013-05-10T13:57:01Z        1           devops.rackspace.com
# 2979  2014-11-06T10:49:34.000Z        1               ariannaodell.com
# 2980      2011-12-18T16:24:33Z        9                 techcrunch.com
# 2981      2010-10-29T22:19:52Z       32                 techcrunch.com
# 2982      2009-01-14T17:27:28Z        1                    nettuts.com
# 2983  2014-06-30T09:10:36.000Z        2                    9to5mac.com
# 2984      2011-11-12T06:54:56Z        1       thomassabo-charmshop.com
# 2985      2011-10-07T19:23:13Z      172                       b3ta.com
# 2986      2014-02-25T01:40:44Z        2              blog.ethereum.org
# 2987      2012-07-29T12:44:54Z        7                      bbc.co.uk
# 2988      2008-03-11T01:44:45Z        7                     k.blog.com
# 2989      2011-12-15T21:56:28Z        2        blog.millermedeiros.com
# 2990      2012-04-26T10:55:04Z      170                jasondavies.com
# 2991      2011-12-09T19:48:24Z        1            specialimages.co.uk
# 2992      2012-01-20T15:31:33Z        1                  27bslash6.com
# 2993      2011-12-28T08:35:13Z        1            walksandwalking.com
# 2994  2015-03-23T18:46:53.000Z        1               ondras.github.io
# 2995      2010-03-11T19:52:37Z       40                  economist.com
# 2996  2015-04-03T18:07:13.000Z        2              computerworld.com
# 2997      2013-07-17T21:54:41Z        2         blog.pythonlibrary.org
# 2998      2011-04-04T23:43:48Z        1                      bitly.com
#
#                                                headline
# 0     Software: Sadly we did adopt from the construc...
# 1      Google’s Stock Split Means More Control for L...
# 2     SSL DOS attack tool released exploiting negoti...
# 3          Immutability and Blocks Lambdas and Closures
# 4            Comment optimiser la vitesse de Wordpress?
# 5               ilk is not as good for you as you think
# 6             Worldometers - Real time world statistics
# 7     icrosoft strikes back: introduces docs for fac...
# 8                                Net HTTP status codes
# 9     Anecdata or how McKinsey’s story became Sheryl...
# 10    Ask HN: What Android Wear apps would you like ...
# 11                Immigration Overhaul Passes in Senate
# 12                 What matters most at Ad:TECH SF 2014
# 13    Amazon Silk revisited: Is the split cloud brow...
# 14           Dieter Ram's Ten Principles Of Good Design
# 15                                           Gmail Down
# 16        Show How Don't Tell What - A Management Style
# 17        U.S. releases images said to implicate Russia
# 18    Real-time OCR/translation of Chinese text thro...
# 19                     Des dcorations de Nol plus colos
# 20                                   Childish behaviour
# 21    Silicon Valley shouldnt fear China Atlantic Mo...
# 22                              Mirillis Action 1.3.3.0
# 23       Older entrepreneurs find new niche in startups
# 24    Computer Programming for Children Minus Crypti...
# 25                     AB testing with Google Analytics
# 26                                      Latino SexDates
# 27    otorola is turning Android 4.0 into a desktop ...
# 28                   A.I. movie merch: Super Toy Teddy
# 29    Prisoners in GA Organize Strike via Contraband...
# ...                                                 ...
# 2969                                 Twitter Experiment
# 2970          Case Study: How Orabrush Got into Walmart
# 2971  Don't Miss Out on the Quora Distribution Gold ...
# 2972     Designing Icons for the Apple Watch: Icon Size
# 2973  Show HN: VeriFi - A web service for asking que...
# 2974  FM Stream: broadcasting local radio to the int...
# 2975     Gist (interesting social media realm start-up)
# 2976                            Nike DunksNike Free Run
# 2977               Why Are Americans So Bad At Saving?
# 2978         DevOps: Improved Productivity Higher Value
# 2979   Can I live in NYC for a month on a budget of $0?
# 2980  Technology Cannot Disrupt Education From The T...
# 2981                          Facebook Acquires Drop.io
# 2982              Practical and creative uses of jQuery
# 2983  Tim Cook and Apple celebrate #ApplePride in Sa...
# 2984  Thomas Sabo Motorcycle Pendant T0188-001-12tho...
# 2985         Breaking a MacBook in memory of Steve Jobs
# 2986            Self-Enforcing Contracts And Factum Law
# 2987          Programmers sought for tropical hackathon
# 2988    Why web frameworks are a bad thing part 1: MVC
# 2989                The problem with CSS pre-processors
# 2990                              Animated Bzier Curves
# 2991                                 Business Headshots
# 2992  Girls like modern technology. Like telephones ...
# 2993                      Walks And Walking Accessories
# 2994            Rot.js: ROguelike Toolkit in JavaScript
# 2995  Amazon auctions computing power: Clouds under ...
# 2996  Nissan CEO: We will have an autonomous vehicle...
# 2997                  Connecting to Dropbox with Python
# 2998  Crowdsourcing disaster response What we learn ...
#
# [2999 rows x 4 columns]

# %% [markdown]
# ## Finding missing Values

# %%
submissions.isnull().sum()
# Out:
# submission_time      0
# upvotes              0
# url                189
# headline            10
# dtype: int64

# %%
submissions.notnull().sum()
# Out:
# submission_time    2999
# upvotes            2999
# url                2810
# headline           2989
# dtype: int64

# %% [markdown]
# Since url and headline NaN values constitutes about less than 7% of the entire datapoints, its fair to drop all rows that contains any NaN value

# %%
submissions = submissions.dropna(axis=0)

# %%
submissions.isnull().sum()
# Out:
# submission_time    0
# upvotes            0
# url                0
# headline           0
# dtype: int64

# %% [markdown]
# ## Tokenizing & Preprocessing the Headlines
#
# As earlier said, I'll be using only the Headlines column to train the model

# %%
tokenized_headlines = []
for item in submissions["headline"]:
    tokenized_headlines.append(item.split())
tokenized_headlines
# Out:
# [['Software:',
#   'Sadly',
#   'we',
#   'did',
#   'adopt',
#   'from',
#   'the',
#   'construction',
#   'analogy'],
#  ['Google’s',
#   'Stock',
#   'Split',
#   'Means',
#   'More',
#   'Control',
#   'for',
#   'Larry',
#   'and',
#   'Sergey'],
#  ['SSL',
#   'DOS',
#   'attack',
#   'tool',
#   'released',
#   'exploiting',
#   'negotiation',
#   'overhead'],
#  ['Immutability', 'and', 'Blocks', 'Lambdas', 'and', 'Closures'],
#  ['Comment', 'optimiser', 'la', 'vitesse', 'de', 'Wordpress?'],
#  ['ilk', 'is', 'not', 'as', 'good', 'for', 'you', 'as', 'you', 'think'],
#  ['Worldometers', '-', 'Real', 'time', 'world', 'statistics'],
#  ['icrosoft', 'strikes', 'back:', 'introduces', 'docs', 'for', 'facebook'],
#  ['Net', 'HTTP', 'status', 'codes'],
#  ['Anecdata',
#   'or',
#   'how',
#   'McKinsey’s',
#   'story',
#   'became',
#   'Sheryl',
#   'Sandberg’s',
#   'fact'],
#  ['Immigration', 'Overhaul', 'Passes', 'in', 'Senate'],
#  ['What', 'matters', 'most', 'at', 'Ad:TECH', 'SF', '2014'],
#  ['Amazon',
#   'Silk',
#   'revisited:',
#   'Is',
#   'the',
#   'split',
#   'cloud',
#   'browser',
#   'any',
#   'faster?'],
#  ['Dieter', "Ram's", 'Ten', 'Principles', 'Of', 'Good', 'Design'],
#  ['Gmail', 'Down'],
#  ['Show', 'How', "Don't", 'Tell', 'What', '-', 'A', 'Management', 'Style'],
#  ['U.S.', 'releases', 'images', 'said', 'to', 'implicate', 'Russia'],
#  ['Real-time',
#   'OCR/translation',
#   'of',
#   'Chinese',
#   'text',
#   'through',
#   'iPhone',
#   'video',
#   'camera'],
#  ['Des', 'dcorations', 'de', 'Nol', 'plus', 'colos'],
#  ['Childish', 'behaviour'],
#  ['Silicon',
#   'Valley',
#   'shouldnt',
#   'fear',
#   'China',
#   'Atlantic',
#   'Monthly',
#   'writer',
#   'says'],
#  ['Mirillis', 'Action', '1.3.3.0'],
#  ['Older', 'entrepreneurs', 'find', 'new', 'niche', 'in', 'startups'],
#  ['Computer', 'Programming', 'for', 'Children', 'Minus', 'Cryptic', 'Syntax'],
#  ['AB', 'testing', 'with', 'Google', 'Analytics'],
#  ['Latino', 'SexDates'],
#  ['otorola',
#   'is',
#   'turning',
#   'Android',
#   '4.0',
#   'into',
#   'a',
#   'desktop',
#   'OS',
#   'with',
#   'Webtop',
#   '3.0'],
#  ['A.I.', 'movie', 'merch:', 'Super', 'Toy', 'Teddy'],
#  ['Prisoners',
#   'in',
#   'GA',
#   'Organize',
#   'Strike',
#   'via',
#   'Contraband',
#   'Cellphones'],
#  ['Amazon', 'Cloud', 'Major', 'Outages', '-', 'Analysis'],
#  ['Hired',
#   'Raises',
#   '$15M',
#   'Series',
#   'A',
#   'At',
#   'Valuation',
#   'Around',
#   '$60M'],
#  ['Google',
#   'CEO',
#   'Is',
#   'Tired',
#   'of',
#   'Rivals',
#   'Laws',
#   'Wants',
#   'to',
#   'Start',
#   'His',
#   'Own',
#   'Country'],
#  ['Effective', 'C++11:', 'Content', 'and', 'Status', '(Scott', 'Meyers)'],
#  ['Twitter',
#   'Back',
#   'On',
#   'Track?',
#   '-',
#   'Raises',
#   'API',
#   'Limit',
#   'To',
#   '100',
#   'Requests',
#   'Per',
#   'Hour'],
#  ['Faster', 'Search', 'With', 'Slashtag.it'],
#  ['The', 'End', 'of', 'Ragequitting'],
#  ['Why',
#   'Basecamp',
#   'just',
#   'launched',
#   'an',
#   'online',
#   'magazine',
#   'that',
#   'shuns',
#   'technology'],
#  ['an', 'quits', 'job', 'with', 'a', 'cake'],
#  ['On',
#   'Being',
#   'a',
#   'Black',
#   'Male',
#   'Six',
#   'Feet',
#   'Four',
#   'Inches',
#   'Tall',
#   'in',
#   'America',
#   'in',
#   '2014'],
#  ['Using', 'OAuth', '2.0', 'with', 'MQTT'],
#  ['PlayStation', '4', "'starting", 'to', 'sell', "out'"],
#  ['Skype', 'for', 'Windows', 'Phone', 'is', 'out', 'of', 'beta'],
#  ['Kernel.org', 'is', 'back'],
#  ['How', "Obama's", 'BlackBerry', 'got', 'secured'],
#  ['Open', 'Web', 'Payments', '-', "PayPal's", 'answer', 'to', 'OpenTransact'],
#  ['Show', 'HN:', 'Discover', 'Top', 'Tech', 'Industry', 'Bloggers'],
#  ["Don't",
#   'Freak',
#   'Out',
#   'but',
#   'the',
#   'First',
#   '3D-Printed',
#   'Metal',
#   'Gun',
#   'Totally',
#   'Works'],
#  ['Our', 'Living', 'Style', 'Guide', '(Writing', 'maintainable', 'HTML/CSS)'],
#  ['Vince', 'Del', 'Monte', 'Fitness', 'for', 'all', 'ages:'],
#  ['Social', 'Media', 'Portraits.'],
#  ['Conceive',
#   'Choose',
#   'Create',
#   'Communicate:',
#   'Advice',
#   'for',
#   'successful',
#   'projects',
#   'from',
#   'a',
#   'hacker'],
#  ['VLC', '1.2.0', 'features', '-', 'Part', '1', 'video', 'output'],
#  ['Startup', 'lessons', 'learned', 'from', 'Warren', 'Buffett'],
#  ['Tesla', 'Smashes', 'Earnings', 'And', 'Revenue', 'Expectations'],
#  ['The', 'Dramatic', 'Nature', 'of', 'the', 'Easiest', 'Bugs', 'to', 'Fix'],
#  ['Google',
#   'Microsoft',
#   'Facebook',
#   'banks',
#   'team',
#   'to',
#   'wipe',
#   'out',
#   'phishing',
#   'via',
#   'DMARC.org'],
#  ['Startups',
#   'Try',
#   'To',
#   'Reroute',
#   'Food',
#   'Waste',
#   'To',
#   'The',
#   'Hungry',
#   ':',
#   'The',
#   'Salt'],
#  ['Tourist', 'Health', 'Insurance', 'for', 'Backpackers'],
#  ['Jonathan', 'Harris', ':', 'Today'],
#  ['Star', 'Wars', 'the', '(High', 'School)', 'Musical', '[video]'],
#  ["'Hacktivists'",
#   'pose',
#   'biggest',
#   'data',
#   'breach',
#   'threat',
#   'study',
#   'finds'],
#  ["France's", '35-hour', 'working', 'week', 'under', 'threat'],
#  ['How', 'Allies', 'Used', 'Math', 'Against', 'German', 'Tanks'],
#  ['ozilla',
#   'Launches',
#   'Minion',
#   'Automated',
#   'Security',
#   'Testing',
#   'Platform'],
#  ['Priceofweed.com', 'releases', 'database', 'on', 'BuzzData'],
#  ['Understanding', 'CSS', 'Filter', 'Effects'],
#  ['Google',
#   'backs',
#   'Iowa',
#   'wind',
#   'farm',
#   'has',
#   'put',
#   'close',
#   'to',
#   '$1B',
#   'into',
#   'clean',
#   'power'],
#  ['Teletext', 'ad', '1978'],
#  ['Air', 'Jordan', '2010', 'Silver', 'Anniversary', 'Dwyane', 'Wade'],
#  ['Simulations',
#   'on',
#   'the',
#   'chances',
#   'Kentucky',
#   'goes',
#   '40-0',
#   'in',
#   'College',
#   'Hoops'],
#  ["Snowden's",
#   'Moscow',
#   'Lawyer:',
#   'NSA',
#   'Leaker',
#   'Is',
#   'Planning',
#   'To',
#   'Live',
#   'In',
#   'Russia',
#   'And',
#   'Get',
#   'A',
#   'Job'],
#  ['The',
#   '19th-century',
#   'Mumbai',
#   'plague',
#   'may',
#   'offer',
#   'clues',
#   'in',
#   'dealing',
#   'with',
#   'Ebola'],
#  ['So', 'you', 'need', 'a', 'typface?'],
#  ['App', 'Engine', '1.7.1', 'Released'],
#  ['Use', 'It', 'or', 'Loose', 'It'],
#  ['icrosoft',
#   'customer',
#   'service',
#   'experience:',
#   'The',
#   'good',
#   'after',
#   'the',
#   'bad'],
#  ['12th',
#   'annual',
#   'ICFP',
#   'programming',
#   'contest',
#   'begins',
#   'next',
#   'weekend'],
#  ['How',
#   'to',
#   'save',
#   'YouTube',
#   'video',
#   'to',
#   'MP3',
#   'formats',
#   'on',
#   'Mac?'],
#  ['The', 'Pastebin', 'Client', 'Exercise'],
#  ['TeliaSonera',
#   'to',
#   'build',
#   'Facebooks',
#   'new',
#   'pan-European',
#   'optical',
#   'network'],
#  ['Email',
#   '&',
#   'Teens',
#   '-',
#   'Using',
#   'email',
#   'hasnt',
#   'taken',
#   'root',
#   'amongst',
#   'the',
#   'Millennials?'],
#  ['Some', 'of', "technology's", 'most', 'underrated', 'founders'],
#  ['API',
#   'Economy:',
#   'Growth',
#   'of',
#   'an',
#   'API',
#   'Hub',
#   'from',
#   '0',
#   'to',
#   '100K',
#   'Users',
#   'and',
#   '10K',
#   'APIs'],
#  ['Covert', 'Communication', 'in', 'a', 'Dark', 'Network'],
#  ['History',
#   'of',
#   'the',
#   'Continental',
#   'Tire',
#   'Company',
#   'First',
#   'Fifty',
#   'Years',
#   'of',
#   'Success'],
#  ['Confessions', 'of', 'a', "'job", "hopper'"],
#  ['Bing', 'is', 'fine', 'insecure', 'as', 'ever', 'but', 'fine'],
#  ['Reddit', 'gay', 'gamers', 'to', 'fight', 'Gaymer', 'trademark'],
#  ['Show',
#   'HN:',
#   'My',
#   'one-sided',
#   'anonymous',
#   'chat',
#   'startup',
#   'reached',
#   '150K+',
#   'members',
#   'virally'],
#  ['Security', 'Hands', 'on', 'Training', '–', 'Part', '1'],
#  ['How', 'to', 'Get', 'Rich', 'Really', 'Really', 'Rich'],
#  ['PayPal',
#   'To',
#   'Open',
#   'A',
#   'Pop-Up',
#   'Store',
#   'In',
#   'New',
#   'York',
#   'To',
#   'Showcase',
#   'New',
#   'Payments',
#   'Technologies'],
#  ['Interacting',
#   'with',
#   'women',
#   'can',
#   'impair',
#   "men's",
#   'cognitive',
#   'functioning'],
#  ['6120', 'C', 'Mic', 'Microphone', 'Problem'],
#  ['Kickstrap:', 'Bootstrap', 'with', 'apps', 'themes', 'and', 'extras'],
#  ['aking', 'money', 'online', 'with', 'freelance', 'jobs'],
#  ['Craft', 'Beer', 'Delivered', 'to', 'Your', 'Office'],
#  ['3D',
#   'printing',
#   'is',
#   'a',
#   'lot',
#   'of',
#   'hype',
#   'and',
#   "it'll",
#   'never',
#   'go',
#   'mainstream'],
#  ['arines',
#   'Catch',
#   'Deserter',
#   '5',
#   'Years',
#   'After',
#   'His',
#   'Honorable',
#   'Discharge'],
#  ['Docker', 'hack', 'day', 'lightning', 'talks', 'live'],
#  ['What', 'Wired', 'Is', 'Not', 'Telling', 'You', 'Eugene', 'Kaspersky'],
#  ['Kindle',
#   'Fire:',
#   'Take',
#   'three',
#   'tablets',
#   'and',
#   'call',
#   'me',
#   'in',
#   'the',
#   'morning'],
#  ['Wary', 'of', 'Egypt', 'Unrest', 'China', 'Censors', 'Web'],
#  ['The',
#   'first',
#   'new',
#   'release',
#   'of',
#   'Inform',
#   'in',
#   'three',
#   'years',
#   'is',
#   'now',
#   'available'],
#  ['The', 'Best', 'API', 'Documentation'],
#  ['BBC', 'website', 'crashes', 'for', 'an', 'hour'],
#  ['Queen', 'tours', 'RIM'],
#  ['Pirated', 'Rihanna', 'songs', 'land', 'Frenchman', 'in', 'court'],
#  ['What', 'is', 'all', 'of', 'this', 'Sublime', 'Text', '2', 'hullaballo?'],
#  ['Dont', 'get', 'stuck:', 'Continuous', 'Deployment'],
#  ['Aaron', "Swartz's", 'Final', 'Commit'],
#  ['Crazy',
#   'stop',
#   'motion',
#   'video:',
#   'Ninja',
#   'Moped',
#   '-',
#   'Insert',
#   'Coin',
#   '[video]'],
#  ['New', 'Sports', 'Cars', 'Hitting', 'the', 'Surface', 'in', '2011-2012'],
#  ['Couple', '–', 'Relationship', 'App', 'for', 'Two'],
#  ['Salman',
#   'Khan',
#   'on',
#   'the',
#   'power',
#   'of',
#   'the',
#   'Internet',
#   'for',
#   'learning'],
#  ['Haskelier', '–', 'Haskell', 'for', 'the', 'Advanced', 'Layman'],
#  ['The',
#   'Digg',
#   'Heat',
#   'Map:',
#   'Digg',
#   'is',
#   'mostly',
#   'US',
#   'and',
#   'mostly',
#   'read',
#   'at',
#   'work'],
#  ['Google',
#   'TV',
#   'Growing',
#   'Pains:',
#   'Networks',
#   'Block',
#   'Web',
#   'TV',
#   'Shows'],
#  ["Denthor's", 'Graphics', 'Tutorials:', 'Why', 'I', 'am', 'a', 'Programmer'],
#  ['Gelael',
#   'art',
#   'shop',
#   'Light',
#   'pink',
#   'and',
#   'gold',
#   'wedding',
#   'centerpiece'],
#  ["Gigya's", 'Big', 'Win', 'With', 'Top', 'Widget', 'Companies'],
#  ['Introducing', 'Firefox', '9'],
#  ['Five',
#   "DO's",
#   'and',
#   "DON'Ts",
#   'on',
#   'Building',
#   'Your',
#   'Robotics',
#   'Startup'],
#  ['Programming', 'Your', 'Culture'],
#  ['Apple',
#   'hires',
#   'former',
#   'Windows',
#   'Hacker',
#   'away',
#   'from',
#   'Microsoft'],
#  ['Patent',
#   'Crowdbusting:',
#   'Q&A',
#   'with',
#   'Cheryl',
#   'Milone',
#   'of',
#   'Article',
#   'One',
#   'Partners'],
#  ['Prometheus:', 'A', 'Next-Generation', 'Monitoring', 'System'],
#  ['Whyday:', 'August', '19'],
#  ['eet',
#   'the',
#   'electric',
#   'life',
#   'forms',
#   'that',
#   'live',
#   'on',
#   'pure',
#   'energy'],
#  ['Tehnoetic',
#   'wireless',
#   'USB',
#   'adapter',
#   'now',
#   'FSF-certified',
#   'to',
#   'respect',
#   'your',
#   'freedom'],
#  ['New', 'Zealand', 'Military', 'Releases', 'UFO', 'Files'],
#  ['List', 'of', 'HTML5', 'Charts'],
#  ['Device',
#   'Frontiers',
#   'That',
#   'Mobile',
#   'Developers',
#   'Think',
#   'Are',
#   'Coming'],
#  ['Laptop',
#   'On',
#   'Your',
#   'Lap',
#   'Might',
#   'Cause',
#   'Fertility',
#   'Issues',
#   'in',
#   'Men'],
#  ['How', 'small', 'companies', 'can', 'compete', 'with', 'Amazon'],
#  ['FBI', 'redacting', 'published', 'facts', 'from', 'drone', 'documents'],
#  ['Relationship', 'of', 'the', 'Government', 'and', 'Entrepreneurship'],
#  ['RT',
#   'AristotelesSD:',
#   'lopezobrador_',
#   'GANO',
#   'AL',
#   'PENDEJO',
#   'DE',
#   'MEXICO',
#   'EPN'],
#  ['Climate',
#   'Change',
#   'As',
#   'Religion:',
#   'The',
#   'Gospel',
#   'According',
#   'To',
#   'Gore'],
#  ['Tip', 'of', 'the', 'week'],
#  ['Premium', 'Rafting', 'Vail', 'Colorado'],
#  ['Pokemon', 'Yellow', 'Total', 'Control', 'Hack'],
#  ["Earth's",
#   'Gold',
#   'May',
#   'Come',
#   'From',
#   'Collisions',
#   'of',
#   'Dead',
#   'Stars'],
#  ['Introducing', 'Chaos', 'Engineering'],
#  ['This', 'is', 'my', 'Twitter', 'algorithm.', "What's", 'yours?'],
#  ['Face', 'tracking', 'coupled', 'with', 'projection', 'mapping'],
#  ['ajorIntel:', 'Business', 'intelligence', 'for', 'QuickBooks'],
#  ['Dear', 'Verisign:', 'Trust', 'requires', 'Transparency'],
#  ['Berlin', 'Tech', 'Start-ups'],
#  ['Show', 'HN:', 'Madrasa', '–', 'A', 'community', 'for', 'Autodidacts'],
#  ['arkov', 'Chains', 'using', "CouchDB's", 'Group', 'Reduce'],
#  ['How', 'serious', 'is', 'the', 'Java7', 'Solr/Lucene', 'bug?'],
#  ['Red', 'Universe', '(requires', 'Flash', '+', 'High-speed', 'Internet)'],
#  ['Snowden:',
#   'I',
#   'Left',
#   'the',
#   'NSA',
#   'Clues',
#   'But',
#   'They',
#   'Couldn’t',
#   'Find',
#   'Them'],
#  ['Newspapers',
#   'can',
#   'reduce',
#   'traffic',
#   'by',
#   '32%',
#   'by',
#   'simply',
#   'asking',
#   'Google',
#   'to',
#   'stop',
#   'sending',
#   'them',
#   'traffic'],
#  ['Google', 'Miscalculator:', 'Revealing', 'Errors'],
#  ['Refactoring', 'Methods', 'with', 'Recursive', 'Combinators'],
#  ['Blog',
#   'Security',
#   'X',
#   'Give',
#   'your',
#   'blog',
#   'some',
#   'extra',
#   'protection.'],
#  ['The', 'Turing', 'Test:', 'Transcripts', 'of', 'the', 'best', 'attempts'],
#  ['Hulu', 'a', 'Victim', 'of', 'Its', 'Own', 'Success?'],
#  ['Olympics', 'Diving', 'live', 'stream', 'online', 'watch', 'here'],
#  ['The', 'Bill', 'Gates', 'challenge', 'to', 'reinvent', 'the', 'toilet'],
#  ['How', 'Bookya', 'Disrupts', 'the', 'Live-Entertainment', 'Industry'],
#  ['Artificial', 'Lawn'],
#  ['Creating', 'effective', 'ruby', 'gems'],
#  ['ight', 'want', 'to', 'skip', 'that', 'tech', 'conference', 'in', 'India'],
#  ['Balancing', 'family', 'and', 'the', 'Drive', 'to', 'Succeed?'],
#  ['EU', 'Opens', 'Antitrust', 'Investigation', 'into', 'Google', 'Search'],
#  ['When',
#   'is',
#   'the',
#   'best',
#   'time',
#   'of',
#   'the',
#   'year',
#   'to',
#   'start',
#   'my',
#   'start-up?'],
#  ['Setup', 'Ghost', 'with', 'PostgreSQL', 'via', 'Dokku'],
#  ['Parliament', 'of', 'the', 'Worlds', 'Religions'],
#  ['Would', 'you', 'hire', 'a', 'Netflix', 'casualty?'],
#  ['Google', 'Earth', '-', 'Except', "it's", 'for', 'Space'],
#  ['Technical', 'Articles'],
#  ['Real-Time', 'Chat', 'Using', 'Dynamic', 'Animated', 'Images'],
#  ['Is',
#   'Paul',
#   'Graham',
#   'really',
#   'as',
#   'PHONY',
#   'as',
#   'these',
#   'guys',
#   'make',
#   'him',
#   'out',
#   'to',
#   'be?'],
#  ['Side',
#   'project',
#   'to',
#   'fund',
#   '3',
#   'months',
#   'of',
#   'rent',
#   'for',
#   'people',
#   'in',
#   'need',
#   'of',
#   'assistance'],
#  ['Only',
#   '5%',
#   'of',
#   'Cubans',
#   'have',
#   'access',
#   'to',
#   'the',
#   'open',
#   'Internet'],
#  ['http_load', '-', 'test', 'your', 'server', 'for', 'heavy', 'load'],
#  ['What', 'are', 'good', 'keyboards', 'for', 'programming?'],
#  ['The',
#   'Voice',
#   'Chat',
#   'API',
#   'Is',
#   'Great',
#   'Example',
#   'Of',
#   'An',
#   'Simple',
#   'Open',
#   'API',
#   'Driven',
#   'Resource'],
#  ['Ego', 'and', '"News', 'Logic"'],
#  ['Walk', 'in', 'bath'],
#  ['Stand', 'Out', 'Get', 'Hired'],
#  ['Easiest',
#   'Guide',
#   'of',
#   'Converting',
#   'MP4',
#   'videos',
#   'to',
#   'MOV',
#   'files',
#   'on',
#   'Mac'],
#  ['Networking',
#   'at',
#   'SXSW:',
#   'How',
#   'to',
#   'Tell',
#   'if',
#   "They're",
#   'Interested',
#   'in',
#   'Business',
#   'or',
#   'Pleasure'],
#  ['The', 'interactive', 'projector', ':'],
#  ['Bret',
#   "Victor's",
#   '(Ex-Apple)',
#   'yin',
#   'and',
#   'yang',
#   'of',
#   'technology',
#   'and',
#   'design'],
#  ['The',
#   'Mercenary',
#   'Techie',
#   'Who',
#   'Troubleshoots',
#   'for',
#   'Drug',
#   'Dealers',
#   'and',
#   'Jealous',
#   'Lovers'],
#  ['Should', 'CS', 'students', 'be', 'graded', 'on', 'performance?'],
#  ['Goa', 'Escorts'],
#  ['Cartoon', 'Wild', 'Weather'],
#  ['Build',
#   'Data-Driven',
#   'Apps',
#   'with',
#   'Windows',
#   'Azure',
#   'and',
#   'Windows',
#   'Phone',
#   '7'],
#  ['Death',
#   'in',
#   'the',
#   'Sahara:',
#   'An',
#   'Ill-Fated',
#   'Attempt',
#   'to',
#   'Reach',
#   'Fortress',
#   'Europe'],
#  ['So',
#   'long',
#   'and',
#   'thanks',
#   'for',
#   'all',
#   'the',
#   'fish.',
#   'Missing',
#   'Douglas',
#   'Adams.'],
#  ['Yesterday',
#   'Russia',
#   'lost',
#   'contact',
#   'with',
#   'every',
#   'last',
#   'one',
#   'of',
#   'its',
#   'space',
#   'satellites'],
#  ['Live', 'Voting', 'Results'],
#  ['What',
#   'it',
#   'takes',
#   'to',
#   'make',
#   'Reddit',
#   'front',
#   'page',
#   'data',
#   'and',
#   'stats'],
#  ['Design-based',
#   'Web',
#   'Applications',
#   'Development',
#   '-',
#   'The',
#   'Essential',
#   'New',
#   'Paradigm'],
#  ['Cara:',
#   'Software',
#   'that',
#   'turns',
#   'any',
#   'camera',
#   'into',
#   'an',
#   'intelligent',
#   'sensor'],
#  ['Being', 'Bleeding', 'Edge', 'Is', 'a', 'Good', 'Thing'],
#  ['Nokia', 'C3', 'Price'],
#  ['Freebie',
#   'Alert:',
#   'Awesome',
#   'Collection',
#   'of',
#   'Textures',
#   'From',
#   'Wegraphics'],
#  ['PhotoMath',
#   'uses',
#   'your',
#   "phone's",
#   'camera',
#   'to',
#   'solve',
#   'equations'],
#  ['GoPano',
#   'micro',
#   '-',
#   'Capture',
#   '360',
#   'videos',
#   'from',
#   'an',
#   'iPhone',
#   '4'],
#  ['Bill',
#   'to',
#   'protect',
#   'car',
#   'services',
#   'from',
#   'Uber',
#   'raises',
#   'questions'],
#  ['The', 'New', "iPad's", 'Screen', 'Under', 'the', 'Microscope'],
#  ['Nice', 'and', 'funny', 'pic'],
#  ['5', 'Web', 'titans', 'that', 'withered', 'under', 'Yahoo'],
#  ['DHS', 'Seizes', '75+', 'Domain', 'Names'],
#  ['New',
#   'Zealand',
#   'to',
#   'begin',
#   'registrations',
#   'for',
#   '2nd',
#   'level',
#   'domains',
#   'tomorrow'],
#  ['Open', 'Source', 'Github', 'Internal', 'Training', 'Materials'],
#  ['Innovation',
#   'in',
#   'education',
#   'and',
#   'the',
#   'opportunity',
#   'to',
#   'create'],
#  ['Low',
#   'Cost',
#   'access',
#   'to',
#   'space',
#   'with',
#   'the',
#   'Starfire',
#   'space',
#   'cannon'],
#  ['RockMelt', 'Releases', 'RockMelt', 'Mobile', 'Browser', 'For', 'iPhone'],
#  ['Canadian',
#   'Hacker',
#   'School',
#   'Goes',
#   'Dark',
#   'After',
#   'Government',
#   'Probe'],
#  ['Plurk', 'relaunches', 'with', 'Twitter/Facebook', 'like', 'service'],
#  ['Ice', 'Cream'],
#  ['How', 'Great', 'iOS', 'Animations', 'Make', 'Great', 'Apps'],
#  ['Google',
#   'Built',
#   'End-to-End',
#   'Encryption',
#   'to',
#   'Block',
#   'Cyber-Crime',
#   'Not',
#   'the',
#   'NSA'],
#  ['Obama', 'new', 'tech', 'A-listers', 'align'],
#  ['Meet', 'Periscope', "Twitter's", 'New', 'Live', 'Video', 'App'],
#  ['Google',
#   'Ventures-Backed',
#   'Start-Up',
#   'TrueLens',
#   'Nabs',
#   '$1.2',
#   'Million'],
#  ['5', 'reasons', 'KDE', 'is', 'better', 'than', 'Unity.'],
#  ['The', 'Problem', 'with', 'Blogging', 'Culture'],
#  ['Sprint',
#   'set',
#   'to',
#   'release',
#   '3G-enabling',
#   '"case"',
#   'for',
#   'iPod',
#   'touch'],
#  ['Startup', 'Quotes'],
#  ['Join', 'Twitter', 'and', 'Get', 'Spammed'],
#  ['Is', 'Trader', 'Joes', 'Really', 'Not', 'on', 'Twitter?'],
#  ['A', 'Start-Up', 'Ecosystem', 'Forms', 'in', 'Chicago'],
#  ['Computer', 'Anonymous'],
#  ['Localization',
#   'platform',
#   'Phraseapp',
#   'now',
#   'offers',
#   'Gengo',
#   'powered',
#   'translation'],
#  ['arioWay:',
#   'a',
#   'hands-free',
#   'wheelchair',
#   'to',
#   'narrow',
#   'the',
#   'disability',
#   'gap.',
#   'Italian',
#   'design'],
#  ['Scala', 'compiler', 'phases'],
#  ['Building', 'High-Quality', 'Front-End', 'Modules'],
#  ['What', 'marriage', 'means', 'to', 'me'],
#  ['Do',
#   'we',
#   'really',
#   'want',
#   'Linux',
#   'machines',
#   'that',
#   'never',
#   'reboot?'],
#  ['How',
#   'I',
#   'Reached',
#   '100000',
#   'views',
#   'in',
#   '30',
#   'Days',
#   'on',
#   'Medium'],
#  ['Chess', 'in', 'C++'],
#  ['Latest', 'News', 'From', 'Africa'],
#  ['ENS',
#   '420',
#   'TOP-BLACK',
#   'MULTICOLOR',
#   '[MENS',
#   '420',
#   'TOP]',
#   '-',
#   '$68.99'],
#  ['How', 'To', 'Be', 'Excellent', 'at', 'Something'],
#  ['Purchased',
#   'copies',
#   'of',
#   '"Rock',
#   'Band"',
#   'for',
#   'iPhone',
#   'to',
#   'become',
#   'unplayable'],
#  ['How', 'to', 'secure', 'iPads', 'for', 'corporate', 'use'],
#  ['Steve', 'Jobs', 'Portrait', 'made', 'of', 'Classic', 'Apple', 'Typefaces'],
#  ['Understanding', "SBT's", '(Scala)', 'Incremental', 'Recompilation'],
#  ['Choosing', 'A', 'Wine', 'Cabinet'],
#  ['How', 'can', 'too', 'much', 'information', 'kill', 'creativity?'],
#  ['Nithyananda', 'breaking', 'records', 'on', 'Tweets'],
#  ['How', "Jonathan's", 'Card', 'Really', 'Works'],
#  ['“Delightful”', 'Interaction', 'Design', 'Needs', 'to', 'Die'],
#  ['Show', 'HN:', 'Swing', 'Copters', 'in', 'HTML5'],
#  ['How',
#   'MasterCard',
#   'Helps',
#   'Retailers',
#   'Understand',
#   'Their',
#   'Consumers'],
#  ['Kenny', 'Kellogg:', 'Six', 'Links', 'on', 'Saturday'],
#  ['HD', 'Mars', 'curiosity', 'landing'],
#  ['FTC', 'asked', 'to', 'investigate', 'kids', 'and', 'in-app', 'purchases'],
#  ['Pintar', 'habitacion'],
#  ['Cloud',
#   'Idea',
#   'using',
#   'GridGain',
#   'Get',
#   'VC',
#   'Funded',
#   'in',
#   '90',
#   'Days'],
#  ['How', 'to', 'examine', ':active', 'and', ':hover', 'in', 'Firebug'],
#  ['HelloJS', '–', 'Client-side', 'OAuth', 'for', 'JS'],
#  ['All', 'your', 'tabs', 'accessible', 'everywhere'],
#  ['Top',
#   '25',
#   '+1',
#   'methods',
#   'to',
#   'enhance',
#   'your',
#   'link',
#   'building',
#   'strategy'],
#  ['Android',
#   '4.0',
#   'a.k.a',
#   'Ice',
#   'Cream',
#   'Sandwich',
#   'Update',
#   'Now',
#   'Rolling',
#   'Out'],
#  ['Andr', 'Cassagnes', 'Etch-a-sketch', 'inventor', 'has', 'died'],
#  ['IPhone', 'App', 'Dev', 'with', 'Titanium:', 'Getting', 'Started'],
#  ['Free',
#   'Idea:',
#   'Code',
#   'equivalent',
#   'to',
#   'Morning',
#   'Pages/750',
#   'Words'],
#  ['Overcome',
#   'Your',
#   'Fear',
#   'of',
#   'Marketing',
#   'to',
#   'Get',
#   'What',
#   'You',
#   'Want'],
#  ['Show', 'HN:', 'Git', 'Flow', 'for', 'Selective', 'Feature', 'Deployment'],
#  ['F#', 't-shirt', 'app', 'from', 'Xamarin'],
#  ['How', 'to', 'correct', 'an', 'essay'],
#  ['PAA', 'Lashes', 'Out', 'Against', 'Rogue', 'Cyberlockers'],
#  ['How', 'the', 'Mac', 'no', 'longer', 'matters', 'to', 'Apple'],
#  ['anic', 'digger', 'help'],
#  ['Foursquare.com', '&', 'Scala/Lift', '[slides]'],
#  ['In', 'Browser', '8-bit', 'Paint', 'Tool'],
#  ['35', 'Perfect', 'Examples', 'Of', 'Branding', 'Design'],
#  ['Anna', 'Miminoshvili', 'Fall/Winter', '2012-13', 'Moscow'],
#  ['BitTorrent', 'net', 'meltdown', 'delayed'],
#  ['Apple', 'responds', 'to', 'iPhone', '4', 'reception', 'issues'],
#  ['Parsing', 'the', 'StackOverflow', 'Careers', 'Feed'],
#  ['QONQR', 'Live', 'Zone', 'Statistics'],
#  ['icrosoft',
#   'unveils',
#   'new',
#   'MSN.com',
#   '-',
#   'for',
#   'Windows',
#   '8',
#   'and',
#   'IE10',
#   'only'],
#  ['Embedding', 'an', 'HTTP', 'Web', 'Server', 'in', 'Firefox', 'OS'],
#  ['Compare', 'Missouri', 'Health', 'Insurance'],
#  ['Time-Reversal',
#   'violation',
#   'directly',
#   'observed',
#   'by',
#   'Stanford',
#   'Physicists'],
#  ['IBM',
#   'Leads',
#   'VISION',
#   'Cloud',
#   'Business',
#   'Storage',
#   'Research',
#   '|',
#   'Cloud',
#   'Business',
#   'Review'],
#  ['ESR', 'uses', 'this'],
#  ['Baidu', '1Q', 'jumps', '165', 'percent', 'topping', 'forecasts'],
#  ['Google',
#   'Blog',
#   'Converter',
#   "(Google's",
#   'tool',
#   'to',
#   'move',
#   'blog',
#   'data',
#   'between',
#   'services)'],
#  ['How',
#   'Intellectual',
#   'Property',
#   'Hampers',
#   'Capitalism',
#   '|',
#   'Stephan',
#   'Kinsella'],
#  ['Youtube', 'Music'],
#  ['Oh'],
#  ['We',
#   "didn't",
#   'make',
#   'the',
#   'cut...',
#   'and',
#   "that's",
#   'okay',
#   '|',
#   'Lessfuss'],
#  ['Photos',
#   'To',
#   'Pop',
#   'Art',
#   '|',
#   'Andy',
#   'Warhol',
#   'Pop',
#   'Art',
#   '|',
#   'Pop',
#   'Art',
#   'Lichstyle',
#   '|',
#   'Retro',
#   'Pop',
#   'Art'],
#  ['Ohio',
#   'Art',
#   'Says',
#   'Etch',
#   'A',
#   'Sketch',
#   'Creator',
#   'Dies',
#   'in',
#   'France'],
#  ['The', 'trailer', 'park', 'is', 'the', 'computer'],
#  ['Axent', 'Wear', 'Raises', '$1.77M', 'from', 'Indiegogo', 'Supporters'],
#  ['Getting',
#   'little',
#   'girls',
#   'interested',
#   'in',
#   'science/tech:',
#   'Move',
#   'Over',
#   'Barbie'],
#  ['Glenn', 'Greenwald:', 'Why', 'privacy', 'matters'],
#  ['HTML5',
#   'geolocation',
#   'API',
#   'to',
#   'measure',
#   'speed',
#   'and',
#   'heading',
#   'of',
#   'your',
#   'car'],
#  ['Taws:', 'a', 'personal', 'private', 'search', 'engine'],
#  ['Talent', 'is', 'overrated', '-', 'And', 'what', 'really', 'matters'],
#  ['HostsVault.com', 'shared', 'cheap', 'hosting', 'from', '$4.95'],
#  ['Show', 'HN:', 'free', 'book', 'cover', 'generator'],
#  ['Http://www.Facebook.com/grandmarquishotel'],
#  ['If',
#   'the',
#   'zombie',
#   'apocalypse',
#   'happens',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'this',
#   "guy's",
#   'number'],
#  ['Best', 'Wedding', 'at', 'Vegas', 'Club'],
#  ['British',
#   'Accuse',
#   'David',
#   'Miranda',
#   'Glenn',
#   "Greenwald's",
#   'Partner',
#   'Of',
#   "'Terrorism'"],
#  ['Developing', 'for', 'the', 'browser'],
#  ['Stephen',
#   'Fry',
#   'to',
#   'pimp',
#   'Pushnote',
#   'to',
#   'his',
#   '2m+',
#   'followers',
#   'will',
#   'it',
#   'work?'],
#  ['Host', 'a', 'collaborative', 'blog', 'on', 'GitHub', 'for', 'free'],
#  ['Adjustable', 'Beds', '|', 'Sleep', 'Comfort', 'Adjustable', 'Bed'],
#  ['Julia',
#   'is',
#   'a',
#   'high-level',
#   'high-performance',
#   'dynamic',
#   'programming',
#   'language'],
#  ['Apple', 'Open', 'and', 'Learning', 'From', 'History'],
#  ['acedonian',
#   'officials',
#   'accused',
#   'of',
#   'spying',
#   'on',
#   '20000',
#   'people',
#   'over',
#   'four',
#   'years'],
#  ['Build',
#   'Your',
#   'Own',
#   'Programming',
#   'Language',
#   'with',
#   'JavaScript',
#   '(Slides',
#   '+',
#   'Code)'],
#  ['Kno', 'brings', 'its', 'digital', 'textbooks', 'to', 'K-12', 'education'],
#  ['Bribery',
#   'in',
#   'India:',
#   'A',
#   'website',
#   'for',
#   'whistleblowers',
#   '(ipaidabribe.com)'],
#  ['The', 'Emacs', 'Problem', '(February', '2005)'],
#  ['What',
#   'happened',
#   'while',
#   'contributing',
#   'to',
#   'Open',
#   'Source',
#   'on',
#   'a',
#   'daily',
#   'basis',
#   'for',
#   'one',
#   'year'],
#  ['Method',
#   'and',
#   'system',
#   'for',
#   'shockwave',
#   'attenuation',
#   'via',
#   'electromagnetic',
#   'arc'],
#  ['The', 'MS-DOS', 'Security', 'Model'],
#  ['11', 'Creative', 'Outdoor', 'Advertisement', 'Designs'],
#  ['A',
#   'Russian',
#   "Spy's",
#   'Guide',
#   'To',
#   'Dealing',
#   'With',
#   'Angel',
#   'Investors'],
#  ['SinglePlatform', 'acquired', 'by', 'ConstantContact'],
#  ['How', 'has', 'VC', 'funding', 'changed', 'since', '1995?'],
#  ['Implementing', 'VisiCalc', '(2003)'],
#  ['Baking',
#   'a',
#   'New',
#   'Site',
#   'With',
#   'a',
#   'Sprinkle',
#   'of',
#   'SEO',
#   'Part',
#   '2'],
#  ['Crowd', 'sourcing', 'your', 'BitCoin', 'mining'],
#  ['Could', 'an', 'Android', 'desktop', 'replace', 'your', 'Windows', 'PC?'],
#  ['Livestream',
#   'of',
#   'Aaron',
#   'Swartz',
#   'Public',
#   'Memorial',
#   'Service',
#   'at',
#   'Cooper',
#   'Union'],
#  ['Bitcoinfs:', 'A', 'minimal', 'full', 'Bitcoin', 'node', 'in', 'F#'],
#  ['New',
#   'AdTech',
#   'Goes',
#   'Consumer:',
#   'Emotion',
#   'Tracker',
#   'Affectiva:',
#   '$12M',
#   'From',
#   'KPCB',
#   'Horizon'],
#  ['Oracle', 'Goes', 'for', 'Broke', 'in', 'Court', 'Battle', 'With', 'Google'],
#  ['Graphical', 'muusic'],
#  ['The', 'Vietnam', 'Solution'],
#  ['Insan', 'b', 'kiya', 'shay', 'hai', '-', 'Advice', 'sms'],
#  ['Why', 'submitting', 'site', 'to', 'web', 'directories'],
#  ['Info-Visualization',
#   'Trough',
#   'the',
#   'Eyes',
#   'and',
#   'Talent',
#   'of',
#   '10',
#   'Brazilian',
#   'Designers'],
#  ['The',
#   'best',
#   'kept',
#   'secret',
#   'about',
#   'linear',
#   'and',
#   'logistic',
#   'regression'],
#  ["Square's",
#   'Invisible',
#   'Mobile',
#   'Payment',
#   'Solution:',
#   'Software',
#   'That',
#   'Gives',
#   'You',
#   'Superpowers'],
#  ['Race', 'Condition'],
#  ['The', 'Internet', 'Ruined', 'April', "Fool's", 'Day'],
#  ['LightSquared',
#   'delays',
#   'release',
#   'of',
#   'report',
#   'on',
#   'GPS',
#   'interference'],
#  ['7rf',
#   '(Letter):',
#   'Minimal',
#   'Arabic-language',
#   'writing',
#   'app',
#   '[Arabic]'],
#  ['Combinator',
#   'v1.1',
#   '-',
#   'A',
#   'simple',
#   'Hacker',
#   'News',
#   'client',
#   'for',
#   'Windows',
#   'Phone.'],
#  ['Web', 'Application', 'Development'],
#  ['Online', 'Trading', 'Platform'],
#  ['The', 'Artist', 'Behind', 'the', "'Sexist'", 'Newsweek', 'Cover', 'Speaks'],
#  ['The', 'App', 'Cobbler'],
#  ['Tech', 'Support'],
#  ['You', "Can't", 'Engineer', 'Around', 'Taxes'],
#  ['IBM', 'water', 'cools', '3D', 'chips'],
#  ['Alfresco',
#   'Brings',
#   'Its',
#   'Enterprise-Level',
#   'Content',
#   'Management',
#   'to',
#   'Small',
#   'Businesses'],
#  ['Progress', 'Acquires', 'Telerik', 'for', '$262.5M'],
#  ['Good', 'Quality', 'E-Gadget'],
#  ['How',
#   'can',
#   'a',
#   'garbage',
#   'collector',
#   '"know"',
#   'that',
#   'a',
#   'variable',
#   "isn't",
#   'referenced',
#   'anymore?'],
#  ['Enabling',
#   'the',
#   'real-time',
#   'web',
#   'with',
#   'LiveDirectory.org',
#   '(an',
#   'early',
#   'release)'],
#  ['Venturing', 'beyond', 'Rails:', 'Sinatra'],
#  ['The',
#   'new',
#   'app',
#   "that's",
#   'disrupting',
#   'the',
#   'pony-sharing',
#   'market'],
#  ['Google',
#   'Maps',
#   'easter',
#   'egg:',
#   'the',
#   'TARDIS',
#   'is',
#   'in',
#   'London',
#   '(Street',
#   'View',
#   'old',
#   'Maps',
#   'only)'],
#  ['Strategic', 'Design:', 'Embrace', 'Imperfection', '[video]'],
#  ['Announcing', 'PuppetDB', '1.1:', 'Do', 'More', 'With', 'Your', 'Data'],
#  ['How', 'to', 'run', 'a', '99designs', 'Competition'],
#  ['Central',
#   'Europe',
#   'Backs',
#   'Out',
#   'of',
#   'Copyright',
#   'Deal',
#   'After',
#   'Protests'],
#  ['GitHub', 'needs', 'a', 'kickass', 'designer', 'GitHub', 'Jobs'],
#  ['Any', 'multi-threaded', 'interpreters?'],
#  ['Facebook', 'Midnight', 'Delivery', 'security', 'flaw'],
#  ['The',
#   'Fermi',
#   'Paradox:',
#   'Where',
#   'the',
#   'Hell',
#   'are',
#   'the',
#   'Other',
#   'Earths?'],
#  ['Home', 'Cotton', 'Candy', 'Machine'],
#  ['Nexus', '4', 'Includes', 'Support', 'for', 'LTE', 'on', 'Band', '4'],
#  ['Early', 'History', 'of', 'HTML', '-', '1990', 'to', '1992'],
#  ['Enabling', 'rich(er)', 'interactions', 'in', 'the', 'Clojure', 'REPL'],
#  ['Lea', 'Verou', '|', 'The', 'humble', 'border-radius', '|', 'CSS', 'Day'],
#  ['Show',
#   'HN:',
#   'RhodeCode',
#   'Enterprise',
#   '-',
#   'an',
#   'Open',
#   'Source',
#   'Alternative',
#   'to',
#   'Github',
#   'Enterprise'],
#  ['How',
#   'to',
#   'Pass',
#   'the',
#   'Cloudera',
#   'Hadoop',
#   'Developer',
#   'Exam',
#   'in',
#   'One',
#   'Month'],
#  ['Why',
#   'Apple',
#   'Was',
#   'My',
#   'Company',
#   'of',
#   'The',
#   'Decade',
#   'by',
#   'Om',
#   'Malik',
#   'of',
#   'GigaOM'],
#  ['A', 'Company', 'That', 'Turns', 'Plastic', 'Bottles', 'Into', 'Clothes'],
#  ['Better', 'Place', 'to', 'file', 'for', 'bankruptcy'],
#  ['Htop', '-', 'better', 'top'],
#  ['arket', 'for', 'zero-day', 'vulnerabilities', 'incentivizes', 'sabotage'],
#  ['New',
#   'Orleans',
#   'still',
#   'working',
#   'to',
#   'fix',
#   'real',
#   'estate',
#   'computer',
#   'crash'],
#  ['obile',
#   'Minute',
#   '#105:',
#   'Banner',
#   'ads',
#   'suck',
#   'dont',
#   'let',
#   'them',
#   'stay',
#   'in',
#   'mobile'],
#  ['What', 'is', 'Juglans', 'Regia', 'English', 'Walnut', 'Tree?'],
#  ['Theres',
#   'always',
#   'this',
#   'tendency',
#   'of',
#   'disruption',
#   '|',
#   'Jorge',
#   'Cuadra',
#   'Fueyo'],
#  ['Facebook',
#   'Reports',
#   'Fourth',
#   'Quarter',
#   'and',
#   'Full',
#   'Year',
#   '2012',
#   'Results'],
#  ['Stop', 'Preaching', 'for', 'Financial', 'Independence'],
#  ['Comparing', 'Colour', 'Space', 'Conversion', 'Libraries'],
#  ['Game', 'Theory', 'in', 'The', 'Dark', 'Knight:', 'the', 'opening', 'scene'],
#  ['Http://www.fivefinger-sale.com/'],
#  ['Resourcey', '-', 'Resources', 'for', 'Programmers'],
#  ['Simple',
#   'Haskell',
#   'webapp:',
#   'Generate',
#   'random',
#   'tweets',
#   'using',
#   'Markov',
#   'chains'],
#  ['Clinical', 'trials'],
#  ['State',
#   'of',
#   'the',
#   'arms',
#   'race',
#   'between',
#   'repressive',
#   'govt',
#   'and',
#   'Tor',
#   'technology'],
#  ['Heka', '0.3', 'Released'],
#  ['Hungry', 'Hackers', 'website', 'hacked', 'by', 'CyberMind', '~', 'THN'],
#  ['Square', 'Closes', '$200M', 'Series', 'D'],
#  ['Water-soluble', 'silicon', 'leads', 'to', 'dissolvable', 'electronics'],
#  ['Googles', 'Android', 'Stats:', '850000', 'Activations', 'Per', 'Day'],
#  ['How', 'I', 'Would', 'Try', 'to', 'Hack', 'Your', 'Mint.com', 'Account'],
#  ['Dwolla', 'shuts', 'off', 'transfers', 'to', 'mtgox'],
#  ['DropBox',
#   'Catches',
#   'Pickpockets',
#   'Selfie',
#   'Video',
#   'On',
#   'Stolen',
#   'Mobile',
#   'Phone'],
#  ['Gmail',
#   'Tricks',
#   'And',
#   'Hacks',
#   "You've",
#   'Probably',
#   'Never',
#   'Heard',
#   'Of'],
#  ['A', 'critique', 'of', 'The', 'Black', 'Swan'],
#  ['The',
#   'One',
#   'Feature',
#   'That',
#   'Changed',
#   'Social',
#   'Networking',
#   'Forever'],
#  ['Will', 'OS', 'X', 'Mavericks', 'kill', 'the', 'paid', 'OS', 'model?'],
#  ['Smart', 'TVs', 'are', 'dumb'],
#  ['Write', 'Better', 'with', 'Draft'],
#  ['Dawadi',
#   'Journal:',
#   'Find',
#   'Most',
#   'Retweeted',
#   'or',
#   'Popular',
#   'Tweets'],
#  ['Upcoming',
#   "'Facebook",
#   'at',
#   "Work'",
#   'Service',
#   'Will',
#   'Rival',
#   'LinkedIn'],
#  ['Apple',
#   'vs',
#   'Google',
#   '-',
#   "Who's",
#   'side',
#   'will',
#   'Verizon',
#   'end',
#   'up',
#   'on?'],
#  ['Fossils', 'Suggest', "'Hobbits'", 'Once', 'Walked', 'the', 'Earth'],
#  ['Why', 'Young', 'Engineers', 'Are', 'Missing', 'Out'],
#  ['Farewell', 'Node.js'],
#  ['How', 'to', 'Have', 'a', 'Successful', 'Sales', 'Presentation'],
#  ['Internet',
#   'Archive',
#   'donations',
#   'matched',
#   '3x',
#   'until',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year'],
#  ['BBC', 'Docs:', 'Over', 'the', 'Hill', 'in', 'Silicon', 'Valley', '(.mp3)'],
#  ['UPGRADE', 'Your', 'Health', 'Today'],
#  ['The', 'Obligation', 'to', 'Dissent'],
#  ['Akamai', 'Update:', 'Heartbleed:', 'A', 'History'],
#  ['Dedicating', 'time', 'for', 'creative', 'pursuits'],
#  ['Installing',
#   'Windows',
#   '8',
#   'on',
#   'a',
#   'Netbook',
#   '-',
#   'Does',
#   'it',
#   'Work?'],
#  ['Did', 'Path', 'Cheat', 'Its', 'Way', 'to', 'The', 'Top?'],
#  ['Bing', 'could', 'beat', 'Yahoo', 'by', 'the', 'end', 'of', 'the', 'year'],
#  ['Unemployment', 'of', 'Engineering', 'Graduates:', 'the', 'Key', 'Issues'],
#  ["Valve's",
#   'hierarchy',
#   'has',
#   "'hidden",
#   "management'",
#   'clique',
#   'like',
#   'high',
#   'school'],
#  ['artin',
#   'Fowler',
#   'on',
#   'Schemalessness',
#   'NoSQL',
#   'and',
#   'Software',
#   'Design'],
#  ['Criminal', 'Case', 'Cheats'],
#  ['HTML5', 'MMORPG', 'on', 'Kickstarter'],
#  ['Http://www.addthis.com/bookmark.php'],
#  ['Online',
#   'news',
#   'overtakes',
#   'paper',
#   'and',
#   'nearly',
#   'half',
#   'of',
#   'it',
#   'is',
#   'mobile'],
#  ["'Big",
#   "Bang'",
#   "Isn't",
#   'Porn',
#   'So',
#   'Why',
#   'Is',
#   'China',
#   'Censoring',
#   'Hollywood?'],
#  ['Allow', 'pro', 'users', 'to', 'disable', 'sponsored', 'ads'],
#  ['From', 'comfortable', 'and', 'pleasant', 'winters'],
#  ['The', 'protocols', 'powering', 'the', 'real-time', 'web'],
#  ['Researcher',
#   'snaps',
#   'a',
#   'Zeus',
#   "hacker's",
#   'photo',
#   'through',
#   'his',
#   'webcam'],
#  ['Amazon',
#   'Prime',
#   'tops',
#   '20M',
#   'members',
#   'as',
#   'company',
#   'touts',
#   'its',
#   'best',
#   'holiday',
#   'season',
#   'ever'],
#  ['$50',
#   'Million',
#   'Series',
#   'A',
#   'Investment',
#   'in',
#   'Tenable',
#   'from',
#   'Accel',
#   'Partners'],
#  ['Give',
#   'Your',
#   'iOS',
#   'App',
#   'An',
#   'Unfair',
#   'Advantage',
#   'By',
#   'Adding',
#   'Keywords',
#   'To',
#   'Its',
#   'Title'],
#  ['Attack', 'on', 'sourceforge.net', 'and', 'global', 'password', 'reset'],
#  ['Neckband', 'used', 'in', '"telepathic"', 'chat'],
#  ['Facebok', 'Quietly', 'Offering', 'Conversion', 'Tracking'],
#  ['ongoDB:', 'Building', 'Your', 'First', 'App'],
#  ['Why',
#   'You',
#   'Should',
#   '301',
#   'Redirect',
#   'Your',
#   'PHPLD-powered',
#   'Directory',
#   'Web',
#   'Address'],
#  ['Book', 'Cheap', 'Flights', 'Online', '|', 'Around', 'The', 'Globe'],
#  ['NOVA',
#   'is',
#   'a',
#   'personal',
#   'climbing',
#   'wall',
#   'that',
#   'redefines',
#   'training',
#   'at',
#   'home'],
#  ['Tech', 'Writing', 'Handbook'],
#  ['Top',
#   'in',
#   'thoi',
#   'chp',
#   'hnh',
#   '"nh"nm',
#   '2010',
#   '|',
#   'in',
#   'thoi',
#   '-',
#   'Smartphone'],
#  ['Omaha', '3:', 'Modernizing', 'Automatic', 'Software', 'Updating'],
#  ['How', '3D', 'Printing', 'Could', 'Help', 'Replace', 'Russian', 'Rockets'],
#  ['Pen.io'],
#  ['Feds',
#   'Warrantlessly',
#   'Tracking',
#   'Americans',
#   'Credit',
#   'Cards',
#   'in',
#   'Real',
#   'Time'],
#  ['The', 'mathematics', 'of', 'leaf', 'decay'],
#  ['The', 'past', 'is', 'the', 'future', 'for', 'hi-tech'],
#  ['Getting', 'More', 'From', 'Vim'],
#  ['Ganesh',
#   "Iyer's",
#   'Real-time',
#   'Words',
#   'in',
#   'a',
#   'Word',
#   'game',
#   'with',
#   'Node.js',
#   '&',
#   'Socket.io'],
#  ['Sam', "Altman's", 'CS183B', '–', 'Class', '0'],
#  ['Ivy', '3770', 'Ti', '-', 'Custom', 'Built', 'Gaming', 'PC'],
#  ['Crowdsourcing', 'an', 'Israeli-Palestinian', 'Border'],
#  ['Want',
#   'healthy',
#   'food',
#   'delivered',
#   'to',
#   'your',
#   'office',
#   'fridge?',
#   "It's",
#   'available',
#   'in',
#   'Oakland.'],
#  ['Linux', 'Ice', 'maker', 'and', 'vending', 'machine', 'Cool'],
#  ['App', 'for', 'selling', 'digital', 'products'],
#  ['Why',
#   'I',
#   'stopped',
#   'using',
#   'the',
#   'phrase',
#   'This',
#   'is',
#   'not',
#   'rocket',
#   'science.'],
#  ['How',
#   'to',
#   'Install',
#   'VMware',
#   'Workstation',
#   'on',
#   'Linux',
#   'and',
#   'Create',
#   'Virtual',
#   'Machine'],
#  ['Hibari', 'design', 'philosophy'],
#  ['aking', 'a', 'beautiful', 'modern', 'website', '-', 'Tutorial', 'Series'],
#  ['Copyright', 'Office', 'fails', 'to', 'protect', 'users', 'from', 'DMCA'],
#  ['Can', 'You', 'Get', 'Treatment', 'for', 'Your', 'Internet', 'Addiction?'],
#  ['The',
#   'Worst',
#   'Act',
#   'of',
#   'Terrorism',
#   'in',
#   'San',
#   'Francisco',
#   'History'],
#  ['Less', 'Consumption', 'More', 'Production'],
#  ['Android', 'Ice', 'Cream', 'Sandwich', 'Features'],
#  ['A', 'list', 'of', 'interesting', 'Erlang', 'links'],
#  ['What', 'is', 'our', 'intent?'],
#  ['DIABLO',
#   '3',
#   'FREE',
#   '-',
#   'Must',
#   'be',
#   'at',
#   'least',
#   '13',
#   'yrs',
#   'of',
#   'age.'],
#  ['How',
#   'Aaron',
#   'Brown',
#   'a',
#   'Fake',
#   'Person',
#   'Was',
#   'Created',
#   'for',
#   'Real',
#   'on',
#   'the',
#   'Deep',
#   'Web'],
#  ['IBM', 'Chip', 'Senses', 'Events', 'to', 'React', 'Like', 'Brain'],
#  ['Nanopond:', 'Artificial', 'Life', 'VM'],
#  ['Creating', 'dynamic', 'volumes', 'with', 'loop', 'devices'],
#  ['CloudGrid.js', 'by', 'Pinterest'],
#  ['ongoDB', 'adds', 'atomic', 'find', 'and', 'modify'],
#  ['The',
#   'secret',
#   'to',
#   'online',
#   'safety:',
#   'Lies',
#   'random',
#   'characters',
#   'and',
#   'a',
#   'password',
#   'manager'],
#  ['Hype', 'Up', 'Weekend', '-', 'a', 'vaporware', 'hackathon'],
#  ['ailCore', '2:', 'The', 'next', 'step', 'of', 'libetpan'],
#  ['Facebook',
#   'does',
#   'block',
#   'Spam',
#   'URLs',
#   'but',
#   'there',
#   'method',
#   'is',
#   'Useless',
#   "'cuz..."],
#  ['SEO', 'Uploading', 'Files', 'With', 'Optimized', 'Name'],
#  ['The',
#   'Surprising',
#   'Reason',
#   'Publishers',
#   'Are',
#   'Finally',
#   'Saying',
#   'Yes',
#   'to',
#   'Apple'],
#  ['Check', 'out', 'our', 'neuroscience', 'based', 'music', 'channels'],
#  ['If',
#   'managers',
#   'were',
#   'interviewed',
#   'the',
#   'same',
#   'way',
#   'as',
#   'developers'],
#  ["Apple's",
#   'North',
#   'Carolina',
#   'solar',
#   'fuel',
#   'cell',
#   'plants',
#   'will',
#   'be',
#   'largest',
#   'of',
#   'their',
#   'kind'],
#  ['ACA', 'to', 'adopt', 'IPL', 'way'],
#  ['Why', 'the', 'Internet', 'needs', 'IPv6'],
#  ['Have',
#   'to',
#   'much',
#   'time',
#   'on',
#   'your',
#   'hands',
#   '?',
#   '-',
#   'Digital',
#   'Lego'],
#  ['Zed', 'presents', '"The', 'ACL', 'is', 'Dead"', 'at', 'CUSEC2008'],
#  ['Show',
#   'HN:',
#   'Clickhop.me',
#   'browser',
#   'screen',
#   'sharing',
#   'for',
#   'Chrome'],
#  ['Fanning', 'the', 'Flames', 'of', 'Developer', 'Burnout'],
#  ['Prototyping',
#   'App',
#   'POP',
#   'Joins',
#   'Avos',
#   'The',
#   'Company',
#   'Led',
#   'By',
#   'YouTube',
#   'Founders'],
#  ['Windows',
#   'Phone',
#   '7:',
#   "Don't",
#   'bother',
#   'with',
#   'this',
#   'disaster',
#   '|',
#   'Mobilize',
#   '-',
#   'InfoWorld'],
#  ['t.',
#   'Gox',
#   'Halts',
#   'US',
#   'Dollar',
#   'Withdrawals',
#   'at',
#   'Bitcoin',
#   'Exchange'],
#  ['Tock', '–', 'New', 'Restaurant', 'Ticketing', 'from', 'Alinea'],
#  ['Dropbox', 'moves', 'beyond', 'simple', 'file', 'management'],
#  ['Pine', 'Furniture'],
#  ['This',
#   'Week',
#   'in',
#   'Location',
#   'Based',
#   'Marketing',
#   '-',
#   'Ep',
#   '41:',
#   'Flickr',
#   'GooTip',
#   'Wajam',
#   '&',
#   'Snapette'],
#  ['Stomach', 'lap-bands', 'now', 'for', 'everyone'],
#  ['Keyway:', 'A', 'simple', 'Bash', 'lock', 'file', 'library'],
#  ['How', 'to', 'be', 'a', 'Successful', 'Software', 'Engineer'],
#  ['DRM', 'is', 'about', 'to', 'get', 'even', 'worse', 'with', 'HDCP', '2.2'],
#  ['Scala',
#   'vs.',
#   'Java:',
#   'Just',
#   'as',
#   'fast',
#   'less',
#   'code',
#   'harder',
#   'to',
#   'program',
#   '(regardless',
#   'of',
#   'skill)'],
#  ['The', 'Content', 'Problem', '(and', 'some', 'RSS', 'ideas)'],
#  ['icrosofts',
#   'Digits',
#   'Hand',
#   'Gesture',
#   'Sensor',
#   'Bracelet',
#   'Breaks',
#   'Cover'],
#  ['C10',
#   'Tapping',
#   'North',
#   'Bridge',
#   'to',
#   'Advance',
#   'Stretchable',
#   'Silicon',
#   'Business'],
#  ['Where',
#   'Uniqueness',
#   'Lies:',
#   'the',
#   'key',
#   'in',
#   'our',
#   'brains',
#   'that',
#   'unlocks',
#   'our',
#   'difference'],
#  ['Intel',
#   'Sandy',
#   'Bridge',
#   'CPUs',
#   'and',
#   'motherboards',
#   'spotted',
#   'in',
#   'Malaysia'],
#  ['The', 'Algebra', 'of', 'Data', 'and', 'the', 'Calculus', 'of', 'Mutation'],
#  ['Sony', 'accidentally', 'funded', '“rogue”', 'piracy', 'sites'],
#  ['ChromePHP:', 'Console', 'logging', 'extension', 'for', 'Google', 'Chrome'],
#  ['Q&A', 'with', 'Battery', 'Ventures', 'about', 'HotelTonight', 'Gogobot'],
#  ["Let's",
#   'hope',
#   'the',
#   'Apple',
#   "Store's",
#   'new',
#   'CEO',
#   'forgets',
#   'everything',
#   'he',
#   'knows',
#   'about',
#   'retail.'],
#  ['Download', 'Safari', '4', '-', 'Official', 'Release'],
#  ['These',
#   'tech',
#   'companies',
#   'are',
#   'spending',
#   'millions',
#   'on',
#   'high-priced',
#   'lobbyists'],
#  ['Daily',
#   'satellite',
#   'shots',
#   'of',
#   'the',
#   'polar',
#   'ice',
#   'caps',
#   'since',
#   '1979'],
#  ['Hosting', 'Clojure', 'web', 'apps', 'in', '7', 'easy', 'steps'],
#  ['Tubular', 'cutting', 'technique'],
#  ['Duplicating',
#   'the',
#   'NSA',
#   'spyset/playset',
#   'to',
#   'an',
#   'opensource',
#   'project'],
#  ['Women', 'are', 'bailing', 'out', 'of', 'IT'],
#  ['The', 'Facebook', 'SDK', 'for', 'Parse', 'is', 'Better', 'Than', 'Ever'],
#  ['Switching',
#   'biofuels',
#   'could',
#   'do',
#   'a',
#   'double-whammy',
#   'on',
#   'climate',
#   'change'],
#  ["World's", 'first', 'Bitcoin', 'dedicated', 'miner', 'board', 'claimed'],
#  ['Coldtags',
#   'suite',
#   '-',
#   'the',
#   'largest',
#   'collection',
#   'of',
#   'custom',
#   'JSP',
#   'tags'],
#  ['Google',
#   'Is',
#   'Said',
#   'to',
#   'Be',
#   'Acquiring',
#   'Waze',
#   'for',
#   '$1.1',
#   'Billion'],
#  ['The', 'Lucrative', 'Linux', 'Job', 'Offer', 'I', 'Turned', 'Down'],
#  ['RSA',
#   'factors',
#   'based',
#   'on',
#   'transmission',
#   'and',
#   'reflection',
#   'coefficient'],
#  ['FastClick',
#   '-',
#   'Polyfill',
#   'to',
#   'remove',
#   'click',
#   'delays',
#   'on',
#   'browsers',
#   'with',
#   'touch',
#   'UIs'],
#  ['Deadmou5', 'Twitter', 'hacked'],
#  ['[Ask',
#   'HN]:',
#   'Any',
#   'feedback',
#   'on',
#   'the',
#   'first',
#   'alpha',
#   'build',
#   'of',
#   'my',
#   'game?'],
#  ['Faust', 'and', 'the', 'Physicists'],
#  ['BNFC:', 'language-agnostic', 'parser', 'generator', 'generator'],
#  ['CoderTalk',
#   '-',
#   'Episode',
#   '4.',
#   'work',
#   '/',
#   'life',
#   'balance',
#   'coding',
#   'with',
#   'kids',
#   'etc'],
#  ['Consumer', 'Technology', 'Trends', 'For', '2014'],
#  ['HackerChat.co',
#   '–',
#   'A',
#   'private',
#   'Slack',
#   'chat',
#   'for',
#   'the',
#   'HN',
#   'community'],
#  ['Wordpress',
#   'explains',
#   '110',
#   'minutes',
#   'of',
#   'downtime',
#   'for',
#   '10.2',
#   'millions',
#   'blogs'],
#  ['The', 'Most', 'Expensive', 'One-byte', 'Mistake', '(2011)'],
#  ['"The', 'Internet', 'Is', 'My', 'Religion"'],
#  ['Http://www.bijuterii-arta.com/blog/bijuterii-timisoara-handmade'],
#  ['How',
#   'to',
#   'build',
#   'a',
#   'Hadoop',
#   'VM',
#   'with',
#   'Ambari',
#   'and',
#   'Vagrant'],
#  ['10', 'Free', 'And', 'Amazing', 'Linux', 'Apps', 'For', 'Programmers'],
#  ['Steve',
#   'Krug',
#   '(author',
#   'of',
#   "Don't",
#   'Make',
#   'Me',
#   'Think)',
#   'has',
#   'a',
#   'new',
#   'book',
#   'on',
#   'usability',
#   'testing'],
#  ["WhatsApp's",
#   'Journey',
#   'From',
#   'Being',
#   'Ignored',
#   'To',
#   'a',
#   '$19',
#   'Billion',
#   'Exit'],
#  ['PullClean', 'Sanitizing', 'Door', 'Handle'],
#  ['A', 'brainf*ck', 'monad'],
#  ["'Even",
#   'worse',
#   'than',
#   "Foxconn':",
#   'Apple',
#   'rocked',
#   'by',
#   'child',
#   'labour',
#   'claims'],
#  ['The', 'Valley', 'Needs', 'A', 'Valleywag', 'Or', 'Something', '(February)'],
#  ['Against', 'Acceleration'],
#  ['Snow',
#   'and',
#   'Tell:',
#   'Snow',
#   'Informing',
#   'How',
#   'We',
#   'Use',
#   'Public',
#   'Space'],
#  ['To', 'Learn', 'Quick', 'Photoshop', 'Use', 'These', 'Tutorials'],
#  ['Hack',
#   'Battle',
#   'at',
#   "'The",
#   'Hacker',
#   'Conference',
#   "2013'",
#   'with',
#   'CTF365',
#   '-',
#   'The',
#   'Hacker',
#   'News'],
#  ['1%',
#   'of',
#   'CMS-Powered',
#   'Sites',
#   'Expose',
#   'Their',
#   'Database',
#   'Passwords',
#   '(2011)'],
#  ['Surface',
#   'Pro',
#   '3',
#   'Can',
#   'Do',
#   'It',
#   'All',
#   '–',
#   'Maybe',
#   'Even',
#   'Lift',
#   'the',
#   'Windows',
#   '8',
#   'Curse'],
#  ['Everything', 'you', 'need', 'to', 'benefit', 'from', 'Big', 'Data'],
#  ['icrosoft',
#   'Has',
#   'Over',
#   '1',
#   'Million',
#   'Servers',
#   '-',
#   'What',
#   'Does',
#   'That',
#   'Really',
#   'Mean?'],
#  ['Show',
#   'HN:',
#   'Weekend',
#   'Project',
#   '-',
#   'Keep',
#   'Calm',
#   'And',
#   'Read',
#   'Hacker',
#   'News'],
#  ['Lessons', 'Learned', 'from', 'the', 'Launch', 'of', 'Word', 'Lens'],
#  ['A',
#   'review',
#   'of',
#   'the',
#   'Blackphone',
#   'the',
#   'Android',
#   'for',
#   'the',
#   'paranoid'],
#  ['Random',
#   'thoughts',
#   'on',
#   'the',
#   'substring',
#   'procedure',
#   '(on',
#   'strict',
#   'vs',
#   'lax/fuzzy',
#   'APIs',
#   '&',
#   'magic)'],
#  ['otorola',
#   'Mobility',
#   'Launched',
#   'Motorola',
#   'Defy',
#   'MINI',
#   'XT320',
#   'in',
#   'China'],
#  ['The', 'Social', 'Organization', 'of', 'the', 'Computer', 'Underground'],
#  ['Note',
#   'to',
#   'Facebook',
#   'Shareholders:',
#   'What',
#   'to',
#   'Do',
#   'After',
#   'You',
#   'Make',
#   'a',
#   'Zillion',
#   'Dollars'],
#  ['Leverage', 'Points:', 'Places', 'to', 'Intervene', 'in', 'a', 'System'],
#  ['On', 'Finding', 'Mentors', 'Through', 'Issuing', 'Challenges'],
#  ['Prototype',
#   'of',
#   'collaborative',
#   'editing',
#   'in',
#   'KDE',
#   'Text',
#   'Editor',
#   'component'],
#  ['Node.js', 'Data-Intensive', 'Real-Time', 'Applications'],
#  ["EFF's", 'mass', 'copyright', 'litigation', 'roundup'],
#  ['otorcycle', 'accident', 'attorney', 'Lexington'],
#  ['How',
#   'Whereoscope',
#   '(YC',
#   'S10)',
#   'located',
#   'a',
#   'market',
#   'for',
#   'its',
#   'family-finder',
#   'app'],
#  ['Churn',
#   'Walkthrough',
#   'Part',
#   'I:',
#   'Defining',
#   'Active',
#   'And',
#   'Lost',
#   'Customer'],
#  ['Deploy', 'PHP', 'to', 'Heroku'],
#  ['Can',
#   "America's",
#   'Desert',
#   'Cities',
#   'Adapt',
#   'Before',
#   'They',
#   'Dry',
#   'Out',
#   'and',
#   'Die?'],
#  ['ErgoEmacs', '-', 'Ergonomically', 'modernized', 'Emacs'],
#  ['What', 'Do', 'HSBC', 'and', 'Anthem', 'Have', 'in', 'Common?'],
#  ['The', 'simple', 'blog', 'engine', '-', 'Substance'],
#  ['Aeron:', 'Another', 'messaging', 'system'],
#  ['Privy', 'purse', 'in', 'India'],
#  ['Come',
#   'on',
#   'google',
#   'need',
#   'this',
#   'site',
#   'up',
#   'and',
#   'seoed',
#   'again'],
#  ['Nvidia',
#   'Network',
#   'Breached',
#   '500+',
#   'Staff',
#   'Urged',
#   'to',
#   'change',
#   'account',
#   'details'],
#  [],
#  ['Dawn', 'Mission'],
#  ['In',
#   'social',
#   'bees',
#   'and',
#   'loners',
#   'a',
#   'hunt',
#   'for',
#   'the',
#   'genes',
#   'behind',
#   'social',
#   'behavior'],
#  ['Facial',
#   'recognition',
#   'being',
#   'rolled',
#   'out',
#   'to',
#   'boost',
#   'sales',
#   'at',
#   'retailers'],
#  ['Criminals', 'Pay', 'Top', 'Money', 'for', 'Hackable', 'Nokia', 'Phone'],
#  ['Elasticsearch',
#   'for',
#   'Beginners:',
#   'Index',
#   'and',
#   'Search',
#   'Hacker',
#   'News'],
#  ['Battle',
#   'In',
#   'The',
#   'Boardroom:',
#   'Why',
#   'Groupon',
#   'Probably',
#   'Paid',
#   'Off',
#   'Its',
#   'Early',
#   'Employees'],
#  ['Learn',
#   'Python',
#   'the',
#   'Hard',
#   'Way:',
#   'P2PU',
#   'School',
#   'of',
#   'Webcraft'],
#  ['Facebook', 'brute-forcing', 'hidden', 'services'],
#  ["Don't", 'Ever', 'Use', 'This', 'Word', 'With', 'Developers'],
#  ['The',
#   "year's",
#   'top',
#   'politicians',
#   'and',
#   'their',
#   'best',
#   'deletions',
#   'from',
#   'Twitter'],
#  ['RIM', 'just', "doesn't", 'understand', "it's", 'developers'],
#  ['Documenting',
#   'and',
#   'Assessing',
#   'an',
#   'Ad',
#   'Experiment',
#   'across',
#   'Search',
#   'and',
#   'Social'],
#  ['PHP', 'meet', 'elegance.', 'Laravel', '3', 'has', 'arrived.'],
#  ['6', 'Most', 'Irresistible', 'Business', 'Boards', 'You', 'Must', 'Follow'],
#  ['HP:', '‘We', 'are', 'not', 'walking', 'away', 'from', 'webOS’'],
#  ['A',
#   'Lecture',
#   'on',
#   'Johnson',
#   'and',
#   'Boswell',
#   'by',
#   'Jorge',
#   'Luis',
#   'Borges'],
#  ['Paul', 'Graham', 'Just', 'Shut', 'Your', 'Face', 'Already'],
#  ['Flummoxed', 'by', 'Failureor', 'Focused?'],
#  ['Two',
#   'Guys',
#   'on',
#   'Mobile',
#   '-',
#   'Episode',
#   '27:',
#   "Amazon's",
#   'Fire',
#   'and',
#   'Silk',
#   '+',
#   "GigaOm's",
#   'Mobilize'],
#  ['Gore',
#   'Video:',
#   'Brutal',
#   'Truck',
#   'Accident',
#   '-',
#   'Dying',
#   'Man',
#   'Bathed',
#   'in',
#   'Blood',
#   'With',
#   'Severed',
#   'Limbs'],
#  ['Hotel',
#   'ousts',
#   'couple',
#   'after',
#   'accusing',
#   'them',
#   'of',
#   'writing',
#   'negative',
#   'TripAdvisor',
#   'review'],
#  ['Delta', 'Debugging'],
#  ['icrosoft', 'Apple', 'Google', 'sued', 'over', 'icon', 'software', 'patent'],
#  ['3',
#   'Steps',
#   'to',
#   'Optimize',
#   'Your',
#   'Website',
#   'For',
#   "Google's",
#   "'Freshness'",
#   'Update'],
#  ['Whats', 'on', 'my', 'Nexus', '5'],
#  ['Find', 'Laundromat', 'phoenix'],
# ...
#  ['Science',
#   'never',
#   'fails:',
#   'The',
#   'Journal',
#   'of',
#   'Unsolved',
#   'Questions'],
#  ['Localtunnel', 'v2', 'available', 'in', 'beta'],
#  ['Understand',
#   'the',
#   'intricacies',
#   'of',
#   'cloud',
#   'benefits',
#   'and',
#   'cloud',
#   'computing',
#   'disadvantages'],
#  ['Why', 'Are', 'We', 'Better', 'Than', 'Google'],
#  ['Company', 'Demos', 'Personal', 'Aircraft', 'Future', 'Jetpack'],
#  ['Poisson', 'Image', 'Editing', 'in', 'Python'],
#  ['ac',
#   'Users',
#   'Can',
#   'Now',
#   'Enjoy',
#   'Bookmark',
#   'Sync',
#   'Extensions',
#   'in',
#   'Chrome'],
#  ['Bankruptcy',
#   'Auctions',
#   'Go',
#   'Online',
#   'to',
#   'Boost',
#   'Cash',
#   'for',
#   'Creditors'],
#  ['Cool', 'silicone', 'snowboard', 'cover'],
#  ['Alibaba', 'Turns', 'To', 'Travel', 'As', 'Profit', 'Zooms'],
#  ['Creative', 'Market', 'is', 'open', 'for', 'business'],
#  ['$MSFT',
#   'at',
#   '14-year',
#   'high',
#   'heading',
#   'into',
#   'the',
#   'Apple',
#   'announcement'],
#  ['3',
#   'steps',
#   'to',
#   'writing',
#   'an',
#   'open',
#   'source',
#   'project',
#   'case',
#   'study'],
#  ['Steve', 'Jobs', 'Probably', "Won't", 'Come', 'Back', 'to', 'Apple'],
#  ['Tokyo', 'trials', 'digital', 'billboards', 'that', 'scan', 'passers-by'],
#  ['ITunes', 'Concept'],
#  ['The', 'Truth', 'about', 'Terms', 'and', 'Conditions'],
#  ['Featured', 'class:', 'Introduction', 'to', 'C++'],
#  ['Facebook',
#   'Fixed',
#   'Data',
#   'Table:',
#   'A',
#   'React',
#   'component',
#   'for',
#   'building',
#   'and',
#   'presenting',
#   'data'],
#  ['Fully', 'Loaded', 'Node'],
#  ['14',
#   'years',
#   'ago:',
#   'the',
#   'day',
#   'Teller',
#   'gave',
#   'me',
#   'the',
#   'secret',
#   'to',
#   'my',
#   'career',
#   'in',
#   'magic.'],
#  ['ore', 'than', '200', 'kids', 'virtual', 'worlds', 'in', 'development'],
#  ['4', 'Ways', 'to', 'Brainstorm', 'Like', 'A', 'Pro'],
#  ['Pete', 'Townshend', 'calls', 'Apple', "'a", "vampire'"],
#  ['edical', 'billing', 'software'],
#  ['Show', 'HN:', 'Urgent', 'care', 'in', 'your', 'home'],
#  ['Oxford',
#   'Graduate',
#   'Application',
#   '2012/13',
#   '|',
#   'Ebook',
#   'and',
#   'PDF',
#   'Search',
#   'Engine'],
#  ['Why', 'you', "shouldn't", 'read', 'Gizmodo'],
#  ['Pets', 'as', 'Wizards'],
#  ["WikiLeaks'", 'Julian', 'Assange', 'to', 'leave', 'embassy', "'soon'"],
#  ['We', 'are', 'the', 'worst', 'registrar', 'in', 'the', 'world'],
#  ['Show', 'HN:', 'Kinect', 'Home', 'Automation', 'goes', 'HTML5'],
#  ['Our',
#   'product',
#   'helped',
#   'build',
#   'software',
#   'for',
#   'the',
#   'Curiosity',
#   'mission'],
#  ['IPad', 'Sales', 'Outpace', 'Every', 'Prediction'],
#  ['A16Z', 'Invests', 'in', 'Stack', 'Exchange'],
#  ['Live', 'Character', 'Count', 'Meter', 'with', 'Jquery.'],
#  ['Learning', 'R', 'interactively', 'with', 'the', 'Swirl', 'package'],
#  ['Leadership',
#   'skills',
#   'come',
#   'from',
#   'expert',
#   'knowledge',
#   'not',
#   'interpersonal',
#   'skills'],
#  ['Get',
#   '10%',
#   'OFF',
#   'IntelliJ',
#   'IDEA',
#   'Personal',
#   'License',
#   'until',
#   'end',
#   'of',
#   'August'],
#  ['Facebook',
#   'Open',
#   'Sources',
#   'flint',
#   'a',
#   'C++',
#   'linter',
#   'written',
#   'in',
#   'D'],
#  ['Laser', 'Marking', 'Machine'],
#  ['Large', 'Hadron', 'Collider', 'as', 'Massive', 'Grid', 'Computer'],
#  ['Watchzindagi', 'na', 'milegi', 'dobaronline', 'freemegavideo'],
#  ['How', 'the', 'Box', '2D', 'hero', 'caught', 'Rovio', 'out'],
#  ['How', 'Plague', 'Inc.', 'Became', '#1', 'in', 'App', 'Store'],
#  ['Artificial',
#   'Sweeteners',
#   'May',
#   'Change',
#   'Our',
#   'Gut',
#   'Bacteria',
#   'in',
#   'Dangerous',
#   'Ways'],
#  ['Finding', 'a', "Graph's", 'Radius', 'with', 'an', 'FPGA'],
#  ['The', 'Bacon', 'Boom', 'Was', 'Not', 'an', 'Accident'],
#  ['ozilla', 'Chromeless', '0.2'],
#  ['Lawyer',
#   'fears',
#   'Assange',
#   'could',
#   'face',
#   'death',
#   'penalty',
#   'in',
#   'US'],
#  ['Complexity',
#   'science',
#   'Python',
#   'programming',
#   'and',
#   'the',
#   'philosophy',
#   'of',
#   'science'],
#  ['Data', 'Visualization', 'CourseWiki', 'CS', '448B'],
#  ['CommitStrip',
#   'the',
#   'blog',
#   'relating',
#   'the',
#   'daily',
#   'life',
#   'of',
#   'web',
#   'agencies',
#   'developers'],
#  ['LizardSquad’s',
#   'DDoS',
#   'tool',
#   'falls',
#   'prey',
#   'to',
#   'hack',
#   'exposes',
#   'complete',
#   'customer',
#   'database'],
#  ['Jimmy',
#   "Wales'",
#   '"Appeal"',
#   'results',
#   'in',
#   '15x',
#   'more',
#   'donation',
#   'dollars'],
#  ['SXSW', 'Trade', 'Show', 'displays', 'latest', 'technologies'],
#  ['The', 'Dangers', 'of', 'Certainty:', 'A', 'Lesson', 'From', 'Auschwitz'],
#  ['Lean', 'tools'],
#  ['Characteristics', 'of', 'Machine', 'Learning', 'Model'],
#  ['CBBC',
#   'Newsround',
#   '-',
#   'Boy',
#   'sends',
#   'robot',
#   'to',
#   'school',
#   'in',
#   'his',
#   'place'],
#  ['Ruby', 'Fibonacci', 'Shootout', 'Part', '2', '(MacRuby', 'vs', 'LuaJIT)'],
#  ['Google', 'lifts', 'malware', 'warning', 'for', 'isocket', 'ad', 'network'],
#  ['Translation', 'of', "Snowden's", 'latest', 'letter.'],
#  ['Interview',
#   'with',
#   'RingCentral:',
#   'how',
#   'to',
#   'appear',
#   'like',
#   'a',
#   'huge',
#   'company',
#   'even',
#   'if',
#   "you're",
#   'just',
#   'one',
#   'guy'],
#  ['Enrich',
#   'your',
#   'updates',
#   'on',
#   'LinkedIn',
#   'with',
#   'Rich',
#   'Media',
#   '[SLIDESHOW]'],
#  ["SpaceShipTwo's", 'First', '"Feathered"', 'Flight'],
#  ['Super', 'Efficient', 'Super', 'Tiny', '"Pico', 'Projectors"'],
#  ['Lessons',
#   'learned',
#   'from',
#   'growing',
#   'LinkedIn',
#   'to',
#   '175',
#   'million',
#   'users'],
#  ['Info', 'on', 'Colocation', 'Server', 'and', 'Colocation', 'Hosting'],
#  ['Giuliano', 'Fujiwara', 'Women', 'Fall/Winter', '2011-12', 'Tokyo'],
#  ['Jiro',
#   'Ono',
#   'and',
#   'René',
#   'Redzepi',
#   'Have',
#   'a',
#   'Cup',
#   'of',
#   'Tea',
#   '[video])'],
#  ['AP', 'Fearful', 'Russian', 'lawmaker', 'flees', 'to', 'US'],
#  ['Weaving', 'Peace', 'for', 'Mindanao'],
#  ['To', 'tool', 'or', 'not', 'to', 'tool?'],
#  ['David',
#   'Foster',
#   'Wallace',
#   'Postmodern',
#   'Writer',
#   'Is',
#   'Found',
#   'Dead',
#   'at',
#   'Home'],
#  ['Emacs', 'now', 'has', 'multi-tty', 'in', 'CVS', 'HEAD'],
#  ['YouTube',
#   '-',
#   'Horrific',
#   'Dust',
#   'Storm',
#   'of',
#   'Decade',
#   'Spikes',
#   'Valley',
#   'Fever',
#   'AZ',
#   '(Raw',
#   'Video)'],
#  ['ark', "Cuban's", 'Amazon', 'Book', 'Recommendations'],
#  ['A',
#   'Cocoa',
#   'library',
#   'to',
#   'extend',
#   'the',
#   'Objective-C',
#   'programming',
#   'language'],
#  ['Nexus', 'One--Verizon', 'support', 'coming'],
#  ['Beano', 'Brand', 'Guidelines', 'Designed', 'by', 'Wayne', 'Hemingway'],
#  ['Google', 'Diversity', 'Statistics'],
#  ['Google', 'Cardboard', '–', 'Inexpensive', 'VR', 'Headset'],
#  ['Will',
#   "YouTube's",
#   'comment',
#   'jerks',
#   'willingly',
#   'out',
#   'themselves?',
#   'Not',
#   'bloody',
#   'likely'],
#  ['3', 'Resources', 'for', 'Web', 'Designers'],
#  ['Banning', 'the', 'word', "'difficult'"],
#  ['Siblyback', 'Lake', 'Walking', 'Route'],
#  ['IMF', 'cuts', 'U.S.', 'growth', 'forecast', 'warns', 'of', 'crisis'],
#  ['The', 'mirror', 'man'],
#  ['Warren',
#   'Spector',
#   'wants',
#   'game',
#   'designers',
#   'to',
#   'work',
#   'on',
#   'non-combat',
#   'A.I.'],
#  ['U.S.', 'Marine', 'Arrested', 'for', 'Facebook', 'Posts'],
#  ['How', 'I', 'started', 'BetaList'],
#  ['House', 'Of', 'Anubis', 'Season', '2'],
#  ['How', 'to', 'switch', 'to', 'a', 'new', 'IDE', 'in', 'an', 'afternoon'],
#  ['Open',
#   'Corp',
#   'Dev:',
#   'An',
#   'Idea',
#   'Too',
#   'Bold',
#   'For',
#   'Facebook',
#   'Or',
#   'Dropbox'],
#  ['Paginator',
#   ':',
#   'A',
#   'simple',
#   'and',
#   'easy',
#   'PHP',
#   'class',
#   'that',
#   'allows',
#   'you',
#   'to',
#   'create',
#   'pagination.'],
#  ['Checkout', 'Luxolasg', 'profile', 'on', 'DiscoverMatch.'],
#  ['Learning', 'to', 'Love', 'JavaScript'],
#  ['Using', 'Agile', 'Techniques', 'to', 'Pay', 'Back', 'Technical', 'Debt'],
#  ['Doomsday', 'Clock', '-', 'one', 'minutes', 'presented'],
#  ['Show',
#   'HN:',
#   'Testing',
#   'a',
#   'Spring',
#   '4',
#   'REST',
#   'Backend',
#   'using',
#   'Java',
#   '8',
#   'Lambdas'],
#  ['[video]',
#   'How',
#   'to',
#   'get',
#   'started',
#   'in',
#   'the',
#   'Rails',
#   'community',
#   '(no',
#   'blogspam)'],
#  ['Hackers',
#   'Can',
#   'Kill',
#   'Diabetics',
#   'w/',
#   'Insulin',
#   'Pumps?',
#   'Facts',
#   'vs.',
#   'Fear',
#   'Mongering'],
#  ['Beautiful',
#   'Natural',
#   'Amazing',
#   'Bridge',
#   'Wallpapers',
#   'desktop',
#   'background'],
#  ['Crafting', 'a', 'Pricing', 'Plan', 'to', 'Maximize', 'Freemium', 'Growth'],
#  ['What',
#   'I',
#   'saw',
#   'in',
#   'consumer',
#   'startups',
#   'after',
#   'I',
#   'left',
#   'Silicon',
#   'Valley'],
#  ['Keplers', 'snowflake'],
#  ['Chiropractors', 'Email', 'Lists', 'and', 'Mailing', 'Lists.'],
#  ['An', 'Inkling', '(how', 'to', 'learn', 'a', 'new', 'language', 'properly)'],
#  ['Video', '–', 'Optimization', 'in', 'Julia'],
#  ['Women',
#   'Hackers',
#   '-',
#   'the',
#   'mission',
#   'to',
#   'locate',
#   'subversive',
#   'women',
#   'on',
#   'the',
#   'net',
#   "('99)"],
#  ['The', 'importance', 'of', 'Trust', 'in', 'teams.'],
#  ['Acer:', 'Critics', 'Unfair', 'to', 'Windows', '8'],
#  ['Phreaking', 'Out', 'Ma', 'Bell'],
#  ['Pygram', '-', 'Open', 'Source', 'Grammar', 'Analyzer'],
#  ['Facebook', 'feels', 'unfriendly', 'toward', 'movie', 'it', 'inspired'],
#  ['Searching', 'Questions:', 'how', 'good', 'is', 'Google?'],
#  ['Dui', 'attorney', 'Jacksonville', '|', 'lawyer', 'Jacksonville'],
#  ['Demistifying', 'Lazy', 'Load', 'Pattern'],
#  ['Show', 'HN:', 'Keep', 'your', 'customers', 'informed', 'and', 'aware'],
#  ['Richard',
#   'Muller:',
#   'The',
#   'Case',
#   'Against',
#   'Global-Warming',
#   'Skepticism'],
#  ['Do', 'You', 'Want', 'Fries', 'With', 'That?'],
#  ['Twitter.com', 'down?'],
#  ['Crash',
#   'Could',
#   'Free',
#   'Up',
#   'Wall',
#   "Street's",
#   'Grip',
#   'on',
#   'Bright',
#   'Young',
#   'Minds'],
#  ['Why', 'companies', 'need', 'to', 'experiment', 'more'],
#  ['A', 'History', 'Of', 'Graphic', 'Design'],
#  ['Fashionable', 'clothsummer', 'fashionbelts'],
#  ['We',
#   'were',
#   'tired',
#   'of',
#   'telling',
#   'people',
#   'what',
#   'gadget',
#   'to',
#   'buy',
#   'so',
#   'we',
#   'did',
#   'something',
#   'about',
#   'it'],
#  ['US',
#   "'federal",
#   'government',
#   "2.0'",
#   'ditches',
#   'BlackBerry',
#   'embraces',
#   'Apple'],
#  ['The',
#   'lesson',
#   'from',
#   'Better',
#   'Places',
#   'bankruptcy:',
#   'Be',
#   'more',
#   'like',
#   'Tesla'],
#  ['Netflix',
#   'To',
#   'Make',
#   'Own',
#   'Horror',
#   'Show',
#   '--',
#   'and',
#   'Pick',
#   'Up',
#   'Terra',
#   'Nova',
#   'The',
#   'River?'],
#  ['Code', 'iOS', 'Apps', 'in', 'OCaml'],
#  ['Hackable', 'measurement', 'board', 'runs', 'Linux', 'on', 'ARM+FPGA'],
#  ['Amazon-Apple', 'App', 'Store', 'Law', 'Suit', 'Update'],
#  ['Cydia', '2.0', 'vs', 'Installer', '4.0'],
#  ['any', 'Teens', 'Send', '100+', 'Texts', 'A', 'Day'],
#  ['Windows', 'Server', '8', 'Beta', 'Released', 'Download', 'Now'],
#  ['First',
#   'ever',
#   'photograph',
#   'of',
#   'light',
#   'as',
#   'a',
#   'particle',
#   'and',
#   'a',
#   'wave'],
#  ['Orient', 'Mako'],
#  ['Ratings', 'Prompts', "Don't", 'Have', 'To', 'Suck'],
#  ['Android', 'challenges', 'the', 'iPhone', 'in', 'every', 'category'],
#  ['Scam', 'Alert', '--', 'Fake', 'US', 'Telecom'],
#  ['Apple',
#   'iPad',
#   'Mini',
#   'Announced',
#   '-',
#   'Release',
#   'date',
#   'is',
#   'Nov',
#   '2nd',
#   'at',
#   '$329'],
#  ["Google's",
#   '"iLost"',
#   'Motorola',
#   'ad',
#   'faked',
#   'an',
#   'address',
#   'to',
#   '"lose"',
#   'iOS',
#   '6',
#   'Maps'],
#  ['How', 'I', 'started', 'programming', 'it', 'was', 'quite', 'a', 'ride'],
#  ['Emmanuel', "Derman's", 'Battle', 'with', '"The', 'Maladroid"', '(Android)'],
#  ['Reimagining',
#   'Not',
#   'Reinventing',
#   'Food',
#   'Distribution',
#   '–',
#   'Food',
#   'and',
#   'Tech',
#   'Connect'],
#  ['The', 'History', 'of', 'Online', 'Advertising'],
#  ['Compiling',
#   'LLJS',
#   'to',
#   'asm.js',
#   'gives',
#   'near',
#   'C',
#   'speed',
#   'w.',
#   'JS',
#   'subset',
#   'using',
#   'typed',
#   'arrays'],
#  ['TV', 'Relieves', 'Loneliness'],
#  ['Does', 'Hydraulic', 'Fracturing', 'Trigger', 'Earthquakes'],
#  ['GM', 'mosquitoes', 'show', 'dengue', 'fever', 'promise'],
#  ['Ask',
#   'HN:',
#   'Feedback',
#   'on',
#   'my',
#   'JavaScript',
#   'library?',
#   'Suggestions',
#   'for',
#   'improvements?'],
#  ['Ask',
#   'HN:',
#   'Re-architecting',
#   'on',
#   'Slicehost',
#   'to',
#   'handle',
#   '50+',
#   'apache',
#   'processes?'],
#  ['BuddyPress', 'Themes', 'That', 'Really', 'Worth', 'Your', 'Attention'],
#  ['Air', 'Hockey', 'Robot', 'Project', '(a', '3D', 'printer', 'hack)'],
#  ['Facebook',
#   'Makes',
#   'A',
#   'Huge',
#   'Data',
#   'Grab',
#   'By',
#   'Aggressively',
#   'Promoting',
#   'Photo',
#   'Sync'],
#  ['Encrypt', 'and', 'Share', 'your', 'messages'],
#  ['C++11',
#   'Tutorial:',
#   'Explaining',
#   'the',
#   'Ever-Elusive',
#   'Lvalues',
#   'and',
#   'Rvalues'],
#  ['Gmail', 'gets', 'nested', 'labels', 'and', 'message', 'sneak', 'peeks'],
#  ['Iran', 'must', 'halt', 'execution', 'of', 'web', 'programmer'],
#  ['Want', 'to', 'work', 'at', 'Reddit?'],
#  ['Kenneth',
#   'Cukier',
#   'speaks',
#   'about',
#   'big',
#   'data',
#   'at',
#   'TNW',
#   'Conference',
#   'Europe',
#   '2013'],
#  ['Harvard',
#   'Business',
#   'School',
#   'Faculty',
#   'Comment',
#   'on',
#   'Crisis',
#   'in',
#   'Japan'],
#  ['Against',
#   'The',
#   'Use',
#   'Of',
#   'Programming',
#   'Languages',
#   'in',
#   'Configuration',
#   'Files'],
#  ['Salesforce.com',
#   'CEO:',
#   'Sorry',
#   'virtualization',
#   "isn't",
#   'cloud',
#   'computing'],
#  ['obile', 'Marketing', 'Trends'],
#  ['Saudi', 'blogger', 'Badawi', 'again', 'avoids', 'flogging:', 'Amnesty'],
#  ['Apple', 'Design', 'Awards', '2014'],
#  ['The', '"Easy', 'Installer"', 'from', 'Joomlatag'],
#  ['Wheels',
#   'of',
#   'Steel;',
#   'Epic',
#   'demo',
#   'of',
#   'rich',
#   'Web',
#   'turn',
#   'table'],
#  ['Helped',
#   'wanted',
#   ':',
#   'Ottawa',
#   'Linux',
#   'SymposiumIndiegogo',
#   'Campaign'],
#  ['Pressflip', 'Is', 'A', 'Belly', 'Flop'],
#  ['Kozmo.com', 'is', 'back', 'from', 'the', 'dead'],
#  ['Galaxy’s',
#   'guardians',
#   'make',
#   'the',
#   'case:',
#   'upgrade',
#   'Pluto',
#   'back',
#   'to',
#   'planet-size'],
#  ['Hacking', 'group', 'wants', 'to', 'play', 'nice', 'with', 'automakers'],
#  ['Why', 'Office', 'Distractions', "Don't", 'Matter.'],
#  ['The', 'best', 'iPhone', 'apps', 'for', 'business'],
#  ['Restore', 'potency', 'and', 'cure', 'ED'],
#  ['Interview', 'with', 'Matt', 'Graham', 'Designer', 'at', 'GitHub'],
#  ['6',
#   'Things',
#   'You',
#   'Should',
#   'Never',
#   'Say',
#   'to',
#   'a',
#   'Software',
#   'Tester'],
#  ['Chicago',
#   'Is',
#   'Beating',
#   'Silicon',
#   'Valley',
#   'At',
#   'The',
#   'Patent',
#   'Game'],
#  ['4.7',
#   'Million',
#   'New',
#   'Places',
#   'to',
#   'Charge',
#   'an',
#   'Electric',
#   'Car',
#   'by',
#   '2015',
#   'Analysts',
#   'Say'],
#  ['Building', 'design', 'plans'],
#  ['A', 'table', 'of', 'electric', 'clay', '(2013)', '[video]'],
#  ['Python', 'bumps', 'off', 'Java', 'as', 'top', 'learning', 'language'],
#  ['VPN', 'access', 'being', 'disabled', 'in', 'China'],
#  ['Solution:',
#   'Blogger',
#   'Redirect',
#   'to',
#   'a',
#   'country-specific',
#   'URL',
#   '(ccTLD)'],
#  ['Is', 'Apple', 'bringing', 'high', 'luxury', 'down', 'to', 'the', 'people?'],
#  ['How', 'video', 'game', 'designers', 'view', 'developers'],
#  ['Stolen',
#   'Credit',
#   'Card',
#   'Information',
#   'Used',
#   'to',
#   'Make',
#   'Purchases',
#   'with',
#   'Apple',
#   'Pay'],
#  ['Tips', 'for', 'Buying', 'Concert', 'Tickets', 'Online'],
#  ['Weird', 'Exoplanet', 'Discovered', 'Orbiting', 'Two', 'Stars'],
#  ['In', 'the', 'last', '10', 'years', "we've", 'learned', 'a', 'lot.'],
#  ['Speed', 'up', 'your', 'iOS', 'development', 'with', 'Clutch.io'],
#  ['Common',
#   'App',
#   'problems:',
#   'A',
#   'meltdown',
#   'worthy',
#   'of',
#   'healthcare.gov'],
#  ['Data', 'killed', 'the', 'HiPPO', 'star'],
#  ['Nokia', '3230', 'Speaker', 'Ways', 'Ear', 'Phone'],
#  ['What', 'happens', 'to', 'your', 'body', 'when', "you're", 'asleep'],
#  ['RIMs',
#   'Q4',
#   'likely',
#   'to',
#   'disappoint',
#   'iPhone',
#   '5',
#   'will',
#   'overshadow',
#   'BlackBerry',
#   '10'],
#  ['Uber', 'for', 'Gift', 'Giving'],
#  ['Nike', 'Dunks', 'Cheap', 'For', 'Sale'],
#  ['Yahoo', 'names', "Paypal's", 'Scott', 'Thompson', 'as', 'new', 'head'],
#  ['oving', 'to', 'California', 'wont', 'make', 'you', 'happy'],
#  ['Luxury', 'Brands', 'Make', 'a', 'Good', 'Investment'],
#  ['Speeding', 'up', 'our', 'test', 'suite', 'in', 'development'],
#  ['Twitter', 'restores', '$50000', 'N', 'username', 'to', 'its', 'owner'],
#  ['Campuses',
#   'getting',
#   'less',
#   'political',
#   'as',
#   "'60s",
#   'professors',
#   'retire'],
#  ...]

# %% [markdown]
# from tokenized_headlines:
#
# - some punctuations are attached to each splitted item
# - the same words are differentiated by uppercase and lowercase

# %%
punctuation = [",", ":", ";", ".", "'", '"', "’", "?", "/", "-", "+", "&", "(", ")"]
clean_tokenized = []
for item in tokenized_headlines:
    tokens = []
    for token in item:
        token = token.lower()
        for punc in punctuation:
            token = token.replace(punc, "")
        tokens.append(token)
    clean_tokenized.append(tokens)

# %%
clean_tokenized
# Out:
# [['software',
#   'sadly',
#   'we',
#   'did',
#   'adopt',
#   'from',
#   'the',
#   'construction',
#   'analogy'],
#  ['googles',
#   'stock',
#   'split',
#   'means',
#   'more',
#   'control',
#   'for',
#   'larry',
#   'and',
#   'sergey'],
#  ['ssl',
#   'dos',
#   'attack',
#   'tool',
#   'released',
#   'exploiting',
#   'negotiation',
#   'overhead'],
#  ['immutability', 'and', 'blocks', 'lambdas', 'and', 'closures'],
#  ['comment', 'optimiser', 'la', 'vitesse', 'de', 'wordpress'],
#  ['ilk', 'is', 'not', 'as', 'good', 'for', 'you', 'as', 'you', 'think'],
#  ['worldometers', '', 'real', 'time', 'world', 'statistics'],
#  ['icrosoft', 'strikes', 'back', 'introduces', 'docs', 'for', 'facebook'],
#  ['net', 'http', 'status', 'codes'],
#  ['anecdata',
#   'or',
#   'how',
#   'mckinseys',
#   'story',
#   'became',
#   'sheryl',
#   'sandbergs',
#   'fact'],
#  ['immigration', 'overhaul', 'passes', 'in', 'senate'],
#  ['what', 'matters', 'most', 'at', 'adtech', 'sf', '2014'],
#  ['amazon',
#   'silk',
#   'revisited',
#   'is',
#   'the',
#   'split',
#   'cloud',
#   'browser',
#   'any',
#   'faster'],
#  ['dieter', 'rams', 'ten', 'principles', 'of', 'good', 'design'],
#  ['gmail', 'down'],
#  ['show', 'how', 'dont', 'tell', 'what', '', 'a', 'management', 'style'],
#  ['us', 'releases', 'images', 'said', 'to', 'implicate', 'russia'],
#  ['realtime',
#   'ocrtranslation',
#   'of',
#   'chinese',
#   'text',
#   'through',
#   'iphone',
#   'video',
#   'camera'],
#  ['des', 'dcorations', 'de', 'nol', 'plus', 'colos'],
#  ['childish', 'behaviour'],
#  ['silicon',
#   'valley',
#   'shouldnt',
#   'fear',
#   'china',
#   'atlantic',
#   'monthly',
#   'writer',
#   'says'],
#  ['mirillis', 'action', '1330'],
#  ['older', 'entrepreneurs', 'find', 'new', 'niche', 'in', 'startups'],
#  ['computer', 'programming', 'for', 'children', 'minus', 'cryptic', 'syntax'],
#  ['ab', 'testing', 'with', 'google', 'analytics'],
#  ['latino', 'sexdates'],
#  ['otorola',
#   'is',
#   'turning',
#   'android',
#   '40',
#   'into',
#   'a',
#   'desktop',
#   'os',
#   'with',
#   'webtop',
#   '30'],
#  ['ai', 'movie', 'merch', 'super', 'toy', 'teddy'],
#  ['prisoners',
#   'in',
#   'ga',
#   'organize',
#   'strike',
#   'via',
#   'contraband',
#   'cellphones'],
#  ['amazon', 'cloud', 'major', 'outages', '', 'analysis'],
#  ['hired',
#   'raises',
#   '$15m',
#   'series',
#   'a',
#   'at',
#   'valuation',
#   'around',
#   '$60m'],
#  ['google',
#   'ceo',
#   'is',
#   'tired',
#   'of',
#   'rivals',
#   'laws',
#   'wants',
#   'to',
#   'start',
#   'his',
#   'own',
#   'country'],
#  ['effective', 'c11', 'content', 'and', 'status', 'scott', 'meyers'],
#  ['twitter',
#   'back',
#   'on',
#   'track',
#   '',
#   'raises',
#   'api',
#   'limit',
#   'to',
#   '100',
#   'requests',
#   'per',
#   'hour'],
#  ['faster', 'search', 'with', 'slashtagit'],
#  ['the', 'end', 'of', 'ragequitting'],
#  ['why',
#   'basecamp',
#   'just',
#   'launched',
#   'an',
#   'online',
#   'magazine',
#   'that',
#   'shuns',
#   'technology'],
#  ['an', 'quits', 'job', 'with', 'a', 'cake'],
#  ['on',
#   'being',
#   'a',
#   'black',
#   'male',
#   'six',
#   'feet',
#   'four',
#   'inches',
#   'tall',
#   'in',
#   'america',
#   'in',
#   '2014'],
#  ['using', 'oauth', '20', 'with', 'mqtt'],
#  ['playstation', '4', 'starting', 'to', 'sell', 'out'],
#  ['skype', 'for', 'windows', 'phone', 'is', 'out', 'of', 'beta'],
#  ['kernelorg', 'is', 'back'],
#  ['how', 'obamas', 'blackberry', 'got', 'secured'],
#  ['open', 'web', 'payments', '', 'paypals', 'answer', 'to', 'opentransact'],
#  ['show', 'hn', 'discover', 'top', 'tech', 'industry', 'bloggers'],
#  ['dont',
#   'freak',
#   'out',
#   'but',
#   'the',
#   'first',
#   '3dprinted',
#   'metal',
#   'gun',
#   'totally',
#   'works'],
#  ['our', 'living', 'style', 'guide', 'writing', 'maintainable', 'htmlcss'],
#  ['vince', 'del', 'monte', 'fitness', 'for', 'all', 'ages'],
#  ['social', 'media', 'portraits'],
#  ['conceive',
#   'choose',
#   'create',
#   'communicate',
#   'advice',
#   'for',
#   'successful',
#   'projects',
#   'from',
#   'a',
#   'hacker'],
#  ['vlc', '120', 'features', '', 'part', '1', 'video', 'output'],
#  ['startup', 'lessons', 'learned', 'from', 'warren', 'buffett'],
#  ['tesla', 'smashes', 'earnings', 'and', 'revenue', 'expectations'],
#  ['the', 'dramatic', 'nature', 'of', 'the', 'easiest', 'bugs', 'to', 'fix'],
#  ['google',
#   'microsoft',
#   'facebook',
#   'banks',
#   'team',
#   'to',
#   'wipe',
#   'out',
#   'phishing',
#   'via',
#   'dmarcorg'],
#  ['startups',
#   'try',
#   'to',
#   'reroute',
#   'food',
#   'waste',
#   'to',
#   'the',
#   'hungry',
#   '',
#   'the',
#   'salt'],
#  ['tourist', 'health', 'insurance', 'for', 'backpackers'],
#  ['jonathan', 'harris', '', 'today'],
#  ['star', 'wars', 'the', 'high', 'school', 'musical', '[video]'],
#  ['hacktivists',
#   'pose',
#   'biggest',
#   'data',
#   'breach',
#   'threat',
#   'study',
#   'finds'],
#  ['frances', '35hour', 'working', 'week', 'under', 'threat'],
#  ['how', 'allies', 'used', 'math', 'against', 'german', 'tanks'],
#  ['ozilla',
#   'launches',
#   'minion',
#   'automated',
#   'security',
#   'testing',
#   'platform'],
#  ['priceofweedcom', 'releases', 'database', 'on', 'buzzdata'],
#  ['understanding', 'css', 'filter', 'effects'],
#  ['google',
#   'backs',
#   'iowa',
#   'wind',
#   'farm',
#   'has',
#   'put',
#   'close',
#   'to',
#   '$1b',
#   'into',
#   'clean',
#   'power'],
#  ['teletext', 'ad', '1978'],
#  ['air', 'jordan', '2010', 'silver', 'anniversary', 'dwyane', 'wade'],
#  ['simulations',
#   'on',
#   'the',
#   'chances',
#   'kentucky',
#   'goes',
#   '400',
#   'in',
#   'college',
#   'hoops'],
#  ['snowdens',
#   'moscow',
#   'lawyer',
#   'nsa',
#   'leaker',
#   'is',
#   'planning',
#   'to',
#   'live',
#   'in',
#   'russia',
#   'and',
#   'get',
#   'a',
#   'job'],
#  ['the',
#   '19thcentury',
#   'mumbai',
#   'plague',
#   'may',
#   'offer',
#   'clues',
#   'in',
#   'dealing',
#   'with',
#   'ebola'],
#  ['so', 'you', 'need', 'a', 'typface'],
#  ['app', 'engine', '171', 'released'],
#  ['use', 'it', 'or', 'loose', 'it'],
#  ['icrosoft',
#   'customer',
#   'service',
#   'experience',
#   'the',
#   'good',
#   'after',
#   'the',
#   'bad'],
#  ['12th',
#   'annual',
#   'icfp',
#   'programming',
#   'contest',
#   'begins',
#   'next',
#   'weekend'],
#  ['how',
#   'to',
#   'save',
#   'youtube',
#   'video',
#   'to',
#   'mp3',
#   'formats',
#   'on',
#   'mac'],
#  ['the', 'pastebin', 'client', 'exercise'],
#  ['teliasonera',
#   'to',
#   'build',
#   'facebooks',
#   'new',
#   'paneuropean',
#   'optical',
#   'network'],
#  ['email',
#   '',
#   'teens',
#   '',
#   'using',
#   'email',
#   'hasnt',
#   'taken',
#   'root',
#   'amongst',
#   'the',
#   'millennials'],
#  ['some', 'of', 'technologys', 'most', 'underrated', 'founders'],
#  ['api',
#   'economy',
#   'growth',
#   'of',
#   'an',
#   'api',
#   'hub',
#   'from',
#   '0',
#   'to',
#   '100k',
#   'users',
#   'and',
#   '10k',
#   'apis'],
#  ['covert', 'communication', 'in', 'a', 'dark', 'network'],
#  ['history',
#   'of',
#   'the',
#   'continental',
#   'tire',
#   'company',
#   'first',
#   'fifty',
#   'years',
#   'of',
#   'success'],
#  ['confessions', 'of', 'a', 'job', 'hopper'],
#  ['bing', 'is', 'fine', 'insecure', 'as', 'ever', 'but', 'fine'],
#  ['reddit', 'gay', 'gamers', 'to', 'fight', 'gaymer', 'trademark'],
#  ['show',
#   'hn',
#   'my',
#   'onesided',
#   'anonymous',
#   'chat',
#   'startup',
#   'reached',
#   '150k',
#   'members',
#   'virally'],
#  ['security', 'hands', 'on', 'training', '–', 'part', '1'],
#  ['how', 'to', 'get', 'rich', 'really', 'really', 'rich'],
#  ['paypal',
#   'to',
#   'open',
#   'a',
#   'popup',
#   'store',
#   'in',
#   'new',
#   'york',
#   'to',
#   'showcase',
#   'new',
#   'payments',
#   'technologies'],
#  ['interacting',
#   'with',
#   'women',
#   'can',
#   'impair',
#   'mens',
#   'cognitive',
#   'functioning'],
#  ['6120', 'c', 'mic', 'microphone', 'problem'],
#  ['kickstrap', 'bootstrap', 'with', 'apps', 'themes', 'and', 'extras'],
#  ['aking', 'money', 'online', 'with', 'freelance', 'jobs'],
#  ['craft', 'beer', 'delivered', 'to', 'your', 'office'],
#  ['3d',
#   'printing',
#   'is',
#   'a',
#   'lot',
#   'of',
#   'hype',
#   'and',
#   'itll',
#   'never',
#   'go',
#   'mainstream'],
#  ['arines',
#   'catch',
#   'deserter',
#   '5',
#   'years',
#   'after',
#   'his',
#   'honorable',
#   'discharge'],
#  ['docker', 'hack', 'day', 'lightning', 'talks', 'live'],
#  ['what', 'wired', 'is', 'not', 'telling', 'you', 'eugene', 'kaspersky'],
#  ['kindle',
#   'fire',
#   'take',
#   'three',
#   'tablets',
#   'and',
#   'call',
#   'me',
#   'in',
#   'the',
#   'morning'],
#  ['wary', 'of', 'egypt', 'unrest', 'china', 'censors', 'web'],
#  ['the',
#   'first',
#   'new',
#   'release',
#   'of',
#   'inform',
#   'in',
#   'three',
#   'years',
#   'is',
#   'now',
#   'available'],
#  ['the', 'best', 'api', 'documentation'],
#  ['bbc', 'website', 'crashes', 'for', 'an', 'hour'],
#  ['queen', 'tours', 'rim'],
#  ['pirated', 'rihanna', 'songs', 'land', 'frenchman', 'in', 'court'],
#  ['what', 'is', 'all', 'of', 'this', 'sublime', 'text', '2', 'hullaballo'],
#  ['dont', 'get', 'stuck', 'continuous', 'deployment'],
#  ['aaron', 'swartzs', 'final', 'commit'],
#  ['crazy',
#   'stop',
#   'motion',
#   'video',
#   'ninja',
#   'moped',
#   '',
#   'insert',
#   'coin',
#   '[video]'],
#  ['new', 'sports', 'cars', 'hitting', 'the', 'surface', 'in', '20112012'],
#  ['couple', '–', 'relationship', 'app', 'for', 'two'],
#  ['salman',
#   'khan',
#   'on',
#   'the',
#   'power',
#   'of',
#   'the',
#   'internet',
#   'for',
#   'learning'],
#  ['haskelier', '–', 'haskell', 'for', 'the', 'advanced', 'layman'],
#  ['the',
#   'digg',
#   'heat',
#   'map',
#   'digg',
#   'is',
#   'mostly',
#   'us',
#   'and',
#   'mostly',
#   'read',
#   'at',
#   'work'],
#  ['google',
#   'tv',
#   'growing',
#   'pains',
#   'networks',
#   'block',
#   'web',
#   'tv',
#   'shows'],
#  ['denthors', 'graphics', 'tutorials', 'why', 'i', 'am', 'a', 'programmer'],
#  ['gelael',
#   'art',
#   'shop',
#   'light',
#   'pink',
#   'and',
#   'gold',
#   'wedding',
#   'centerpiece'],
#  ['gigyas', 'big', 'win', 'with', 'top', 'widget', 'companies'],
#  ['introducing', 'firefox', '9'],
#  ['five',
#   'dos',
#   'and',
#   'donts',
#   'on',
#   'building',
#   'your',
#   'robotics',
#   'startup'],
#  ['programming', 'your', 'culture'],
#  ['apple',
#   'hires',
#   'former',
#   'windows',
#   'hacker',
#   'away',
#   'from',
#   'microsoft'],
#  ['patent',
#   'crowdbusting',
#   'qa',
#   'with',
#   'cheryl',
#   'milone',
#   'of',
#   'article',
#   'one',
#   'partners'],
#  ['prometheus', 'a', 'nextgeneration', 'monitoring', 'system'],
#  ['whyday', 'august', '19'],
#  ['eet',
#   'the',
#   'electric',
#   'life',
#   'forms',
#   'that',
#   'live',
#   'on',
#   'pure',
#   'energy'],
#  ['tehnoetic',
#   'wireless',
#   'usb',
#   'adapter',
#   'now',
#   'fsfcertified',
#   'to',
#   'respect',
#   'your',
#   'freedom'],
#  ['new', 'zealand', 'military', 'releases', 'ufo', 'files'],
#  ['list', 'of', 'html5', 'charts'],
#  ['device',
#   'frontiers',
#   'that',
#   'mobile',
#   'developers',
#   'think',
#   'are',
#   'coming'],
#  ['laptop',
#   'on',
#   'your',
#   'lap',
#   'might',
#   'cause',
#   'fertility',
#   'issues',
#   'in',
#   'men'],
#  ['how', 'small', 'companies', 'can', 'compete', 'with', 'amazon'],
#  ['fbi', 'redacting', 'published', 'facts', 'from', 'drone', 'documents'],
#  ['relationship', 'of', 'the', 'government', 'and', 'entrepreneurship'],
#  ['rt',
#   'aristotelessd',
#   'lopezobrador_',
#   'gano',
#   'al',
#   'pendejo',
#   'de',
#   'mexico',
#   'epn'],
#  ['climate',
#   'change',
#   'as',
#   'religion',
#   'the',
#   'gospel',
#   'according',
#   'to',
#   'gore'],
#  ['tip', 'of', 'the', 'week'],
#  ['premium', 'rafting', 'vail', 'colorado'],
#  ['pokemon', 'yellow', 'total', 'control', 'hack'],
#  ['earths',
#   'gold',
#   'may',
#   'come',
#   'from',
#   'collisions',
#   'of',
#   'dead',
#   'stars'],
#  ['introducing', 'chaos', 'engineering'],
#  ['this', 'is', 'my', 'twitter', 'algorithm', 'whats', 'yours'],
#  ['face', 'tracking', 'coupled', 'with', 'projection', 'mapping'],
#  ['ajorintel', 'business', 'intelligence', 'for', 'quickbooks'],
#  ['dear', 'verisign', 'trust', 'requires', 'transparency'],
#  ['berlin', 'tech', 'startups'],
#  ['show', 'hn', 'madrasa', '–', 'a', 'community', 'for', 'autodidacts'],
#  ['arkov', 'chains', 'using', 'couchdbs', 'group', 'reduce'],
#  ['how', 'serious', 'is', 'the', 'java7', 'solrlucene', 'bug'],
#  ['red', 'universe', 'requires', 'flash', '', 'highspeed', 'internet'],
#  ['snowden',
#   'i',
#   'left',
#   'the',
#   'nsa',
#   'clues',
#   'but',
#   'they',
#   'couldnt',
#   'find',
#   'them'],
#  ['newspapers',
#   'can',
#   'reduce',
#   'traffic',
#   'by',
#   '32%',
#   'by',
#   'simply',
#   'asking',
#   'google',
#   'to',
#   'stop',
#   'sending',
#   'them',
#   'traffic'],
#  ['google', 'miscalculator', 'revealing', 'errors'],
#  ['refactoring', 'methods', 'with', 'recursive', 'combinators'],
#  ['blog',
#   'security',
#   'x',
#   'give',
#   'your',
#   'blog',
#   'some',
#   'extra',
#   'protection'],
#  ['the', 'turing', 'test', 'transcripts', 'of', 'the', 'best', 'attempts'],
#  ['hulu', 'a', 'victim', 'of', 'its', 'own', 'success'],
#  ['olympics', 'diving', 'live', 'stream', 'online', 'watch', 'here'],
#  ['the', 'bill', 'gates', 'challenge', 'to', 'reinvent', 'the', 'toilet'],
#  ['how', 'bookya', 'disrupts', 'the', 'liveentertainment', 'industry'],
#  ['artificial', 'lawn'],
#  ['creating', 'effective', 'ruby', 'gems'],
#  ['ight', 'want', 'to', 'skip', 'that', 'tech', 'conference', 'in', 'india'],
#  ['balancing', 'family', 'and', 'the', 'drive', 'to', 'succeed'],
#  ['eu', 'opens', 'antitrust', 'investigation', 'into', 'google', 'search'],
#  ['when',
#   'is',
#   'the',
#   'best',
#   'time',
#   'of',
#   'the',
#   'year',
#   'to',
#   'start',
#   'my',
#   'startup'],
#  ['setup', 'ghost', 'with', 'postgresql', 'via', 'dokku'],
#  ['parliament', 'of', 'the', 'worlds', 'religions'],
#  ['would', 'you', 'hire', 'a', 'netflix', 'casualty'],
#  ['google', 'earth', '', 'except', 'its', 'for', 'space'],
#  ['technical', 'articles'],
#  ['realtime', 'chat', 'using', 'dynamic', 'animated', 'images'],
#  ['is',
#   'paul',
#   'graham',
#   'really',
#   'as',
#   'phony',
#   'as',
#   'these',
#   'guys',
#   'make',
#   'him',
#   'out',
#   'to',
#   'be'],
#  ['side',
#   'project',
#   'to',
#   'fund',
#   '3',
#   'months',
#   'of',
#   'rent',
#   'for',
#   'people',
#   'in',
#   'need',
#   'of',
#   'assistance'],
#  ['only',
#   '5%',
#   'of',
#   'cubans',
#   'have',
#   'access',
#   'to',
#   'the',
#   'open',
#   'internet'],
#  ['http_load', '', 'test', 'your', 'server', 'for', 'heavy', 'load'],
#  ['what', 'are', 'good', 'keyboards', 'for', 'programming'],
#  ['the',
#   'voice',
#   'chat',
#   'api',
#   'is',
#   'great',
#   'example',
#   'of',
#   'an',
#   'simple',
#   'open',
#   'api',
#   'driven',
#   'resource'],
#  ['ego', 'and', 'news', 'logic'],
#  ['walk', 'in', 'bath'],
#  ['stand', 'out', 'get', 'hired'],
#  ['easiest',
#   'guide',
#   'of',
#   'converting',
#   'mp4',
#   'videos',
#   'to',
#   'mov',
#   'files',
#   'on',
#   'mac'],
#  ['networking',
#   'at',
#   'sxsw',
#   'how',
#   'to',
#   'tell',
#   'if',
#   'theyre',
#   'interested',
#   'in',
#   'business',
#   'or',
#   'pleasure'],
#  ['the', 'interactive', 'projector', ''],
#  ['bret',
#   'victors',
#   'exapple',
#   'yin',
#   'and',
#   'yang',
#   'of',
#   'technology',
#   'and',
#   'design'],
#  ['the',
#   'mercenary',
#   'techie',
#   'who',
#   'troubleshoots',
#   'for',
#   'drug',
#   'dealers',
#   'and',
#   'jealous',
#   'lovers'],
#  ['should', 'cs', 'students', 'be', 'graded', 'on', 'performance'],
#  ['goa', 'escorts'],
#  ['cartoon', 'wild', 'weather'],
#  ['build',
#   'datadriven',
#   'apps',
#   'with',
#   'windows',
#   'azure',
#   'and',
#   'windows',
#   'phone',
#   '7'],
#  ['death',
#   'in',
#   'the',
#   'sahara',
#   'an',
#   'illfated',
#   'attempt',
#   'to',
#   'reach',
#   'fortress',
#   'europe'],
#  ['so',
#   'long',
#   'and',
#   'thanks',
#   'for',
#   'all',
#   'the',
#   'fish',
#   'missing',
#   'douglas',
#   'adams'],
#  ['yesterday',
#   'russia',
#   'lost',
#   'contact',
#   'with',
#   'every',
#   'last',
#   'one',
#   'of',
#   'its',
#   'space',
#   'satellites'],
#  ['live', 'voting', 'results'],
#  ['what',
#   'it',
#   'takes',
#   'to',
#   'make',
#   'reddit',
#   'front',
#   'page',
#   'data',
#   'and',
#   'stats'],
#  ['designbased',
#   'web',
#   'applications',
#   'development',
#   '',
#   'the',
#   'essential',
#   'new',
#   'paradigm'],
#  ['cara',
#   'software',
#   'that',
#   'turns',
#   'any',
#   'camera',
#   'into',
#   'an',
#   'intelligent',
#   'sensor'],
#  ['being', 'bleeding', 'edge', 'is', 'a', 'good', 'thing'],
#  ['nokia', 'c3', 'price'],
#  ['freebie',
#   'alert',
#   'awesome',
#   'collection',
#   'of',
#   'textures',
#   'from',
#   'wegraphics'],
#  ['photomath', 'uses', 'your', 'phones', 'camera', 'to', 'solve', 'equations'],
#  ['gopano',
#   'micro',
#   '',
#   'capture',
#   '360',
#   'videos',
#   'from',
#   'an',
#   'iphone',
#   '4'],
#  ['bill',
#   'to',
#   'protect',
#   'car',
#   'services',
#   'from',
#   'uber',
#   'raises',
#   'questions'],
#  ['the', 'new', 'ipads', 'screen', 'under', 'the', 'microscope'],
#  ['nice', 'and', 'funny', 'pic'],
#  ['5', 'web', 'titans', 'that', 'withered', 'under', 'yahoo'],
#  ['dhs', 'seizes', '75', 'domain', 'names'],
#  ['new',
#   'zealand',
#   'to',
#   'begin',
#   'registrations',
#   'for',
#   '2nd',
#   'level',
#   'domains',
#   'tomorrow'],
#  ['open', 'source', 'github', 'internal', 'training', 'materials'],
#  ['innovation',
#   'in',
#   'education',
#   'and',
#   'the',
#   'opportunity',
#   'to',
#   'create'],
#  ['low',
#   'cost',
#   'access',
#   'to',
#   'space',
#   'with',
#   'the',
#   'starfire',
#   'space',
#   'cannon'],
#  ['rockmelt', 'releases', 'rockmelt', 'mobile', 'browser', 'for', 'iphone'],
#  ['canadian',
#   'hacker',
#   'school',
#   'goes',
#   'dark',
#   'after',
#   'government',
#   'probe'],
#  ['plurk', 'relaunches', 'with', 'twitterfacebook', 'like', 'service'],
#  ['ice', 'cream'],
#  ['how', 'great', 'ios', 'animations', 'make', 'great', 'apps'],
#  ['google',
#   'built',
#   'endtoend',
#   'encryption',
#   'to',
#   'block',
#   'cybercrime',
#   'not',
#   'the',
#   'nsa'],
#  ['obama', 'new', 'tech', 'alisters', 'align'],
#  ['meet', 'periscope', 'twitters', 'new', 'live', 'video', 'app'],
#  ['google', 'venturesbacked', 'startup', 'truelens', 'nabs', '$12', 'million'],
#  ['5', 'reasons', 'kde', 'is', 'better', 'than', 'unity'],
#  ['the', 'problem', 'with', 'blogging', 'culture'],
#  ['sprint',
#   'set',
#   'to',
#   'release',
#   '3genabling',
#   'case',
#   'for',
#   'ipod',
#   'touch'],
#  ['startup', 'quotes'],
#  ['join', 'twitter', 'and', 'get', 'spammed'],
#  ['is', 'trader', 'joes', 'really', 'not', 'on', 'twitter'],
#  ['a', 'startup', 'ecosystem', 'forms', 'in', 'chicago'],
#  ['computer', 'anonymous'],
#  ['localization',
#   'platform',
#   'phraseapp',
#   'now',
#   'offers',
#   'gengo',
#   'powered',
#   'translation'],
#  ['arioway',
#   'a',
#   'handsfree',
#   'wheelchair',
#   'to',
#   'narrow',
#   'the',
#   'disability',
#   'gap',
#   'italian',
#   'design'],
#  ['scala', 'compiler', 'phases'],
#  ['building', 'highquality', 'frontend', 'modules'],
#  ['what', 'marriage', 'means', 'to', 'me'],
#  ['do',
#   'we',
#   'really',
#   'want',
#   'linux',
#   'machines',
#   'that',
#   'never',
#   'reboot'],
#  ['how',
#   'i',
#   'reached',
#   '100000',
#   'views',
#   'in',
#   '30',
#   'days',
#   'on',
#   'medium'],
#  ['chess', 'in', 'c'],
#  ['latest', 'news', 'from', 'africa'],
#  ['ens', '420', 'topblack', 'multicolor', '[mens', '420', 'top]', '', '$6899'],
#  ['how', 'to', 'be', 'excellent', 'at', 'something'],
#  ['purchased',
#   'copies',
#   'of',
#   'rock',
#   'band',
#   'for',
#   'iphone',
#   'to',
#   'become',
#   'unplayable'],
#  ['how', 'to', 'secure', 'ipads', 'for', 'corporate', 'use'],
#  ['steve', 'jobs', 'portrait', 'made', 'of', 'classic', 'apple', 'typefaces'],
#  ['understanding', 'sbts', 'scala', 'incremental', 'recompilation'],
#  ['choosing', 'a', 'wine', 'cabinet'],
#  ['how', 'can', 'too', 'much', 'information', 'kill', 'creativity'],
#  ['nithyananda', 'breaking', 'records', 'on', 'tweets'],
#  ['how', 'jonathans', 'card', 'really', 'works'],
#  ['“delightful”', 'interaction', 'design', 'needs', 'to', 'die'],
#  ['show', 'hn', 'swing', 'copters', 'in', 'html5'],
#  ['how',
#   'mastercard',
#   'helps',
#   'retailers',
#   'understand',
#   'their',
#   'consumers'],
#  ['kenny', 'kellogg', 'six', 'links', 'on', 'saturday'],
#  ['hd', 'mars', 'curiosity', 'landing'],
#  ['ftc', 'asked', 'to', 'investigate', 'kids', 'and', 'inapp', 'purchases'],
#  ['pintar', 'habitacion'],
#  ['cloud',
#   'idea',
#   'using',
#   'gridgain',
#   'get',
#   'vc',
#   'funded',
#   'in',
#   '90',
#   'days'],
#  ['how', 'to', 'examine', 'active', 'and', 'hover', 'in', 'firebug'],
#  ['hellojs', '–', 'clientside', 'oauth', 'for', 'js'],
#  ['all', 'your', 'tabs', 'accessible', 'everywhere'],
#  ['top',
#   '25',
#   '1',
#   'methods',
#   'to',
#   'enhance',
#   'your',
#   'link',
#   'building',
#   'strategy'],
#  ['android',
#   '40',
#   'aka',
#   'ice',
#   'cream',
#   'sandwich',
#   'update',
#   'now',
#   'rolling',
#   'out'],
#  ['andr', 'cassagnes', 'etchasketch', 'inventor', 'has', 'died'],
#  ['iphone', 'app', 'dev', 'with', 'titanium', 'getting', 'started'],
#  ['free', 'idea', 'code', 'equivalent', 'to', 'morning', 'pages750', 'words'],
#  ['overcome',
#   'your',
#   'fear',
#   'of',
#   'marketing',
#   'to',
#   'get',
#   'what',
#   'you',
#   'want'],
#  ['show', 'hn', 'git', 'flow', 'for', 'selective', 'feature', 'deployment'],
#  ['f#', 'tshirt', 'app', 'from', 'xamarin'],
#  ['how', 'to', 'correct', 'an', 'essay'],
#  ['paa', 'lashes', 'out', 'against', 'rogue', 'cyberlockers'],
#  ['how', 'the', 'mac', 'no', 'longer', 'matters', 'to', 'apple'],
#  ['anic', 'digger', 'help'],
#  ['foursquarecom', '', 'scalalift', '[slides]'],
#  ['in', 'browser', '8bit', 'paint', 'tool'],
#  ['35', 'perfect', 'examples', 'of', 'branding', 'design'],
#  ['anna', 'miminoshvili', 'fallwinter', '201213', 'moscow'],
#  ['bittorrent', 'net', 'meltdown', 'delayed'],
#  ['apple', 'responds', 'to', 'iphone', '4', 'reception', 'issues'],
#  ['parsing', 'the', 'stackoverflow', 'careers', 'feed'],
#  ['qonqr', 'live', 'zone', 'statistics'],
#  ['icrosoft',
#   'unveils',
#   'new',
#   'msncom',
#   '',
#   'for',
#   'windows',
#   '8',
#   'and',
#   'ie10',
#   'only'],
#  ['embedding', 'an', 'http', 'web', 'server', 'in', 'firefox', 'os'],
#  ['compare', 'missouri', 'health', 'insurance'],
#  ['timereversal',
#   'violation',
#   'directly',
#   'observed',
#   'by',
#   'stanford',
#   'physicists'],
#  ['ibm',
#   'leads',
#   'vision',
#   'cloud',
#   'business',
#   'storage',
#   'research',
#   '|',
#   'cloud',
#   'business',
#   'review'],
#  ['esr', 'uses', 'this'],
#  ['baidu', '1q', 'jumps', '165', 'percent', 'topping', 'forecasts'],
#  ['google',
#   'blog',
#   'converter',
#   'googles',
#   'tool',
#   'to',
#   'move',
#   'blog',
#   'data',
#   'between',
#   'services'],
#  ['how',
#   'intellectual',
#   'property',
#   'hampers',
#   'capitalism',
#   '|',
#   'stephan',
#   'kinsella'],
#  ['youtube', 'music'],
#  ['oh'],
#  ['we',
#   'didnt',
#   'make',
#   'the',
#   'cut',
#   'and',
#   'thats',
#   'okay',
#   '|',
#   'lessfuss'],
#  ['photos',
#   'to',
#   'pop',
#   'art',
#   '|',
#   'andy',
#   'warhol',
#   'pop',
#   'art',
#   '|',
#   'pop',
#   'art',
#   'lichstyle',
#   '|',
#   'retro',
#   'pop',
#   'art'],
#  ['ohio',
#   'art',
#   'says',
#   'etch',
#   'a',
#   'sketch',
#   'creator',
#   'dies',
#   'in',
#   'france'],
#  ['the', 'trailer', 'park', 'is', 'the', 'computer'],
#  ['axent', 'wear', 'raises', '$177m', 'from', 'indiegogo', 'supporters'],
#  ['getting',
#   'little',
#   'girls',
#   'interested',
#   'in',
#   'sciencetech',
#   'move',
#   'over',
#   'barbie'],
#  ['glenn', 'greenwald', 'why', 'privacy', 'matters'],
#  ['html5',
#   'geolocation',
#   'api',
#   'to',
#   'measure',
#   'speed',
#   'and',
#   'heading',
#   'of',
#   'your',
#   'car'],
#  ['taws', 'a', 'personal', 'private', 'search', 'engine'],
#  ['talent', 'is', 'overrated', '', 'and', 'what', 'really', 'matters'],
#  ['hostsvaultcom', 'shared', 'cheap', 'hosting', 'from', '$495'],
#  ['show', 'hn', 'free', 'book', 'cover', 'generator'],
#  ['httpwwwfacebookcomgrandmarquishotel'],
#  ['if',
#   'the',
#   'zombie',
#   'apocalypse',
#   'happens',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'this',
#   'guys',
#   'number'],
#  ['best', 'wedding', 'at', 'vegas', 'club'],
#  ['british',
#   'accuse',
#   'david',
#   'miranda',
#   'glenn',
#   'greenwalds',
#   'partner',
#   'of',
#   'terrorism'],
#  ['developing', 'for', 'the', 'browser'],
#  ['stephen',
#   'fry',
#   'to',
#   'pimp',
#   'pushnote',
#   'to',
#   'his',
#   '2m',
#   'followers',
#   'will',
#   'it',
#   'work'],
#  ['host', 'a', 'collaborative', 'blog', 'on', 'github', 'for', 'free'],
#  ['adjustable', 'beds', '|', 'sleep', 'comfort', 'adjustable', 'bed'],
#  ['julia',
#   'is',
#   'a',
#   'highlevel',
#   'highperformance',
#   'dynamic',
#   'programming',
#   'language'],
#  ['apple', 'open', 'and', 'learning', 'from', 'history'],
#  ['acedonian',
#   'officials',
#   'accused',
#   'of',
#   'spying',
#   'on',
#   '20000',
#   'people',
#   'over',
#   'four',
#   'years'],
#  ['build',
#   'your',
#   'own',
#   'programming',
#   'language',
#   'with',
#   'javascript',
#   'slides',
#   '',
#   'code'],
#  ['kno', 'brings', 'its', 'digital', 'textbooks', 'to', 'k12', 'education'],
#  ['bribery',
#   'in',
#   'india',
#   'a',
#   'website',
#   'for',
#   'whistleblowers',
#   'ipaidabribecom'],
#  ['the', 'emacs', 'problem', 'february', '2005'],
#  ['what',
#   'happened',
#   'while',
#   'contributing',
#   'to',
#   'open',
#   'source',
#   'on',
#   'a',
#   'daily',
#   'basis',
#   'for',
#   'one',
#   'year'],
#  ['method',
#   'and',
#   'system',
#   'for',
#   'shockwave',
#   'attenuation',
#   'via',
#   'electromagnetic',
#   'arc'],
#  ['the', 'msdos', 'security', 'model'],
#  ['11', 'creative', 'outdoor', 'advertisement', 'designs'],
#  ['a',
#   'russian',
#   'spys',
#   'guide',
#   'to',
#   'dealing',
#   'with',
#   'angel',
#   'investors'],
#  ['singleplatform', 'acquired', 'by', 'constantcontact'],
#  ['how', 'has', 'vc', 'funding', 'changed', 'since', '1995'],
#  ['implementing', 'visicalc', '2003'],
#  ['baking',
#   'a',
#   'new',
#   'site',
#   'with',
#   'a',
#   'sprinkle',
#   'of',
#   'seo',
#   'part',
#   '2'],
#  ['crowd', 'sourcing', 'your', 'bitcoin', 'mining'],
#  ['could', 'an', 'android', 'desktop', 'replace', 'your', 'windows', 'pc'],
#  ['livestream',
#   'of',
#   'aaron',
#   'swartz',
#   'public',
#   'memorial',
#   'service',
#   'at',
#   'cooper',
#   'union'],
#  ['bitcoinfs', 'a', 'minimal', 'full', 'bitcoin', 'node', 'in', 'f#'],
#  ['new',
#   'adtech',
#   'goes',
#   'consumer',
#   'emotion',
#   'tracker',
#   'affectiva',
#   '$12m',
#   'from',
#   'kpcb',
#   'horizon'],
#  ['oracle', 'goes', 'for', 'broke', 'in', 'court', 'battle', 'with', 'google'],
#  ['graphical', 'muusic'],
#  ['the', 'vietnam', 'solution'],
#  ['insan', 'b', 'kiya', 'shay', 'hai', '', 'advice', 'sms'],
#  ['why', 'submitting', 'site', 'to', 'web', 'directories'],
#  ['infovisualization',
#   'trough',
#   'the',
#   'eyes',
#   'and',
#   'talent',
#   'of',
#   '10',
#   'brazilian',
#   'designers'],
#  ['the',
#   'best',
#   'kept',
#   'secret',
#   'about',
#   'linear',
#   'and',
#   'logistic',
#   'regression'],
#  ['squares',
#   'invisible',
#   'mobile',
#   'payment',
#   'solution',
#   'software',
#   'that',
#   'gives',
#   'you',
#   'superpowers'],
#  ['race', 'condition'],
#  ['the', 'internet', 'ruined', 'april', 'fools', 'day'],
#  ['lightsquared',
#   'delays',
#   'release',
#   'of',
#   'report',
#   'on',
#   'gps',
#   'interference'],
#  ['7rf', 'letter', 'minimal', 'arabiclanguage', 'writing', 'app', '[arabic]'],
#  ['combinator',
#   'v11',
#   '',
#   'a',
#   'simple',
#   'hacker',
#   'news',
#   'client',
#   'for',
#   'windows',
#   'phone'],
#  ['web', 'application', 'development'],
#  ['online', 'trading', 'platform'],
#  ['the', 'artist', 'behind', 'the', 'sexist', 'newsweek', 'cover', 'speaks'],
#  ['the', 'app', 'cobbler'],
#  ['tech', 'support'],
#  ['you', 'cant', 'engineer', 'around', 'taxes'],
#  ['ibm', 'water', 'cools', '3d', 'chips'],
#  ['alfresco',
#   'brings',
#   'its',
#   'enterpriselevel',
#   'content',
#   'management',
#   'to',
#   'small',
#   'businesses'],
#  ['progress', 'acquires', 'telerik', 'for', '$2625m'],
#  ['good', 'quality', 'egadget'],
#  ['how',
#   'can',
#   'a',
#   'garbage',
#   'collector',
#   'know',
#   'that',
#   'a',
#   'variable',
#   'isnt',
#   'referenced',
#   'anymore'],
#  ['enabling',
#   'the',
#   'realtime',
#   'web',
#   'with',
#   'livedirectoryorg',
#   'an',
#   'early',
#   'release'],
#  ['venturing', 'beyond', 'rails', 'sinatra'],
#  ['the', 'new', 'app', 'thats', 'disrupting', 'the', 'ponysharing', 'market'],
#  ['google',
#   'maps',
#   'easter',
#   'egg',
#   'the',
#   'tardis',
#   'is',
#   'in',
#   'london',
#   'street',
#   'view',
#   'old',
#   'maps',
#   'only'],
#  ['strategic', 'design', 'embrace', 'imperfection', '[video]'],
#  ['announcing', 'puppetdb', '11', 'do', 'more', 'with', 'your', 'data'],
#  ['how', 'to', 'run', 'a', '99designs', 'competition'],
#  ['central',
#   'europe',
#   'backs',
#   'out',
#   'of',
#   'copyright',
#   'deal',
#   'after',
#   'protests'],
#  ['github', 'needs', 'a', 'kickass', 'designer', 'github', 'jobs'],
#  ['any', 'multithreaded', 'interpreters'],
#  ['facebook', 'midnight', 'delivery', 'security', 'flaw'],
#  ['the',
#   'fermi',
#   'paradox',
#   'where',
#   'the',
#   'hell',
#   'are',
#   'the',
#   'other',
#   'earths'],
#  ['home', 'cotton', 'candy', 'machine'],
#  ['nexus', '4', 'includes', 'support', 'for', 'lte', 'on', 'band', '4'],
#  ['early', 'history', 'of', 'html', '', '1990', 'to', '1992'],
#  ['enabling', 'richer', 'interactions', 'in', 'the', 'clojure', 'repl'],
#  ['lea', 'verou', '|', 'the', 'humble', 'borderradius', '|', 'css', 'day'],
#  ['show',
#   'hn',
#   'rhodecode',
#   'enterprise',
#   '',
#   'an',
#   'open',
#   'source',
#   'alternative',
#   'to',
#   'github',
#   'enterprise'],
#  ['how',
#   'to',
#   'pass',
#   'the',
#   'cloudera',
#   'hadoop',
#   'developer',
#   'exam',
#   'in',
#   'one',
#   'month'],
#  ['why',
#   'apple',
#   'was',
#   'my',
#   'company',
#   'of',
#   'the',
#   'decade',
#   'by',
#   'om',
#   'malik',
#   'of',
#   'gigaom'],
#  ['a', 'company', 'that', 'turns', 'plastic', 'bottles', 'into', 'clothes'],
#  ['better', 'place', 'to', 'file', 'for', 'bankruptcy'],
#  ['htop', '', 'better', 'top'],
#  ['arket', 'for', 'zeroday', 'vulnerabilities', 'incentivizes', 'sabotage'],
#  ['new',
#   'orleans',
#   'still',
#   'working',
#   'to',
#   'fix',
#   'real',
#   'estate',
#   'computer',
#   'crash'],
#  ['obile',
#   'minute',
#   '#105',
#   'banner',
#   'ads',
#   'suck',
#   'dont',
#   'let',
#   'them',
#   'stay',
#   'in',
#   'mobile'],
#  ['what', 'is', 'juglans', 'regia', 'english', 'walnut', 'tree'],
#  ['theres',
#   'always',
#   'this',
#   'tendency',
#   'of',
#   'disruption',
#   '|',
#   'jorge',
#   'cuadra',
#   'fueyo'],
#  ['facebook',
#   'reports',
#   'fourth',
#   'quarter',
#   'and',
#   'full',
#   'year',
#   '2012',
#   'results'],
#  ['stop', 'preaching', 'for', 'financial', 'independence'],
#  ['comparing', 'colour', 'space', 'conversion', 'libraries'],
#  ['game', 'theory', 'in', 'the', 'dark', 'knight', 'the', 'opening', 'scene'],
#  ['httpwwwfivefingersalecom'],
#  ['resourcey', '', 'resources', 'for', 'programmers'],
#  ['simple',
#   'haskell',
#   'webapp',
#   'generate',
#   'random',
#   'tweets',
#   'using',
#   'markov',
#   'chains'],
#  ['clinical', 'trials'],
#  ['state',
#   'of',
#   'the',
#   'arms',
#   'race',
#   'between',
#   'repressive',
#   'govt',
#   'and',
#   'tor',
#   'technology'],
#  ['heka', '03', 'released'],
#  ['hungry', 'hackers', 'website', 'hacked', 'by', 'cybermind', '~', 'thn'],
#  ['square', 'closes', '$200m', 'series', 'd'],
#  ['watersoluble', 'silicon', 'leads', 'to', 'dissolvable', 'electronics'],
#  ['googles', 'android', 'stats', '850000', 'activations', 'per', 'day'],
#  ['how', 'i', 'would', 'try', 'to', 'hack', 'your', 'mintcom', 'account'],
#  ['dwolla', 'shuts', 'off', 'transfers', 'to', 'mtgox'],
#  ['dropbox',
#   'catches',
#   'pickpockets',
#   'selfie',
#   'video',
#   'on',
#   'stolen',
#   'mobile',
#   'phone'],
#  ['gmail',
#   'tricks',
#   'and',
#   'hacks',
#   'youve',
#   'probably',
#   'never',
#   'heard',
#   'of'],
#  ['a', 'critique', 'of', 'the', 'black', 'swan'],
#  ['the',
#   'one',
#   'feature',
#   'that',
#   'changed',
#   'social',
#   'networking',
#   'forever'],
#  ['will', 'os', 'x', 'mavericks', 'kill', 'the', 'paid', 'os', 'model'],
#  ['smart', 'tvs', 'are', 'dumb'],
#  ['write', 'better', 'with', 'draft'],
#  ['dawadi', 'journal', 'find', 'most', 'retweeted', 'or', 'popular', 'tweets'],
#  ['upcoming',
#   'facebook',
#   'at',
#   'work',
#   'service',
#   'will',
#   'rival',
#   'linkedin'],
#  ['apple',
#   'vs',
#   'google',
#   '',
#   'whos',
#   'side',
#   'will',
#   'verizon',
#   'end',
#   'up',
#   'on'],
#  ['fossils', 'suggest', 'hobbits', 'once', 'walked', 'the', 'earth'],
#  ['why', 'young', 'engineers', 'are', 'missing', 'out'],
#  ['farewell', 'nodejs'],
#  ['how', 'to', 'have', 'a', 'successful', 'sales', 'presentation'],
#  ['internet',
#   'archive',
#   'donations',
#   'matched',
#   '3x',
#   'until',
#   'the',
#   'end',
#   'of',
#   'the',
#   'year'],
#  ['bbc', 'docs', 'over', 'the', 'hill', 'in', 'silicon', 'valley', 'mp3'],
#  ['upgrade', 'your', 'health', 'today'],
#  ['the', 'obligation', 'to', 'dissent'],
#  ['akamai', 'update', 'heartbleed', 'a', 'history'],
#  ['dedicating', 'time', 'for', 'creative', 'pursuits'],
#  ['installing',
#   'windows',
#   '8',
#   'on',
#   'a',
#   'netbook',
#   '',
#   'does',
#   'it',
#   'work'],
#  ['did', 'path', 'cheat', 'its', 'way', 'to', 'the', 'top'],
#  ['bing', 'could', 'beat', 'yahoo', 'by', 'the', 'end', 'of', 'the', 'year'],
#  ['unemployment', 'of', 'engineering', 'graduates', 'the', 'key', 'issues'],
#  ['valves',
#   'hierarchy',
#   'has',
#   'hidden',
#   'management',
#   'clique',
#   'like',
#   'high',
#   'school'],
#  ['artin',
#   'fowler',
#   'on',
#   'schemalessness',
#   'nosql',
#   'and',
#   'software',
#   'design'],
#  ['criminal', 'case', 'cheats'],
#  ['html5', 'mmorpg', 'on', 'kickstarter'],
#  ['httpwwwaddthiscombookmarkphp'],
#  ['online',
#   'news',
#   'overtakes',
#   'paper',
#   'and',
#   'nearly',
#   'half',
#   'of',
#   'it',
#   'is',
#   'mobile'],
#  ['big',
#   'bang',
#   'isnt',
#   'porn',
#   'so',
#   'why',
#   'is',
#   'china',
#   'censoring',
#   'hollywood'],
#  ['allow', 'pro', 'users', 'to', 'disable', 'sponsored', 'ads'],
#  ['from', 'comfortable', 'and', 'pleasant', 'winters'],
#  ['the', 'protocols', 'powering', 'the', 'realtime', 'web'],
#  ['researcher',
#   'snaps',
#   'a',
#   'zeus',
#   'hackers',
#   'photo',
#   'through',
#   'his',
#   'webcam'],
#  ['amazon',
#   'prime',
#   'tops',
#   '20m',
#   'members',
#   'as',
#   'company',
#   'touts',
#   'its',
#   'best',
#   'holiday',
#   'season',
#   'ever'],
#  ['$50',
#   'million',
#   'series',
#   'a',
#   'investment',
#   'in',
#   'tenable',
#   'from',
#   'accel',
#   'partners'],
#  ['give',
#   'your',
#   'ios',
#   'app',
#   'an',
#   'unfair',
#   'advantage',
#   'by',
#   'adding',
#   'keywords',
#   'to',
#   'its',
#   'title'],
#  ['attack', 'on', 'sourceforgenet', 'and', 'global', 'password', 'reset'],
#  ['neckband', 'used', 'in', 'telepathic', 'chat'],
#  ['facebok', 'quietly', 'offering', 'conversion', 'tracking'],
#  ['ongodb', 'building', 'your', 'first', 'app'],
#  ['why',
#   'you',
#   'should',
#   '301',
#   'redirect',
#   'your',
#   'phpldpowered',
#   'directory',
#   'web',
#   'address'],
#  ['book', 'cheap', 'flights', 'online', '|', 'around', 'the', 'globe'],
#  ['nova',
#   'is',
#   'a',
#   'personal',
#   'climbing',
#   'wall',
#   'that',
#   'redefines',
#   'training',
#   'at',
#   'home'],
#  ['tech', 'writing', 'handbook'],
#  ['top',
#   'in',
#   'thoi',
#   'chp',
#   'hnh',
#   'nhnm',
#   '2010',
#   '|',
#   'in',
#   'thoi',
#   '',
#   'smartphone'],
#  ['omaha', '3', 'modernizing', 'automatic', 'software', 'updating'],
#  ['how', '3d', 'printing', 'could', 'help', 'replace', 'russian', 'rockets'],
#  ['penio'],
#  ['feds',
#   'warrantlessly',
#   'tracking',
#   'americans',
#   'credit',
#   'cards',
#   'in',
#   'real',
#   'time'],
#  ['the', 'mathematics', 'of', 'leaf', 'decay'],
#  ['the', 'past', 'is', 'the', 'future', 'for', 'hitech'],
#  ['getting', 'more', 'from', 'vim'],
#  ['ganesh',
#   'iyers',
#   'realtime',
#   'words',
#   'in',
#   'a',
#   'word',
#   'game',
#   'with',
#   'nodejs',
#   '',
#   'socketio'],
#  ['sam', 'altmans', 'cs183b', '–', 'class', '0'],
#  ['ivy', '3770', 'ti', '', 'custom', 'built', 'gaming', 'pc'],
#  ['crowdsourcing', 'an', 'israelipalestinian', 'border'],
#  ['want',
#   'healthy',
#   'food',
#   'delivered',
#   'to',
#   'your',
#   'office',
#   'fridge',
#   'its',
#   'available',
#   'in',
#   'oakland'],
#  ['linux', 'ice', 'maker', 'and', 'vending', 'machine', 'cool'],
#  ['app', 'for', 'selling', 'digital', 'products'],
#  ['why',
#   'i',
#   'stopped',
#   'using',
#   'the',
#   'phrase',
#   'this',
#   'is',
#   'not',
#   'rocket',
#   'science'],
#  ['how',
#   'to',
#   'install',
#   'vmware',
#   'workstation',
#   'on',
#   'linux',
#   'and',
#   'create',
#   'virtual',
#   'machine'],
#  ['hibari', 'design', 'philosophy'],
#  ['aking', 'a', 'beautiful', 'modern', 'website', '', 'tutorial', 'series'],
#  ['copyright', 'office', 'fails', 'to', 'protect', 'users', 'from', 'dmca'],
#  ['can', 'you', 'get', 'treatment', 'for', 'your', 'internet', 'addiction'],
#  ['the',
#   'worst',
#   'act',
#   'of',
#   'terrorism',
#   'in',
#   'san',
#   'francisco',
#   'history'],
#  ['less', 'consumption', 'more', 'production'],
#  ['android', 'ice', 'cream', 'sandwich', 'features'],
#  ['a', 'list', 'of', 'interesting', 'erlang', 'links'],
#  ['what', 'is', 'our', 'intent'],
#  ['diablo',
#   '3',
#   'free',
#   '',
#   'must',
#   'be',
#   'at',
#   'least',
#   '13',
#   'yrs',
#   'of',
#   'age'],
#  ['how',
#   'aaron',
#   'brown',
#   'a',
#   'fake',
#   'person',
#   'was',
#   'created',
#   'for',
#   'real',
#   'on',
#   'the',
#   'deep',
#   'web'],
#  ['ibm', 'chip', 'senses', 'events', 'to', 'react', 'like', 'brain'],
#  ['nanopond', 'artificial', 'life', 'vm'],
#  ['creating', 'dynamic', 'volumes', 'with', 'loop', 'devices'],
#  ['cloudgridjs', 'by', 'pinterest'],
#  ['ongodb', 'adds', 'atomic', 'find', 'and', 'modify'],
#  ['the',
#   'secret',
#   'to',
#   'online',
#   'safety',
#   'lies',
#   'random',
#   'characters',
#   'and',
#   'a',
#   'password',
#   'manager'],
#  ['hype', 'up', 'weekend', '', 'a', 'vaporware', 'hackathon'],
#  ['ailcore', '2', 'the', 'next', 'step', 'of', 'libetpan'],
#  ['facebook',
#   'does',
#   'block',
#   'spam',
#   'urls',
#   'but',
#   'there',
#   'method',
#   'is',
#   'useless',
#   'cuz'],
#  ['seo', 'uploading', 'files', 'with', 'optimized', 'name'],
#  ['the',
#   'surprising',
#   'reason',
#   'publishers',
#   'are',
#   'finally',
#   'saying',
#   'yes',
#   'to',
#   'apple'],
#  ['check', 'out', 'our', 'neuroscience', 'based', 'music', 'channels'],
#  ['if',
#   'managers',
#   'were',
#   'interviewed',
#   'the',
#   'same',
#   'way',
#   'as',
#   'developers'],
#  ['apples',
#   'north',
#   'carolina',
#   'solar',
#   'fuel',
#   'cell',
#   'plants',
#   'will',
#   'be',
#   'largest',
#   'of',
#   'their',
#   'kind'],
#  ['aca', 'to', 'adopt', 'ipl', 'way'],
#  ['why', 'the', 'internet', 'needs', 'ipv6'],
#  ['have',
#   'to',
#   'much',
#   'time',
#   'on',
#   'your',
#   'hands',
#   '',
#   '',
#   'digital',
#   'lego'],
#  ['zed', 'presents', 'the', 'acl', 'is', 'dead', 'at', 'cusec2008'],
#  ['show', 'hn', 'clickhopme', 'browser', 'screen', 'sharing', 'for', 'chrome'],
#  ['fanning', 'the', 'flames', 'of', 'developer', 'burnout'],
#  ['prototyping',
#   'app',
#   'pop',
#   'joins',
#   'avos',
#   'the',
#   'company',
#   'led',
#   'by',
#   'youtube',
#   'founders'],
#  ['windows',
#   'phone',
#   '7',
#   'dont',
#   'bother',
#   'with',
#   'this',
#   'disaster',
#   '|',
#   'mobilize',
#   '',
#   'infoworld'],
#  ['t',
#   'gox',
#   'halts',
#   'us',
#   'dollar',
#   'withdrawals',
#   'at',
#   'bitcoin',
#   'exchange'],
#  ['tock', '–', 'new', 'restaurant', 'ticketing', 'from', 'alinea'],
#  ['dropbox', 'moves', 'beyond', 'simple', 'file', 'management'],
#  ['pine', 'furniture'],
#  ['this',
#   'week',
#   'in',
#   'location',
#   'based',
#   'marketing',
#   '',
#   'ep',
#   '41',
#   'flickr',
#   'gootip',
#   'wajam',
#   '',
#   'snapette'],
#  ['stomach', 'lapbands', 'now', 'for', 'everyone'],
#  ['keyway', 'a', 'simple', 'bash', 'lock', 'file', 'library'],
#  ['how', 'to', 'be', 'a', 'successful', 'software', 'engineer'],
#  ['drm', 'is', 'about', 'to', 'get', 'even', 'worse', 'with', 'hdcp', '22'],
#  ['scala',
#   'vs',
#   'java',
#   'just',
#   'as',
#   'fast',
#   'less',
#   'code',
#   'harder',
#   'to',
#   'program',
#   'regardless',
#   'of',
#   'skill'],
#  ['the', 'content', 'problem', 'and', 'some', 'rss', 'ideas'],
#  ['icrosofts',
#   'digits',
#   'hand',
#   'gesture',
#   'sensor',
#   'bracelet',
#   'breaks',
#   'cover'],
#  ['c10',
#   'tapping',
#   'north',
#   'bridge',
#   'to',
#   'advance',
#   'stretchable',
#   'silicon',
#   'business'],
#  ['where',
#   'uniqueness',
#   'lies',
#   'the',
#   'key',
#   'in',
#   'our',
#   'brains',
#   'that',
#   'unlocks',
#   'our',
#   'difference'],
#  ['intel',
#   'sandy',
#   'bridge',
#   'cpus',
#   'and',
#   'motherboards',
#   'spotted',
#   'in',
#   'malaysia'],
#  ['the', 'algebra', 'of', 'data', 'and', 'the', 'calculus', 'of', 'mutation'],
#  ['sony', 'accidentally', 'funded', '“rogue”', 'piracy', 'sites'],
#  ['chromephp', 'console', 'logging', 'extension', 'for', 'google', 'chrome'],
#  ['qa', 'with', 'battery', 'ventures', 'about', 'hoteltonight', 'gogobot'],
#  ['lets',
#   'hope',
#   'the',
#   'apple',
#   'stores',
#   'new',
#   'ceo',
#   'forgets',
#   'everything',
#   'he',
#   'knows',
#   'about',
#   'retail'],
#  ['download', 'safari', '4', '', 'official', 'release'],
#  ['these',
#   'tech',
#   'companies',
#   'are',
#   'spending',
#   'millions',
#   'on',
#   'highpriced',
#   'lobbyists'],
#  ['daily',
#   'satellite',
#   'shots',
#   'of',
#   'the',
#   'polar',
#   'ice',
#   'caps',
#   'since',
#   '1979'],
#  ['hosting', 'clojure', 'web', 'apps', 'in', '7', 'easy', 'steps'],
#  ['tubular', 'cutting', 'technique'],
#  ['duplicating',
#   'the',
#   'nsa',
#   'spysetplayset',
#   'to',
#   'an',
#   'opensource',
#   'project'],
#  ['women', 'are', 'bailing', 'out', 'of', 'it'],
#  ['the', 'facebook', 'sdk', 'for', 'parse', 'is', 'better', 'than', 'ever'],
#  ['switching',
#   'biofuels',
#   'could',
#   'do',
#   'a',
#   'doublewhammy',
#   'on',
#   'climate',
#   'change'],
#  ['worlds', 'first', 'bitcoin', 'dedicated', 'miner', 'board', 'claimed'],
#  ['coldtags',
#   'suite',
#   '',
#   'the',
#   'largest',
#   'collection',
#   'of',
#   'custom',
#   'jsp',
#   'tags'],
#  ['google',
#   'is',
#   'said',
#   'to',
#   'be',
#   'acquiring',
#   'waze',
#   'for',
#   '$11',
#   'billion'],
#  ['the', 'lucrative', 'linux', 'job', 'offer', 'i', 'turned', 'down'],
#  ['rsa',
#   'factors',
#   'based',
#   'on',
#   'transmission',
#   'and',
#   'reflection',
#   'coefficient'],
#  ['fastclick',
#   '',
#   'polyfill',
#   'to',
#   'remove',
#   'click',
#   'delays',
#   'on',
#   'browsers',
#   'with',
#   'touch',
#   'uis'],
#  ['deadmou5', 'twitter', 'hacked'],
#  ['[ask',
#   'hn]',
#   'any',
#   'feedback',
#   'on',
#   'the',
#   'first',
#   'alpha',
#   'build',
#   'of',
#   'my',
#   'game'],
#  ['faust', 'and', 'the', 'physicists'],
#  ['bnfc', 'languageagnostic', 'parser', 'generator', 'generator'],
#  ['codertalk',
#   '',
#   'episode',
#   '4',
#   'work',
#   '',
#   'life',
#   'balance',
#   'coding',
#   'with',
#   'kids',
#   'etc'],
#  ['consumer', 'technology', 'trends', 'for', '2014'],
#  ['hackerchatco',
#   '–',
#   'a',
#   'private',
#   'slack',
#   'chat',
#   'for',
#   'the',
#   'hn',
#   'community'],
#  ['wordpress',
#   'explains',
#   '110',
#   'minutes',
#   'of',
#   'downtime',
#   'for',
#   '102',
#   'millions',
#   'blogs'],
#  ['the', 'most', 'expensive', 'onebyte', 'mistake', '2011'],
#  ['the', 'internet', 'is', 'my', 'religion'],
#  ['httpwwwbijuteriiartacomblogbijuteriitimisoarahandmade'],
#  ['how',
#   'to',
#   'build',
#   'a',
#   'hadoop',
#   'vm',
#   'with',
#   'ambari',
#   'and',
#   'vagrant'],
#  ['10', 'free', 'and', 'amazing', 'linux', 'apps', 'for', 'programmers'],
#  ['steve',
#   'krug',
#   'author',
#   'of',
#   'dont',
#   'make',
#   'me',
#   'think',
#   'has',
#   'a',
#   'new',
#   'book',
#   'on',
#   'usability',
#   'testing'],
#  ['whatsapps',
#   'journey',
#   'from',
#   'being',
#   'ignored',
#   'to',
#   'a',
#   '$19',
#   'billion',
#   'exit'],
#  ['pullclean', 'sanitizing', 'door', 'handle'],
#  ['a', 'brainf*ck', 'monad'],
#  ['even',
#   'worse',
#   'than',
#   'foxconn',
#   'apple',
#   'rocked',
#   'by',
#   'child',
#   'labour',
#   'claims'],
#  ['the', 'valley', 'needs', 'a', 'valleywag', 'or', 'something', 'february'],
#  ['against', 'acceleration'],
#  ['snow',
#   'and',
#   'tell',
#   'snow',
#   'informing',
#   'how',
#   'we',
#   'use',
#   'public',
#   'space'],
#  ['to', 'learn', 'quick', 'photoshop', 'use', 'these', 'tutorials'],
#  ['hack',
#   'battle',
#   'at',
#   'the',
#   'hacker',
#   'conference',
#   '2013',
#   'with',
#   'ctf365',
#   '',
#   'the',
#   'hacker',
#   'news'],
#  ['1%',
#   'of',
#   'cmspowered',
#   'sites',
#   'expose',
#   'their',
#   'database',
#   'passwords',
#   '2011'],
#  ['surface',
#   'pro',
#   '3',
#   'can',
#   'do',
#   'it',
#   'all',
#   '–',
#   'maybe',
#   'even',
#   'lift',
#   'the',
#   'windows',
#   '8',
#   'curse'],
#  ['everything', 'you', 'need', 'to', 'benefit', 'from', 'big', 'data'],
#  ['icrosoft',
#   'has',
#   'over',
#   '1',
#   'million',
#   'servers',
#   '',
#   'what',
#   'does',
#   'that',
#   'really',
#   'mean'],
#  ['show',
#   'hn',
#   'weekend',
#   'project',
#   '',
#   'keep',
#   'calm',
#   'and',
#   'read',
#   'hacker',
#   'news'],
#  ['lessons', 'learned', 'from', 'the', 'launch', 'of', 'word', 'lens'],
#  ['a',
#   'review',
#   'of',
#   'the',
#   'blackphone',
#   'the',
#   'android',
#   'for',
#   'the',
#   'paranoid'],
#  ['random',
#   'thoughts',
#   'on',
#   'the',
#   'substring',
#   'procedure',
#   'on',
#   'strict',
#   'vs',
#   'laxfuzzy',
#   'apis',
#   '',
#   'magic'],
#  ['otorola',
#   'mobility',
#   'launched',
#   'motorola',
#   'defy',
#   'mini',
#   'xt320',
#   'in',
#   'china'],
#  ['the', 'social', 'organization', 'of', 'the', 'computer', 'underground'],
#  ['note',
#   'to',
#   'facebook',
#   'shareholders',
#   'what',
#   'to',
#   'do',
#   'after',
#   'you',
#   'make',
#   'a',
#   'zillion',
#   'dollars'],
#  ['leverage', 'points', 'places', 'to', 'intervene', 'in', 'a', 'system'],
#  ['on', 'finding', 'mentors', 'through', 'issuing', 'challenges'],
#  ['prototype',
#   'of',
#   'collaborative',
#   'editing',
#   'in',
#   'kde',
#   'text',
#   'editor',
#   'component'],
#  ['nodejs', 'dataintensive', 'realtime', 'applications'],
#  ['effs', 'mass', 'copyright', 'litigation', 'roundup'],
#  ['otorcycle', 'accident', 'attorney', 'lexington'],
#  ['how',
#   'whereoscope',
#   'yc',
#   's10',
#   'located',
#   'a',
#   'market',
#   'for',
#   'its',
#   'familyfinder',
#   'app'],
#  ['churn',
#   'walkthrough',
#   'part',
#   'i',
#   'defining',
#   'active',
#   'and',
#   'lost',
#   'customer'],
#  ['deploy', 'php', 'to', 'heroku'],
#  ['can',
#   'americas',
#   'desert',
#   'cities',
#   'adapt',
#   'before',
#   'they',
#   'dry',
#   'out',
#   'and',
#   'die'],
#  ['ergoemacs', '', 'ergonomically', 'modernized', 'emacs'],
#  ['what', 'do', 'hsbc', 'and', 'anthem', 'have', 'in', 'common'],
#  ['the', 'simple', 'blog', 'engine', '', 'substance'],
#  ['aeron', 'another', 'messaging', 'system'],
#  ['privy', 'purse', 'in', 'india'],
#  ['come',
#   'on',
#   'google',
#   'need',
#   'this',
#   'site',
#   'up',
#   'and',
#   'seoed',
#   'again'],
#  ['nvidia',
#   'network',
#   'breached',
#   '500',
#   'staff',
#   'urged',
#   'to',
#   'change',
#   'account',
#   'details'],
#  [],
#  ['dawn', 'mission'],
#  ['in',
#   'social',
#   'bees',
#   'and',
#   'loners',
#   'a',
#   'hunt',
#   'for',
#   'the',
#   'genes',
#   'behind',
#   'social',
#   'behavior'],
#  ['facial',
#   'recognition',
#   'being',
#   'rolled',
#   'out',
#   'to',
#   'boost',
#   'sales',
#   'at',
#   'retailers'],
#  ['criminals', 'pay', 'top', 'money', 'for', 'hackable', 'nokia', 'phone'],
#  ['elasticsearch',
#   'for',
#   'beginners',
#   'index',
#   'and',
#   'search',
#   'hacker',
#   'news'],
#  ['battle',
#   'in',
#   'the',
#   'boardroom',
#   'why',
#   'groupon',
#   'probably',
#   'paid',
#   'off',
#   'its',
#   'early',
#   'employees'],
#  ['learn', 'python', 'the', 'hard', 'way', 'p2pu', 'school', 'of', 'webcraft'],
#  ['facebook', 'bruteforcing', 'hidden', 'services'],
#  ['dont', 'ever', 'use', 'this', 'word', 'with', 'developers'],
#  ['the',
#   'years',
#   'top',
#   'politicians',
#   'and',
#   'their',
#   'best',
#   'deletions',
#   'from',
#   'twitter'],
#  ['rim', 'just', 'doesnt', 'understand', 'its', 'developers'],
#  ['documenting',
#   'and',
#   'assessing',
#   'an',
#   'ad',
#   'experiment',
#   'across',
#   'search',
#   'and',
#   'social'],
#  ['php', 'meet', 'elegance', 'laravel', '3', 'has', 'arrived'],
#  ['6', 'most', 'irresistible', 'business', 'boards', 'you', 'must', 'follow'],
#  ['hp', '‘we', 'are', 'not', 'walking', 'away', 'from', 'webos'],
#  ['a',
#   'lecture',
#   'on',
#   'johnson',
#   'and',
#   'boswell',
#   'by',
#   'jorge',
#   'luis',
#   'borges'],
#  ['paul', 'graham', 'just', 'shut', 'your', 'face', 'already'],
#  ['flummoxed', 'by', 'failureor', 'focused'],
#  ['two',
#   'guys',
#   'on',
#   'mobile',
#   '',
#   'episode',
#   '27',
#   'amazons',
#   'fire',
#   'and',
#   'silk',
#   '',
#   'gigaoms',
#   'mobilize'],
#  ['gore',
#   'video',
#   'brutal',
#   'truck',
#   'accident',
#   '',
#   'dying',
#   'man',
#   'bathed',
#   'in',
#   'blood',
#   'with',
#   'severed',
#   'limbs'],
#  ['hotel',
#   'ousts',
#   'couple',
#   'after',
#   'accusing',
#   'them',
#   'of',
#   'writing',
#   'negative',
#   'tripadvisor',
#   'review'],
#  ['delta', 'debugging'],
#  ['icrosoft', 'apple', 'google', 'sued', 'over', 'icon', 'software', 'patent'],
#  ['3',
#   'steps',
#   'to',
#   'optimize',
#   'your',
#   'website',
#   'for',
#   'googles',
#   'freshness',
#   'update'],
#  ['whats', 'on', 'my', 'nexus', '5'],
#  ['find', 'laundromat', 'phoenix'],
#  ['linux', 'journal', 'readers', 'choice', 'awards', '2013'],
#  ['show', 'hn', 'printchomp', 'print', 'goods', 'ordercomparison', 'engine'],
#  ['show', 'hn', 'wooey', 'web', 'uis', 'for', 'python', 'scripts'],
#  ['google', 'executives', 'face', 'jail', 'time', 'for', 'italian', 'video'],
#  ['ben',
#   'goertzel',
#   'the',
#   'structure',
#   'of',
#   'the',
#   'physical',
#   'world',
#   'and',
#   'definitions',
#   'of',
#   'intelligence'],
#  ['wall', 'streets', 'bad', 'dream'],
#  ['twitters',
#   'storm',
#   'complex',
#   'event',
#   'processing',
#   'system',
#   'is',
#   'now',
#   'open',
#   'source'],
#  ['nasa',
#   'scientists',
#   'are',
#   'on',
#   'a',
#   'mission',
#   'to',
#   'break',
#   'the',
# ...
#   'the',
#   'same',
#   'time'],
#  ['skills', 'needed', 'in', 'programming'],
#  ['otif', 'now', 'freely', 'available', 'under', 'the', 'lgpl'],
#  ['project', 'management', 'software', 'online', 'tour', 'projectvision'],
#  ['science',
#   'never',
#   'fails',
#   'the',
#   'journal',
#   'of',
#   'unsolved',
#   'questions'],
#  ['localtunnel', 'v2', 'available', 'in', 'beta'],
#  ['understand',
#   'the',
#   'intricacies',
#   'of',
#   'cloud',
#   'benefits',
#   'and',
#   'cloud',
#   'computing',
#   'disadvantages'],
#  ['why', 'are', 'we', 'better', 'than', 'google'],
#  ['company', 'demos', 'personal', 'aircraft', 'future', 'jetpack'],
#  ['poisson', 'image', 'editing', 'in', 'python'],
#  ['ac',
#   'users',
#   'can',
#   'now',
#   'enjoy',
#   'bookmark',
#   'sync',
#   'extensions',
#   'in',
#   'chrome'],
#  ['bankruptcy',
#   'auctions',
#   'go',
#   'online',
#   'to',
#   'boost',
#   'cash',
#   'for',
#   'creditors'],
#  ['cool', 'silicone', 'snowboard', 'cover'],
#  ['alibaba', 'turns', 'to', 'travel', 'as', 'profit', 'zooms'],
#  ['creative', 'market', 'is', 'open', 'for', 'business'],
#  ['$msft',
#   'at',
#   '14year',
#   'high',
#   'heading',
#   'into',
#   'the',
#   'apple',
#   'announcement'],
#  ['3',
#   'steps',
#   'to',
#   'writing',
#   'an',
#   'open',
#   'source',
#   'project',
#   'case',
#   'study'],
#  ['steve', 'jobs', 'probably', 'wont', 'come', 'back', 'to', 'apple'],
#  ['tokyo', 'trials', 'digital', 'billboards', 'that', 'scan', 'passersby'],
#  ['itunes', 'concept'],
#  ['the', 'truth', 'about', 'terms', 'and', 'conditions'],
#  ['featured', 'class', 'introduction', 'to', 'c'],
#  ['facebook',
#   'fixed',
#   'data',
#   'table',
#   'a',
#   'react',
#   'component',
#   'for',
#   'building',
#   'and',
#   'presenting',
#   'data'],
#  ['fully', 'loaded', 'node'],
#  ['14',
#   'years',
#   'ago',
#   'the',
#   'day',
#   'teller',
#   'gave',
#   'me',
#   'the',
#   'secret',
#   'to',
#   'my',
#   'career',
#   'in',
#   'magic'],
#  ['ore', 'than', '200', 'kids', 'virtual', 'worlds', 'in', 'development'],
#  ['4', 'ways', 'to', 'brainstorm', 'like', 'a', 'pro'],
#  ['pete', 'townshend', 'calls', 'apple', 'a', 'vampire'],
#  ['edical', 'billing', 'software'],
#  ['show', 'hn', 'urgent', 'care', 'in', 'your', 'home'],
#  ['oxford',
#   'graduate',
#   'application',
#   '201213',
#   '|',
#   'ebook',
#   'and',
#   'pdf',
#   'search',
#   'engine'],
#  ['why', 'you', 'shouldnt', 'read', 'gizmodo'],
#  ['pets', 'as', 'wizards'],
#  ['wikileaks', 'julian', 'assange', 'to', 'leave', 'embassy', 'soon'],
#  ['we', 'are', 'the', 'worst', 'registrar', 'in', 'the', 'world'],
#  ['show', 'hn', 'kinect', 'home', 'automation', 'goes', 'html5'],
#  ['our',
#   'product',
#   'helped',
#   'build',
#   'software',
#   'for',
#   'the',
#   'curiosity',
#   'mission'],
#  ['ipad', 'sales', 'outpace', 'every', 'prediction'],
#  ['a16z', 'invests', 'in', 'stack', 'exchange'],
#  ['live', 'character', 'count', 'meter', 'with', 'jquery'],
#  ['learning', 'r', 'interactively', 'with', 'the', 'swirl', 'package'],
#  ['leadership',
#   'skills',
#   'come',
#   'from',
#   'expert',
#   'knowledge',
#   'not',
#   'interpersonal',
#   'skills'],
#  ['get',
#   '10%',
#   'off',
#   'intellij',
#   'idea',
#   'personal',
#   'license',
#   'until',
#   'end',
#   'of',
#   'august'],
#  ['facebook',
#   'open',
#   'sources',
#   'flint',
#   'a',
#   'c',
#   'linter',
#   'written',
#   'in',
#   'd'],
#  ['laser', 'marking', 'machine'],
#  ['large', 'hadron', 'collider', 'as', 'massive', 'grid', 'computer'],
#  ['watchzindagi', 'na', 'milegi', 'dobaronline', 'freemegavideo'],
#  ['how', 'the', 'box', '2d', 'hero', 'caught', 'rovio', 'out'],
#  ['how', 'plague', 'inc', 'became', '#1', 'in', 'app', 'store'],
#  ['artificial',
#   'sweeteners',
#   'may',
#   'change',
#   'our',
#   'gut',
#   'bacteria',
#   'in',
#   'dangerous',
#   'ways'],
#  ['finding', 'a', 'graphs', 'radius', 'with', 'an', 'fpga'],
#  ['the', 'bacon', 'boom', 'was', 'not', 'an', 'accident'],
#  ['ozilla', 'chromeless', '02'],
#  ['lawyer',
#   'fears',
#   'assange',
#   'could',
#   'face',
#   'death',
#   'penalty',
#   'in',
#   'us'],
#  ['complexity',
#   'science',
#   'python',
#   'programming',
#   'and',
#   'the',
#   'philosophy',
#   'of',
#   'science'],
#  ['data', 'visualization', 'coursewiki', 'cs', '448b'],
#  ['commitstrip',
#   'the',
#   'blog',
#   'relating',
#   'the',
#   'daily',
#   'life',
#   'of',
#   'web',
#   'agencies',
#   'developers'],
#  ['lizardsquads',
#   'ddos',
#   'tool',
#   'falls',
#   'prey',
#   'to',
#   'hack',
#   'exposes',
#   'complete',
#   'customer',
#   'database'],
#  ['jimmy',
#   'wales',
#   'appeal',
#   'results',
#   'in',
#   '15x',
#   'more',
#   'donation',
#   'dollars'],
#  ['sxsw', 'trade', 'show', 'displays', 'latest', 'technologies'],
#  ['the', 'dangers', 'of', 'certainty', 'a', 'lesson', 'from', 'auschwitz'],
#  ['lean', 'tools'],
#  ['characteristics', 'of', 'machine', 'learning', 'model'],
#  ['cbbc',
#   'newsround',
#   '',
#   'boy',
#   'sends',
#   'robot',
#   'to',
#   'school',
#   'in',
#   'his',
#   'place'],
#  ['ruby', 'fibonacci', 'shootout', 'part', '2', 'macruby', 'vs', 'luajit'],
#  ['google', 'lifts', 'malware', 'warning', 'for', 'isocket', 'ad', 'network'],
#  ['translation', 'of', 'snowdens', 'latest', 'letter'],
#  ['interview',
#   'with',
#   'ringcentral',
#   'how',
#   'to',
#   'appear',
#   'like',
#   'a',
#   'huge',
#   'company',
#   'even',
#   'if',
#   'youre',
#   'just',
#   'one',
#   'guy'],
#  ['enrich',
#   'your',
#   'updates',
#   'on',
#   'linkedin',
#   'with',
#   'rich',
#   'media',
#   '[slideshow]'],
#  ['spaceshiptwos', 'first', 'feathered', 'flight'],
#  ['super', 'efficient', 'super', 'tiny', 'pico', 'projectors'],
#  ['lessons',
#   'learned',
#   'from',
#   'growing',
#   'linkedin',
#   'to',
#   '175',
#   'million',
#   'users'],
#  ['info', 'on', 'colocation', 'server', 'and', 'colocation', 'hosting'],
#  ['giuliano', 'fujiwara', 'women', 'fallwinter', '201112', 'tokyo'],
#  ['jiro',
#   'ono',
#   'and',
#   'rené',
#   'redzepi',
#   'have',
#   'a',
#   'cup',
#   'of',
#   'tea',
#   '[video]'],
#  ['ap', 'fearful', 'russian', 'lawmaker', 'flees', 'to', 'us'],
#  ['weaving', 'peace', 'for', 'mindanao'],
#  ['to', 'tool', 'or', 'not', 'to', 'tool'],
#  ['david',
#   'foster',
#   'wallace',
#   'postmodern',
#   'writer',
#   'is',
#   'found',
#   'dead',
#   'at',
#   'home'],
#  ['emacs', 'now', 'has', 'multitty', 'in', 'cvs', 'head'],
#  ['youtube',
#   '',
#   'horrific',
#   'dust',
#   'storm',
#   'of',
#   'decade',
#   'spikes',
#   'valley',
#   'fever',
#   'az',
#   'raw',
#   'video'],
#  ['ark', 'cubans', 'amazon', 'book', 'recommendations'],
#  ['a',
#   'cocoa',
#   'library',
#   'to',
#   'extend',
#   'the',
#   'objectivec',
#   'programming',
#   'language'],
#  ['nexus', 'oneverizon', 'support', 'coming'],
#  ['beano', 'brand', 'guidelines', 'designed', 'by', 'wayne', 'hemingway'],
#  ['google', 'diversity', 'statistics'],
#  ['google', 'cardboard', '–', 'inexpensive', 'vr', 'headset'],
#  ['will',
#   'youtubes',
#   'comment',
#   'jerks',
#   'willingly',
#   'out',
#   'themselves',
#   'not',
#   'bloody',
#   'likely'],
#  ['3', 'resources', 'for', 'web', 'designers'],
#  ['banning', 'the', 'word', 'difficult'],
#  ['siblyback', 'lake', 'walking', 'route'],
#  ['imf', 'cuts', 'us', 'growth', 'forecast', 'warns', 'of', 'crisis'],
#  ['the', 'mirror', 'man'],
#  ['warren',
#   'spector',
#   'wants',
#   'game',
#   'designers',
#   'to',
#   'work',
#   'on',
#   'noncombat',
#   'ai'],
#  ['us', 'marine', 'arrested', 'for', 'facebook', 'posts'],
#  ['how', 'i', 'started', 'betalist'],
#  ['house', 'of', 'anubis', 'season', '2'],
#  ['how', 'to', 'switch', 'to', 'a', 'new', 'ide', 'in', 'an', 'afternoon'],
#  ['open',
#   'corp',
#   'dev',
#   'an',
#   'idea',
#   'too',
#   'bold',
#   'for',
#   'facebook',
#   'or',
#   'dropbox'],
#  ['paginator',
#   '',
#   'a',
#   'simple',
#   'and',
#   'easy',
#   'php',
#   'class',
#   'that',
#   'allows',
#   'you',
#   'to',
#   'create',
#   'pagination'],
#  ['checkout', 'luxolasg', 'profile', 'on', 'discovermatch'],
#  ['learning', 'to', 'love', 'javascript'],
#  ['using', 'agile', 'techniques', 'to', 'pay', 'back', 'technical', 'debt'],
#  ['doomsday', 'clock', '', 'one', 'minutes', 'presented'],
#  ['show',
#   'hn',
#   'testing',
#   'a',
#   'spring',
#   '4',
#   'rest',
#   'backend',
#   'using',
#   'java',
#   '8',
#   'lambdas'],
#  ['[video]',
#   'how',
#   'to',
#   'get',
#   'started',
#   'in',
#   'the',
#   'rails',
#   'community',
#   'no',
#   'blogspam'],
#  ['hackers',
#   'can',
#   'kill',
#   'diabetics',
#   'w',
#   'insulin',
#   'pumps',
#   'facts',
#   'vs',
#   'fear',
#   'mongering'],
#  ['beautiful',
#   'natural',
#   'amazing',
#   'bridge',
#   'wallpapers',
#   'desktop',
#   'background'],
#  ['crafting', 'a', 'pricing', 'plan', 'to', 'maximize', 'freemium', 'growth'],
#  ['what',
#   'i',
#   'saw',
#   'in',
#   'consumer',
#   'startups',
#   'after',
#   'i',
#   'left',
#   'silicon',
#   'valley'],
#  ['keplers', 'snowflake'],
#  ['chiropractors', 'email', 'lists', 'and', 'mailing', 'lists'],
#  ['an', 'inkling', 'how', 'to', 'learn', 'a', 'new', 'language', 'properly'],
#  ['video', '–', 'optimization', 'in', 'julia'],
#  ['women',
#   'hackers',
#   '',
#   'the',
#   'mission',
#   'to',
#   'locate',
#   'subversive',
#   'women',
#   'on',
#   'the',
#   'net',
#   '99'],
#  ['the', 'importance', 'of', 'trust', 'in', 'teams'],
#  ['acer', 'critics', 'unfair', 'to', 'windows', '8'],
#  ['phreaking', 'out', 'ma', 'bell'],
#  ['pygram', '', 'open', 'source', 'grammar', 'analyzer'],
#  ['facebook', 'feels', 'unfriendly', 'toward', 'movie', 'it', 'inspired'],
#  ['searching', 'questions', 'how', 'good', 'is', 'google'],
#  ['dui', 'attorney', 'jacksonville', '|', 'lawyer', 'jacksonville'],
#  ['demistifying', 'lazy', 'load', 'pattern'],
#  ['show', 'hn', 'keep', 'your', 'customers', 'informed', 'and', 'aware'],
#  ['richard',
#   'muller',
#   'the',
#   'case',
#   'against',
#   'globalwarming',
#   'skepticism'],
#  ['do', 'you', 'want', 'fries', 'with', 'that'],
#  ['twittercom', 'down'],
#  ['crash',
#   'could',
#   'free',
#   'up',
#   'wall',
#   'streets',
#   'grip',
#   'on',
#   'bright',
#   'young',
#   'minds'],
#  ['why', 'companies', 'need', 'to', 'experiment', 'more'],
#  ['a', 'history', 'of', 'graphic', 'design'],
#  ['fashionable', 'clothsummer', 'fashionbelts'],
#  ['we',
#   'were',
#   'tired',
#   'of',
#   'telling',
#   'people',
#   'what',
#   'gadget',
#   'to',
#   'buy',
#   'so',
#   'we',
#   'did',
#   'something',
#   'about',
#   'it'],
#  ['us',
#   'federal',
#   'government',
#   '20',
#   'ditches',
#   'blackberry',
#   'embraces',
#   'apple'],
#  ['the',
#   'lesson',
#   'from',
#   'better',
#   'places',
#   'bankruptcy',
#   'be',
#   'more',
#   'like',
#   'tesla'],
#  ['netflix',
#   'to',
#   'make',
#   'own',
#   'horror',
#   'show',
#   '',
#   'and',
#   'pick',
#   'up',
#   'terra',
#   'nova',
#   'the',
#   'river'],
#  ['code', 'ios', 'apps', 'in', 'ocaml'],
#  ['hackable', 'measurement', 'board', 'runs', 'linux', 'on', 'armfpga'],
#  ['amazonapple', 'app', 'store', 'law', 'suit', 'update'],
#  ['cydia', '20', 'vs', 'installer', '40'],
#  ['any', 'teens', 'send', '100', 'texts', 'a', 'day'],
#  ['windows', 'server', '8', 'beta', 'released', 'download', 'now'],
#  ['first',
#   'ever',
#   'photograph',
#   'of',
#   'light',
#   'as',
#   'a',
#   'particle',
#   'and',
#   'a',
#   'wave'],
#  ['orient', 'mako'],
#  ['ratings', 'prompts', 'dont', 'have', 'to', 'suck'],
#  ['android', 'challenges', 'the', 'iphone', 'in', 'every', 'category'],
#  ['scam', 'alert', '', 'fake', 'us', 'telecom'],
#  ['apple',
#   'ipad',
#   'mini',
#   'announced',
#   '',
#   'release',
#   'date',
#   'is',
#   'nov',
#   '2nd',
#   'at',
#   '$329'],
#  ['googles',
#   'ilost',
#   'motorola',
#   'ad',
#   'faked',
#   'an',
#   'address',
#   'to',
#   'lose',
#   'ios',
#   '6',
#   'maps'],
#  ['how', 'i', 'started', 'programming', 'it', 'was', 'quite', 'a', 'ride'],
#  ['emmanuel', 'dermans', 'battle', 'with', 'the', 'maladroid', 'android'],
#  ['reimagining',
#   'not',
#   'reinventing',
#   'food',
#   'distribution',
#   '–',
#   'food',
#   'and',
#   'tech',
#   'connect'],
#  ['the', 'history', 'of', 'online', 'advertising'],
#  ['compiling',
#   'lljs',
#   'to',
#   'asmjs',
#   'gives',
#   'near',
#   'c',
#   'speed',
#   'w',
#   'js',
#   'subset',
#   'using',
#   'typed',
#   'arrays'],
#  ['tv', 'relieves', 'loneliness'],
#  ['does', 'hydraulic', 'fracturing', 'trigger', 'earthquakes'],
#  ['gm', 'mosquitoes', 'show', 'dengue', 'fever', 'promise'],
#  ['ask',
#   'hn',
#   'feedback',
#   'on',
#   'my',
#   'javascript',
#   'library',
#   'suggestions',
#   'for',
#   'improvements'],
#  ['ask',
#   'hn',
#   'rearchitecting',
#   'on',
#   'slicehost',
#   'to',
#   'handle',
#   '50',
#   'apache',
#   'processes'],
#  ['buddypress', 'themes', 'that', 'really', 'worth', 'your', 'attention'],
#  ['air', 'hockey', 'robot', 'project', 'a', '3d', 'printer', 'hack'],
#  ['facebook',
#   'makes',
#   'a',
#   'huge',
#   'data',
#   'grab',
#   'by',
#   'aggressively',
#   'promoting',
#   'photo',
#   'sync'],
#  ['encrypt', 'and', 'share', 'your', 'messages'],
#  ['c11',
#   'tutorial',
#   'explaining',
#   'the',
#   'everelusive',
#   'lvalues',
#   'and',
#   'rvalues'],
#  ['gmail', 'gets', 'nested', 'labels', 'and', 'message', 'sneak', 'peeks'],
#  ['iran', 'must', 'halt', 'execution', 'of', 'web', 'programmer'],
#  ['want', 'to', 'work', 'at', 'reddit'],
#  ['kenneth',
#   'cukier',
#   'speaks',
#   'about',
#   'big',
#   'data',
#   'at',
#   'tnw',
#   'conference',
#   'europe',
#   '2013'],
#  ['harvard',
#   'business',
#   'school',
#   'faculty',
#   'comment',
#   'on',
#   'crisis',
#   'in',
#   'japan'],
#  ['against',
#   'the',
#   'use',
#   'of',
#   'programming',
#   'languages',
#   'in',
#   'configuration',
#   'files'],
#  ['salesforcecom',
#   'ceo',
#   'sorry',
#   'virtualization',
#   'isnt',
#   'cloud',
#   'computing'],
#  ['obile', 'marketing', 'trends'],
#  ['saudi', 'blogger', 'badawi', 'again', 'avoids', 'flogging', 'amnesty'],
#  ['apple', 'design', 'awards', '2014'],
#  ['the', 'easy', 'installer', 'from', 'joomlatag'],
#  ['wheels',
#   'of',
#   'steel',
#   'epic',
#   'demo',
#   'of',
#   'rich',
#   'web',
#   'turn',
#   'table'],
#  ['helped', 'wanted', '', 'ottawa', 'linux', 'symposiumindiegogo', 'campaign'],
#  ['pressflip', 'is', 'a', 'belly', 'flop'],
#  ['kozmocom', 'is', 'back', 'from', 'the', 'dead'],
#  ['galaxys',
#   'guardians',
#   'make',
#   'the',
#   'case',
#   'upgrade',
#   'pluto',
#   'back',
#   'to',
#   'planetsize'],
#  ['hacking', 'group', 'wants', 'to', 'play', 'nice', 'with', 'automakers'],
#  ['why', 'office', 'distractions', 'dont', 'matter'],
#  ['the', 'best', 'iphone', 'apps', 'for', 'business'],
#  ['restore', 'potency', 'and', 'cure', 'ed'],
#  ['interview', 'with', 'matt', 'graham', 'designer', 'at', 'github'],
#  ['6',
#   'things',
#   'you',
#   'should',
#   'never',
#   'say',
#   'to',
#   'a',
#   'software',
#   'tester'],
#  ['chicago',
#   'is',
#   'beating',
#   'silicon',
#   'valley',
#   'at',
#   'the',
#   'patent',
#   'game'],
#  ['47',
#   'million',
#   'new',
#   'places',
#   'to',
#   'charge',
#   'an',
#   'electric',
#   'car',
#   'by',
#   '2015',
#   'analysts',
#   'say'],
#  ['building', 'design', 'plans'],
#  ['a', 'table', 'of', 'electric', 'clay', '2013', '[video]'],
#  ['python', 'bumps', 'off', 'java', 'as', 'top', 'learning', 'language'],
#  ['vpn', 'access', 'being', 'disabled', 'in', 'china'],
#  ['solution',
#   'blogger',
#   'redirect',
#   'to',
#   'a',
#   'countryspecific',
#   'url',
#   'cctld'],
#  ['is', 'apple', 'bringing', 'high', 'luxury', 'down', 'to', 'the', 'people'],
#  ['how', 'video', 'game', 'designers', 'view', 'developers'],
#  ['stolen',
#   'credit',
#   'card',
#   'information',
#   'used',
#   'to',
#   'make',
#   'purchases',
#   'with',
#   'apple',
#   'pay'],
#  ['tips', 'for', 'buying', 'concert', 'tickets', 'online'],
#  ['weird', 'exoplanet', 'discovered', 'orbiting', 'two', 'stars'],
#  ['in', 'the', 'last', '10', 'years', 'weve', 'learned', 'a', 'lot'],
#  ['speed', 'up', 'your', 'ios', 'development', 'with', 'clutchio'],
#  ['common',
#   'app',
#   'problems',
#   'a',
#   'meltdown',
#   'worthy',
#   'of',
#   'healthcaregov'],
#  ['data', 'killed', 'the', 'hippo', 'star'],
#  ['nokia', '3230', 'speaker', 'ways', 'ear', 'phone'],
#  ['what', 'happens', 'to', 'your', 'body', 'when', 'youre', 'asleep'],
#  ['rims',
#   'q4',
#   'likely',
#   'to',
#   'disappoint',
#   'iphone',
#   '5',
#   'will',
#   'overshadow',
#   'blackberry',
#   '10'],
#  ['uber', 'for', 'gift', 'giving'],
#  ['nike', 'dunks', 'cheap', 'for', 'sale'],
#  ['yahoo', 'names', 'paypals', 'scott', 'thompson', 'as', 'new', 'head'],
#  ['oving', 'to', 'california', 'wont', 'make', 'you', 'happy'],
#  ['luxury', 'brands', 'make', 'a', 'good', 'investment'],
#  ['speeding', 'up', 'our', 'test', 'suite', 'in', 'development'],
#  ['twitter', 'restores', '$50000', 'n', 'username', 'to', 'its', 'owner'],
#  ['campuses',
#   'getting',
#   'less',
#   'political',
#   'as',
#   '60s',
#   'professors',
#   'retire'],
#  ...]

# %% [markdown]
# #### Assembling a Matrix of Unique Words

# %%
import numpy as np
unique_tokens = []
single_tokens = []
for tokens in clean_tokenized:
    for token in tokens:
        if token not in single_tokens:
            single_tokens.append(token)
        elif token in single_tokens and token not in unique_tokens:
            unique_tokens.append(token)

counts = pd.DataFrame(0, index=np.arange(len(clean_tokenized)), columns=unique_tokens)

# %%
for i, item in enumerate(clean_tokenized):
    for token in item:
        if token in unique_tokens:
            counts.iloc[i][token] += 1

# %% [markdown]
# #### Removing stopwords

# %%
word_counts = counts.sum(axis=0)

counts = counts.loc[:,(word_counts >= 5) & (word_counts <= 100)]

# %% [markdown]
# ## Training a Model with LInearRegression
#
# first of all, I'll split the data into train and test data and out target column is the upvotes column

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(counts, submissions["upvotes"], test_size=0.35, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression()
clf.fit(X_train, y_train)

predictions = clf.predict(X_test)

# %% [markdown]
# #### Picking an Error Metric
#
# I'll use rmse as thee error metric

# %%
mse = sum((predictions - y_test) ** 2) / len(predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 54.556993831940254

# %% [markdown]
# ## Training a Model with RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=5, random_state=1, min_samples_leaf=2)

rfr.fit(X_train, y_train)

predictions_1 = rfr.predict(X_test)

# %%
mse = sum((predictions_1 - y_test) ** 2) / len(predictions_1)
rmse = np.sqrt(mse)
rmse
# Out:
# 44.84857168288281

# %% [markdown]
#  There's no hard and fast rule about what a "good" error rate is, because it depends on the problem we're solving and our error tolerance.
#
# In this case, the mean number of upvotes is 10, and the standard deviation is 39.5.
#
# Using the Linear Regression Model, we got our rmse to be 54.5. This means that our average error is 54.5 upvotes away from the true value.
#
# Using the RandomForest Regressor Model, we got our rmse to be 44.8. This means that our average error is 44.8 upvotes away from the true value
#
#
# it seems the RandomForest Regressor Model performed better than Linear Regression Model, cause it's less farther from the standard deviation
